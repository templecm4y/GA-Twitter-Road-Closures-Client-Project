# %% [markdown]
# # Location Extraction and Spacy Word Vectorization

# %%
import pandas as pd
import numpy as np
import re
import spacy
import string
import datetime

# %%
# Read in csv with Tweets
twitter_closures = pd.read_csv("../data/Cleaned_Tweets/cleaned_historic_official_07302019.csv")
exits = pd.read_csv("../data/interstate_exits.csv")

twitter_closures = twitter_closures[['date', 'text', 'type', 'username', 'tweet', 'state', 'road_closure']]

# Print DF shape
print(twitter_closures.shape)

# Show head 
twitter_closures.head()
# Out:
# (24054, 7)
#                         date  \
# 0  2016-10-11 16:39:51+00:00
# 1  2016-10-10 19:10:23+00:00
# 2  2016-10-09 17:30:22+00:00
# 3  2016-10-09 15:45:11+00:00
# 4  2016-10-09 14:00:20+00:00
#
#                                                 text      type username  \
# 0  the pioh for the sr 138 i-20 is going on now u...  official  GDOTATL
# 1  we appreciate all the hard work our crews have...  official  GDOTATL
# 2  need info on re-entry  check here  also follow...  official  GDOTATL
# 3  do you need some updates  you can find all of ...  official  GDOTATL
# 4  did you know that the  511georgia website and ...  official  GDOTATL
#
#                                                tweet    state  road_closure
# 0  The PIOH for the SR 138 I-20 is going on now u...  Georgia             0
# 1  We appreciate all the hard work our crews have...  Georgia             0
# 2  Need info on re-entry  Check here  Also follow...  Georgia             0
# 3  Do you need some updates  You can find ALL of ...  Georgia             0
# 4  Did you know that the  511Georgia website and ...  Georgia             0

# %% [markdown]
# ## SpaCy Preprocessing

# %%
# Create new columns to transfer modified tweet text. Five versions of tweets will be created.
twitter_closures['modified_text'] = ''
twitter_closures['location'] = ''

# Show modified DF
twitter_closures.head(2)
# Out:
#                         date  \
# 0  2016-10-11 16:39:51+00:00
# 1  2016-10-10 19:10:23+00:00
#
#                                                 text      type username  \
# 0  the pioh for the sr 138 i-20 is going on now u...  official  GDOTATL
# 1  we appreciate all the hard work our crews have...  official  GDOTATL
#
#                                                tweet    state  road_closure  \
# 0  The PIOH for the SR 138 I-20 is going on now u...  Georgia             0
# 1  We appreciate all the hard work our crews have...  Georgia             0
#
#   modified_text location
# 0
# 1

# %%
format_dict = {"hwy": "highway ",
            "blvd": "boulevard",
            " st": "street",
           "CR ": "County Road ",
           "SR ": "State Road",
           "I-": "Interstate ",
           "EB ": "Eastbound ",
           "WB ": "Westbound ",
           "SB ": "Southbound",
           "NB ": "Northbound",
           " on ": " at ",
           " E ": " East ",
           " W ": " West ",
           " S ": " South",
           " N ": " North",
           "mi ": "mile ",
           "between ": "at ",
           "Between ": "at ",
           " In ": " in",
           " in ": " at "}

# %%
def spacy_cleaner(df, col, word_dict):
    modified_text = "At " + df[col].replace(word_dict, regex=True)
    modified_text = modified_text.str.title()
    return modified_text

# %%
# run the text cleaning function and test results
twitter_closures['modified_text'] = spacy_cleaner(twitter_closures, 'tweet', format_dict)

# %%
twitter_closures['username'].unique()
# Out:
# array(['GDOTATL', 'SCDOTMidlands', 'SCDOTPeeDee', 'SCDOTLowCountry',
#        'SCDOTPiedmont', '511statewideva', 'fl511_panhandl', '511Georgia',
#        'fl511_state', 'fl511_northeast', 'fl511_southeast',
#        'fl511_southwest', 'fl511_tampabay', 'fl511_central',
#        '511centralva', '511hamptonroads', '511northernva',
#        'NCDOT_Westmtn', 'NCDOT_Triangle', 'NCDOT_Piedmont',
#        'NCDOT_Charlotte', 'NCDOT_Asheville', 'NCDOT_Scoast',
#        'NCDOT_Ncoast'], dtype=object)

# %%
twitter_closures['date'] = pd.to_datetime(twitter_closures['date'])

# %%
twitter_closures = twitter_closures[(twitter_closures['date'] > '2016-10-4') & (twitter_closures['date'] < '2016-10-5')]

# %%
test_df = twitter_closures[(twitter_closures['road_closure'] == 1) & (twitter_closures['username'] == 'fl511_northeast')]
test_df.shape
# Out:
# (167, 9)

# %%
def get_loc(df, text_column, location_column):
    
    # Use Spacy to extract location names from `text` column
    for i in range(len(df)):
        
        #instantiate spacy model
        nlp = spacy.load("en_core_web_sm")
        
        # create documewnt from modified text column
        doc = nlp(df[text_column].iloc[i])
        
        locations = set()
        
        # loop through every entity in the doc
        for ent in doc.ents:
            
            # find entities labelled as places
            if (ent.label_=='GPE') or (ent.label_=='FAC') or (ent.label_ == 'LOC'):
                
                # put locations in a set
                locations.add(ent.text)
                df[location_column].iloc[i] = locations
                
    return df[location_column]

# %%
test = get_loc(test_df, 'modified_text', 'location')
# Out:
# /Users/templemoore/anaconda3/envs/dsi/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/templemoore/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
test_df['location'] = test
test_df.head()
# Out:
# /Users/templemoore/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                            date  \
# 14259 2016-10-04 23:58:11+00:00
# 14260 2016-10-04 22:43:11+00:00
# 14261 2016-10-04 22:32:41+00:00
# 14262 2016-10-04 22:28:37+00:00
# 14263 2016-10-04 22:22:46+00:00
#
#                                                     text      type  \
# 14259  new  crash in duval on i-95 south before 8th s...  official
# 14260  update  traffic congestion in duval on i-95 so...  official
# 14261  update  traffic congestion in duval on i-295 w...  official
# 14262  update  traffic congestion in duval on i-295 e...  official
# 14263  update  traffic congestion in duval on i-95 no...  official
#
#               username                                              tweet  \
# 14259  fl511_northeast  NEW  Crash in Duval on I-95 south before 8th S...
# 14260  fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 so...
# 14261  fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 W...
# 14262  fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 E...
# 14263  fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 no...
#
#          state  road_closure  \
# 14259  Florida             1
# 14260  Florida             1
# 14261  Florida             1
# 14262  Florida             1
# 14263  Florida             1
#
#                                            modified_text  \
# 14259  At New  Crash At Duval At Interstate 95 South ...
# 14260  At Update  Traffic Congestion At Duval At Inte...
# 14261  At Update  Traffic Congestion At Duval At Inte...
# 14262  At Update  Traffic Congestion At Duval At Inte...
# 14263  At Update  Traffic Congestion At Duval At Inte...
#
#                                                 location
# 14259         {Interstate 95 South, New  Crash At Duval}
# 14260  {Interstate 95 South From Exit 337 Interstate ...
# 14261  {Interstate 10, Exit 21, Normandy Blvd, Inters...
# 14262      {Exit 56, Exit 53, Interstate 295 East South}
# 14263  {Interstate 10, Interstate 95 North From Exit ...

# %%
test_df.to_csv("../data/Loc_Extracted/tweet_locations_sample_07302019.csv", index = False)

# %%
test_df = pd.read_csv("../data/Loc_Extracted/tweet_locations_sample_07302019.csv")

# %%
def exit_extractor (df, col, i_df):
    
    # instantiate lists for exit data
    exits = []
    interstates = []
    lat = []
    long = []
    direction = []
    
    # loop through text column
    for item in df[col]:
        
        # look for "interstate" in text
        if 'Interstate' in item:
            
            # use regex to extract interstate and number from text
            i_string = re.search(r'Interstate (\S+)', item)
            interstates.append(i_string.group(0))
            
            # find "exit" in text
            if 'Exit' in item:
                
                # use regex to extract interstate and number from text
                e_string = re.search(r'Exit (\S+)', item)
                exits.append(e_string.group(0))
            
            # add "none" when no exit is found   
            else:
                exits.append("None")
                
        # add "none" to exits and interstates if no interstate is found
        else:
            interstates.append("None")
            exits.append("None")
            
    # create a new dataframe from the interstate and exit lists
    new_df = pd.DataFrame(data = interstates, columns = ['interstate'])
    new_df['exits'] = exits
    
    # loop through the new dataframe
    for index, row in new_df.iterrows():
        
        # find rows that have both an interstate and exit extracted
        if (row['interstate'] != "None") and (row['exits'] != "None"):
            
            # create filter mask
            mask = (i_df['interstate'].str.contains(row['interstate'])) & (i_df['exits'].str.contains(row['exits']))
            
            # attempt to add lat and long based on exit and interstate strings
            try:
                # add lat and long to list
                lat.append(i_df[mask].iloc[0]['lat'])
                long.append(i_df[mask].iloc[0]['long'])
            
            # if an error occurs, append null to lat and long
            # print index where error occured
            except:
                print(f"No exit found at {index}")
                
                lat.append(np.nan)
                long.append(np.nan)
                
        # if no exit is found, add null values to lat and long
        else:
            lat.append(np.nan)
            long.append(np.nan)
            
    # add lat and long to new dataframe
    new_df['lat'] = lat
    new_df['long'] = long
    
    # sreturn new dataframe
    return new_df

# %%
e_df = exit_extractor(test_df, 'modified_text', exits)
# Out:
# No exit found at 9
# No exit found at 19
# No exit found at 28
# No exit found at 36
# No exit found at 49
# No exit found at 88
# No exit found at 89
# No exit found at 153
# No exit found at 161

# %%
final_df = pd.concat([test_df, e_df], axis = 1)

# %%
final_df
# Out:
#                           date  \
# 0    2016-10-04 23:58:11+00:00
# 1    2016-10-04 22:43:11+00:00
# 2    2016-10-04 22:32:41+00:00
# 3    2016-10-04 22:28:37+00:00
# 4    2016-10-04 22:22:46+00:00
# 5    2016-10-04 22:09:08+00:00
# 6    2016-10-04 22:02:53+00:00
# 7    2016-10-04 21:58:14+00:00
# 8    2016-10-04 21:58:12+00:00
# 9    2016-10-04 21:58:11+00:00
# 10   2016-10-04 21:58:00+00:00
# 11   2016-10-04 21:48:06+00:00
# 12   2016-10-04 21:48:04+00:00
# 13   2016-10-04 21:38:30+00:00
# 14   2016-10-04 21:38:28+00:00
# 15   2016-10-04 21:37:40+00:00
# 16   2016-10-04 21:28:03+00:00
# 17   2016-10-04 21:23:33+00:00
# 18   2016-10-04 21:23:31+00:00
# 19   2016-10-04 21:23:30+00:00
# 20   2016-10-04 21:17:59+00:00
# 21   2016-10-04 21:17:59+00:00
# 22   2016-10-04 21:17:57+00:00
# 23   2016-10-04 21:12:43+00:00
# 24   2016-10-04 21:12:43+00:00
# 25   2016-10-04 21:09:11+00:00
# 26   2016-10-04 20:58:38+00:00
# 27   2016-10-04 20:58:37+00:00
# 28   2016-10-04 20:58:36+00:00
# 29   2016-10-04 20:58:35+00:00
# ..                         ...
# 137  2016-10-04 10:42:39+00:00
# 138  2016-10-04 10:37:40+00:00
# 139  2016-10-04 10:37:40+00:00
# 140  2016-10-04 09:17:48+00:00
# 141  2016-10-04 09:13:01+00:00
# 142  2016-10-04 09:13:00+00:00
# 143  2016-10-04 09:12:43+00:00
# 144  2016-10-04 04:57:50+00:00
# 145  2016-10-04 04:57:37+00:00
# 146  2016-10-04 04:27:37+00:00
# 147  2016-10-04 04:12:37+00:00
# 148  2016-10-04 03:47:36+00:00
# 149  2016-10-04 03:37:58+00:00
# 150  2016-10-04 03:07:37+00:00
# 151  2016-10-04 03:07:37+00:00
# 152  2016-10-04 02:47:49+00:00
# 153  2016-10-04 02:47:47+00:00
# 154  2016-10-04 02:02:36+00:00
# 155  2016-10-04 01:57:47+00:00
# 156  2016-10-04 01:57:47+00:00
# 157  2016-10-04 01:52:49+00:00
# 158  2016-10-04 01:52:48+00:00
# 159  2016-10-04 01:52:48+00:00
# 160  2016-10-04 01:22:37+00:00
# 161  2016-10-04 01:17:37+00:00
# 162  2016-10-04 01:12:37+00:00
# 163  2016-10-04 01:12:36+00:00
# 164  2016-10-04 01:12:36+00:00
# 165  2016-10-04 01:07:47+00:00
# 166  2016-10-04 00:07:47+00:00
#
#                                                   text      type  \
# 0    new  crash in duval on i-95 south before 8th s...  official
# 1    update  traffic congestion in duval on i-95 so...  official
# 2    update  traffic congestion in duval on i-295 w...  official
# 3    update  traffic congestion in duval on i-295 e...  official
# 4    update  traffic congestion in duval on i-95 no...  official
# 5    new  traffic congestion in duval on i-95 south...  official
# 6    update  traffic congestion in duval on i-295 w...  official
# 7    update  disabled vehicle in duval on i-95 nort...  official
# 8    update  traffic congestion in duval on sr-202 ...  official
# 9    update  traffic congestion in duval on i-10 we...  official
# 10   update  traffic congestion in duval on i-295 e...  official
# 11   new  disabled vehicle in duval on i-95 north a...  official
# 12   update  traffic congestion in duval on i-295 w...  official
# 13   new  disabled vehicle in duval on i-95 south b...  official
# 14   update  unconfirmed disabled vehicle in duval ...  official
# 15   update  traffic congestion in duval on i-95 no...  official
# 16   update  disabled vehicle in duval on i-295 w s...  official
# 17   new  unconfirmed disabled vehicle in duval on ...  official
# 18   update  disabled vehicle in duval on i-295 e s...  official
# 19   update  traffic congestion in duval on i-10 we...  official
# 20   new  traffic congestion in duval on i-295 w so...  official
# 21   new  disabled vehicle in duval on i-95 north a...  official
# 22   update  traffic congestion in duval on sr-202 ...  official
# 23   new  traffic congestion in duval on i-295 w so...  official
# 24   new  disabled vehicle in duval on i-295 w sout...  official
# 25   new  traffic congestion in duval on sr-202   b...  official
# 26   new  crash in duval on i-295 e south at dames ...  official
# 27   new  crash in duval on i-10 west before lane a...  official
# 28   new  traffic congestion in duval on i-10 west ...  official
# 29   update  traffic congestion in duval on sr-202 ...  official
# ..                                                 ...       ...
# 137  new  traffic congestion in duval on i-10 east ...  official
# 138  new  traffic congestion in duval on i-295 w so...  official
# 139  new  disabled vehicle in duval on i-295 w sout...  official
# 140  update  planned construction in columbia on i-...  official
# 141  update  planned construction in duval on sr-20...  official
# 142  update  planned construction in duval on i-95 ...  official
# 143  update  planned construction in duval on i-95 ...  official
# 144  new  planned construction in duval on i-295 w ...  official
# 145  update  planned construction in duval on i-295...  official
# 146  update  planned construction in duval on sr-20...  official
# 147  jacksonville  butler blvd sr-202 is closed in ...  official
# 148  new  planned construction in duval on sr-202  ...  official
# 149  update  planned construction in alachua on i-7...  official
# 150  new  planned construction in duval on i-295 e ...  official
# 151  new  planned construction in duval on i-295 e ...  official
# 152  new  planned construction in alachua on i-75 n...  official
# 153  update  planned construction in alachua on i-7...  official
# 154  update  planned construction in duval on i-95 ...  official
# 155  new  planned construction in duval on i-95 nor...  official
# 156  update  crash in duval on i-295 e north at dam...  official
# 157  new  planned construction in duval on i-295 w ...  official
# 158  new  planned construction in duval on i-295 w ...  official
# 159  new  planned construction in duval on i-295 w ...  official
# 160  new  crash in duval on i-295 e north at dames ...  official
# 161  new  planned construction in alachua on i-75 s...  official
# 162  new  planned construction in duval on i-95 sou...  official
# 163  update  planned construction in duval on sr-20...  official
# 164  update  planned construction in duval on i-95 ...  official
# 165  new  planned construction in duval on sr-202  ...  official
# 166  new  planned construction in duval on i-95 nor...  official
#
#             username                                              tweet  \
# 0    fl511_northeast  NEW  Crash in Duval on I-95 south before 8th S...
# 1    fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 so...
# 2    fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 W...
# 3    fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 E...
# 4    fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 no...
# 5    fl511_northeast  NEW  Traffic congestion in Duval on I-95 south...
# 6    fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 W...
# 7    fl511_northeast  UPDATE  Disabled vehicle in Duval on I-95 nort...
# 8    fl511_northeast  UPDATE  Traffic congestion in Duval on SR-202 ...
# 9    fl511_northeast  UPDATE  Traffic congestion in Duval on I-10 we...
# 10   fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 E...
# 11   fl511_northeast  NEW  Disabled vehicle in Duval on I-95 north a...
# 12   fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 W...
# 13   fl511_northeast  NEW  Disabled vehicle in Duval on I-95 south b...
# 14   fl511_northeast  UPDATE  Unconfirmed disabled vehicle in Duval ...
# 15   fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 no...
# 16   fl511_northeast  UPDATE  Disabled vehicle in Duval on I-295 W s...
# 17   fl511_northeast  NEW  Unconfirmed disabled vehicle in Duval on ...
# 18   fl511_northeast  UPDATE  Disabled vehicle in Duval on I-295 E s...
# 19   fl511_northeast  UPDATE  Traffic congestion in Duval on I-10 we...
# 20   fl511_northeast  NEW  Traffic congestion in Duval on I-295 W so...
# 21   fl511_northeast  NEW  Disabled vehicle in Duval on I-95 north a...
# 22   fl511_northeast  UPDATE  Traffic congestion in Duval on SR-202 ...
# 23   fl511_northeast  NEW  Traffic congestion in Duval on I-295 W so...
# 24   fl511_northeast  NEW  Disabled vehicle in Duval on I-295 W sout...
# 25   fl511_northeast  NEW  Traffic congestion in Duval on SR-202   B...
# 26   fl511_northeast  NEW  Crash in Duval on I-295 E south at Dames ...
# 27   fl511_northeast  NEW  Crash in Duval on I-10 west before Lane A...
# 28   fl511_northeast  NEW  Traffic congestion in Duval on I-10 west ...
# 29   fl511_northeast  UPDATE  Traffic congestion in Duval on SR-202 ...
# ..               ...                                                ...
# 137  fl511_northeast  NEW  Traffic congestion in Duval on I-10 east ...
# 138  fl511_northeast  NEW  Traffic congestion in Duval on I-295 W so...
# 139  fl511_northeast  NEW  Disabled vehicle in Duval on I-295 W sout...
# 140  fl511_northeast  UPDATE  Planned construction in Columbia on I-...
# 141  fl511_northeast  UPDATE  Planned construction in Duval on SR-20...
# 142  fl511_northeast  UPDATE  Planned construction in Duval on I-95 ...
# 143  fl511_northeast  UPDATE  Planned construction in Duval on I-95 ...
# 144  fl511_northeast  NEW  Planned construction in Duval on I-295 W ...
# 145  fl511_northeast  UPDATE  Planned construction in Duval on I-295...
# 146  fl511_northeast  UPDATE  Planned construction in Duval on SR-20...
# 147  fl511_northeast  JACKSONVILLE  BUTLER BLVD SR-202 IS CLOSED IN ...
# 148  fl511_northeast  NEW  Planned construction in Duval on SR-202  ...
# 149  fl511_northeast  UPDATE  Planned construction in Alachua on I-7...
# 150  fl511_northeast  NEW  Planned construction in Duval on I-295 E ...
# 151  fl511_northeast  NEW  Planned construction in Duval on I-295 E ...
# 152  fl511_northeast  NEW  Planned construction in Alachua on I-75 n...
# 153  fl511_northeast  UPDATE  Planned construction in Alachua on I-7...
# 154  fl511_northeast  UPDATE  Planned construction in Duval on I-95 ...
# 155  fl511_northeast  NEW  Planned construction in Duval on I-95 nor...
# 156  fl511_northeast  UPDATE  Crash in Duval on I-295 E north at Dam...
# 157  fl511_northeast  NEW  Planned construction in Duval on I-295 W ...
# 158  fl511_northeast  NEW  Planned construction in Duval on I-295 W ...
# 159  fl511_northeast  NEW  Planned construction in Duval on I-295 W ...
# 160  fl511_northeast  NEW  Crash in Duval on I-295 E north at Dames ...
# 161  fl511_northeast  NEW  Planned construction in Alachua on I-75 s...
# 162  fl511_northeast  NEW  Planned construction in Duval on I-95 sou...
# 163  fl511_northeast  UPDATE  Planned construction in Duval on SR-20...
# 164  fl511_northeast  UPDATE  Planned construction in Duval on I-95 ...
# 165  fl511_northeast  NEW  Planned construction in Duval on SR-202  ...
# 166  fl511_northeast  NEW  Planned construction in Duval on I-95 nor...
#
#        state  road_closure                                      modified_text  \
# 0    Florida             1  At New  Crash At Duval At Interstate 95 South ...
# 1    Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 2    Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 3    Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 4    Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 5    Florida             1  At New  Traffic Congestion At Duval At Interst...
# 6    Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 7    Florida             1  At Update  Disabled Vehicle At Duval At Inters...
# 8    Florida             1  At Update  Traffic Congestion At Duval At Sr-2...
# 9    Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 10   Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 11   Florida             1  At New  Disabled Vehicle At Duval At Interstat...
# 12   Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 13   Florida             1  At New  Disabled Vehicle At Duval At Interstat...
# 14   Florida             1  At Update  Unconfirmed Disabled Vehicle At Duv...
# 15   Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 16   Florida             1  At Update  Disabled Vehicle At Duval At Inters...
# 17   Florida             1  At New  Unconfirmed Disabled Vehicle At Duval ...
# 18   Florida             1  At Update  Disabled Vehicle At Duval At Inters...
# 19   Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 20   Florida             1  At New  Traffic Congestion At Duval At Interst...
# 21   Florida             1  At New  Disabled Vehicle At Duval At Interstat...
# 22   Florida             1  At Update  Traffic Congestion At Duval At Sr-2...
# 23   Florida             1  At New  Traffic Congestion At Duval At Interst...
# 24   Florida             1  At New  Disabled Vehicle At Duval At Interstat...
# 25   Florida             1  At New  Traffic Congestion At Duval At Sr-202 ...
# 26   Florida             1  At New  Crash At Duval At Interstate 295 East ...
# 27   Florida             1  At New  Crash At Duval At Interstate 10 West B...
# 28   Florida             1  At New  Traffic Congestion At Duval At Interst...
# 29   Florida             1  At Update  Traffic Congestion At Duval At Sr-2...
# ..       ...           ...                                                ...
# 137  Florida             1  At New  Traffic Congestion At Duval At Interst...
# 138  Florida             1  At New  Traffic Congestion At Duval At Interst...
# 139  Florida             1  At New  Disabled Vehicle At Duval At Interstat...
# 140  Florida             1  At Update  Planned Construction At Columbia At...
# 141  Florida             1  At Update  Planned Construction At Duval At Sr...
# 142  Florida             1  At Update  Planned Construction At Duval At In...
# 143  Florida             1  At Update  Planned Construction At Duval At In...
# 144  Florida             1  At New  Planned Construction At Duval At Inter...
# 145  Florida             1  At Update  Planned Construction At Duval At In...
# 146  Florida             1  At Update  Planned Construction At Duval At Sr...
# 147  Florida             1  At Jacksonville  Butler Blvd Sr-202 Is Closed ...
# 148  Florida             1  At New  Planned Construction At Duval At Sr-20...
# 149  Florida             1  At Update  Planned Construction At Alachua At ...
# 150  Florida             1  At New  Planned Construction At Duval At Inter...
# 151  Florida             1  At New  Planned Construction At Duval At Inter...
# 152  Florida             1  At New  Planned Construction At Alachua At Int...
# 153  Florida             1  At Update  Planned Construction At Alachua At ...
# 154  Florida             1  At Update  Planned Construction At Duval At In...
# 155  Florida             1  At New  Planned Construction At Duval At Inter...
# 156  Florida             1  At Update  Crash At Duval At Interstate 295 Ea...
# 157  Florida             1  At New  Planned Construction At Duval At Inter...
# 158  Florida             1  At New  Planned Construction At Duval At Inter...
# 159  Florida             1  At New  Planned Construction At Duval At Inter...
# 160  Florida             1  At New  Crash At Duval At Interstate 295 East ...
# 161  Florida             1  At New  Planned Construction At Alachua At Int...
# 162  Florida             1  At New  Planned Construction At Duval At Inter...
# 163  Florida             1  At Update  Planned Construction At Duval At Sr...
# 164  Florida             1  At Update  Planned Construction At Duval At In...
# 165  Florida             1  At New  Planned Construction At Duval At Sr-20...
# 166  Florida             1  At New  Planned Construction At Duval At Inter...
#
#                                               location      interstate  \
# 0       {'Interstate 95 South', 'New  Crash At Duval'}   Interstate 95
# 1    {'Interstate 95 South From Exit 337 Interstate...   Interstate 95
# 2    {'Interstate 10', 'Exit 21', 'Normandy Blvd', ...  Interstate 295
# 3    {'Exit 56', 'Exit 53', 'Interstate 295 East So...  Interstate 295
# 4    {'Interstate 10', 'Interstate 95 North From Ex...   Interstate 95
# 5    {'Interstate 95 South From Exit 337 Interstate...   Interstate 95
# 6    {'Wilson Blvd', 'Exit 25', 'Interstate 295 Wes...  Interstate 295
# 7                    {'Warren', 'Interstate 95 North'}   Interstate 95
# 8          {'Kernan Blvd', 'Blvd East From Southside'}            None
# 9    {'Exit 357 Lane Ave', 'Interstate 10 West From...   Interstate 10
# 10   {'Exit 56', 'Exit 53', 'Interstate 295 East So...  Interstate 295
# 11                             {'Interstate 95 North'}   Interstate 95
# 12   {'Pritchard Rd', 'Exit 22 Commonwealth', 'Exit...  Interstate 295
# 13               {'Interstate 95 South Before Butler'}   Interstate 95
# 14            {'Interstate 295 East South', 'Exit 47'}  Interstate 295
# 15   {'Interstate 95 North From Exit 346 University...   Interstate 95
# 16           {'San Jose', 'Interstate 295 West South'}  Interstate 295
# 17            {'Interstate 295 East South', 'Exit 47'}  Interstate 295
# 18        {'Interstate 295 East South', 'Dames Point'}  Interstate 295
# 19   {'Exit 358', 'Interstate 10 West From Exit 363...   Interstate 10
# 20    {'Exit 5 San Jose', 'Interstate 295 West South'}  Interstate 295
# 21          {'Interstate 95 North At Exit 344 Butler'}   Interstate 95
# 22       {'Interstate 95', 'Blvd West From Southside'}   Interstate 95
# 23   {'Pritchard Rd', 'Exit 22 Commonwealth', 'Exit...  Interstate 295
# 24           {'San Jose', 'Interstate 295 West South'}  Interstate 295
# 25         {'Kernan Blvd', 'Blvd East From Southside'}            None
# 26   {'Dames Point', 'Interstate 295 East South', '...  Interstate 295
# 27   {'Interstate 10 West', 'Before Lane Ave', 'New...   Interstate 10
# 28   {'Exit 358', 'Interstate 10 West From Exit 363...   Interstate 10
# 29        {'Blvd West', 'Interstate 95', 'Belfort Rd'}   Interstate 95
# ..                                                 ...             ...
# 137   {'Exit 358', 'Interstate 10 East From Exit 357'}   Interstate 10
# 138  {'Exit 61', 'Exit 3', 'Interstate 95', 'Inters...  Interstate 295
# 139          {'San Jose', 'Interstate 295 West South'}  Interstate 295
# 140                  {'Mm 429', 'Interstate 75 North'}   Interstate 75
# 141                     {'Blvd East', 'Interstate 95'}  Interstate 95,
# 142                       {'Interstate 95 South Ramp'}   Interstate 95
# 143                     {'Interstate', 'North Beyond'}   Interstate 95
# 144      {'Interstate 295 West North Ramp To Exit 22'}  Interstate 295
# 145                       {'Interstate', 'West North'}  Interstate 295
# 146                        {'Blvd West', 'Belfort Rd'}            None
# 147  {'Jacksonville', 'Butler Blvd', 'Interstate 95...   Interstate 95
# 148                     {'Blvd East', 'Interstate 95'}  Interstate 95,
# 149                     {'Interstate 75 North Before'}   Interstate 75
# 150                      {'Interstate 295 East North'}  Interstate 295
# 151           {'Exit 56', 'Interstate 295 East South'}  Interstate 295
# 152                     {'Interstate 75 North Before'}   Interstate 75
# 153                {'Interstate 75 South', 'Exit 384'}   Interstate 75
# 154                     {'Interstate', 'North Beyond'}   Interstate 95
# 155             {'Interstate', 'North Beyond Emerson'}   Interstate 95
# 156                                     {'Interstate'}  Interstate 295
# 157      {'Interstate 295 West South Ramp To Exit 22'}  Interstate 295
# 158  {'Interstate 295 West South Before Commonwealt...  Interstate 295
# 159  {'Interstate 295 West North Before Commonwealth'}  Interstate 295
# 160              {'Interstate', 'New  Crash At Duval'}  Interstate 295
# 161                {'Interstate 75 South', 'Exit 384'}   Interstate 75
# 162    {'Interstate 95 South Ramp To Exit 344 Butler'}   Interstate 95
# 163     {'Belfort Rd, Left Lane Blocked', 'Blvd West'}            None
# 164                     {'Interstate', 'North Beyond'}   Interstate 95
# 165     {'Belfort Rd, Left Lane Blocked', 'Blvd West'}            None
# 166                     {'Interstate', 'North Beyond'}   Interstate 95
#
#         exits       lat      long
# 0        None       NaN       NaN
# 1    Exit 337  30.15859 -81.55057
# 2     Exit 21  30.31098 -81.76966
# 3     Exit 53    30.257 -81.51787
# 4    Exit 344  30.24393 -81.58858
# 5    Exit 337  30.15859 -81.55057
# 6     Exit 25  30.36906 -81.76069
# 7        None       NaN       NaN
# 8        None       NaN       NaN
# 9    Exit 363       NaN       NaN
# 10    Exit 53    30.257 -81.51787
# 11       None       NaN       NaN
# 12    Exit 25  30.36906 -81.76069
# 13       None       NaN       NaN
# 14    Exit 47  30.34267 -81.54430
# 15   Exit 346  30.27203 -81.61395
# 16       None       NaN       NaN
# 17    Exit 47  30.34267 -81.54430
# 18       None       NaN       NaN
# 19   Exit 363       NaN       NaN
# 20     Exit 5  30.17924 -81.62420
# 21   Exit 344  30.24393 -81.58858
# 22       None       NaN       NaN
# 23    Exit 25  30.36906 -81.76069
# 24       None       NaN       NaN
# 25       None       NaN       NaN
# 26       None       NaN       NaN
# 27       None       NaN       NaN
# 28   Exit 363       NaN       NaN
# 29       None       NaN       NaN
# ..        ...       ...       ...
# 137  Exit 357   30.3155 -81.75616
# 138    Exit 3  30.16897 -81.59703
# 139      None       NaN       NaN
# 140      None       NaN       NaN
# 141      None       NaN       NaN
# 142  Exit 344  30.24393 -81.58858
# 143      None       NaN       NaN
# 144   Exit 22  30.33213 -81.76245
# 145      None       NaN       NaN
# 146      None       NaN       NaN
# 147      None       NaN       NaN
# 148      None       NaN       NaN
# 149      None       NaN       NaN
# 150      None       NaN       NaN
# 151   Exit 56  30.21982 -81.51444
# 152      None       NaN       NaN
# 153  Exit 384       NaN       NaN
# 154      None       NaN       NaN
# 155      None       NaN       NaN
# 156      None       NaN       NaN
# 157   Exit 22  30.33213 -81.76245
# 158      None       NaN       NaN
# 159      None       NaN       NaN
# 160      None       NaN       NaN
# 161  Exit 384       NaN       NaN
# 162  Exit 344  30.24393 -81.58858
# 163      None       NaN       NaN
# 164      None       NaN       NaN
# 165      None       NaN       NaN
# 166      None       NaN       NaN
#
# [167 rows x 13 columns]

# %%
final_df.to_csv("../data/Loc_Extracted/tweet_locations_sample_07302019.csv", index = False)
