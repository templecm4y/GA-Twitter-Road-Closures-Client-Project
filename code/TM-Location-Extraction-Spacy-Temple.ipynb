# %% [markdown]
# # Location Extraction and Spacy Word Vectorization

# %%
import pandas as pd
import numpy as np
import re
import spacy
import string
import datetime

# %%
# Read in csv with Tweets
twitter_closures = pd.read_csv("../data/Cleaned_Tweets/cleaned_historic_official_07292019.csv")
exits = pd.read_csv("../data/interstate_exits.csv")

twitter_closures = twitter_closures[['date', 'text', 'type', 'username', 'tweet', 'road_closure']]

# Print DF shape
print(twitter_closures.shape)

# Show head 
twitter_closures.head()
# Out:
# (24054, 6)
#                         date  \
# 0  2016-10-11 16:39:51+00:00
# 1  2016-10-10 19:10:23+00:00
# 2  2016-10-09 17:30:22+00:00
# 3  2016-10-09 15:45:11+00:00
# 4  2016-10-09 14:00:20+00:00
#
#                                                 text      type username  \
# 0  The PIOH for the SR 138 I-20 is going on now u...  official  GDOTATL
# 1  We appreciate all the hard work our crews have...  official  GDOTATL
# 2  Need info on re-entry  Check here  Also follow...  official  GDOTATL
# 3  Do you need some updates  You can find ALL of ...  official  GDOTATL
# 4  Did you know that the  511Georgia website and ...  official  GDOTATL
#
#                                                tweet  road_closure
# 0  The PIOH for the SR 138 I-20 is going on now u...             0
# 1  We appreciate all the hard work our crews have...             0
# 2  Need info on re-entry  Check here  Also follow...             0
# 3  Do you need some updates  You can find ALL of ...             0
# 4  Did you know that the  511Georgia website and ...             0

# %% [markdown]
# ## SpaCy Preprocessing

# %%
# Create new columns to transfer modified tweet text. Five versions of tweets will be created.
twitter_closures['modified_text'] = ''
twitter_closures['location'] = ''

# Show modified DF
twitter_closures.head(2)
# Out:
#                         date  \
# 0  2016-10-11 16:39:51+00:00
# 1  2016-10-10 19:10:23+00:00
#
#                                                 text      type username  \
# 0  The PIOH for the SR 138 I-20 is going on now u...  official  GDOTATL
# 1  We appreciate all the hard work our crews have...  official  GDOTATL
#
#                                                tweet  road_closure  \
# 0  The PIOH for the SR 138 I-20 is going on now u...             0
# 1  We appreciate all the hard work our crews have...             0
#
#   modified_text location
# 0
# 1

# %%
format_dict = {"hwy": "Highway ",
            "Blvd": "Boulevard",
            " st": "street",
           "CR ": "Country Road ",
           "SR ": "State Road",
           "I-": "Interstate ",
           "EB ": "Eastbound ",
           "WB ": "Westbound ",
           "SB ": "Southbound",
           "NB ": "Northbound",
           " on ": " at ",
           " E ": " East ",
           " W ": " West ",
           " S ": " South",
           " N ": " North",
           "mi ": "mile ",
           "between ": "at ",
           "Between ": "at ",
           "In ": "in ",
           " in ": " at "}

# %%
def spacy_cleaner(df, col, word_dict):
    modified_text = "At " + df[col].replace(word_dict, regex=True)
    modified_text = modified_text.str.title()
    return modified_text

# %%
# run the text cleaning function and test results
twitter_closures['modified_text'] = spacy_cleaner(twitter_closures, 'text', format_dict)

# %%
twitter_closures['username'].unique()
# Out:
# array(['GDOTATL', 'SCDOTMidlands', 'SCDOTPeeDee', 'SCDOTLowCountry',
#        'SCDOTPiedmont', '511statewideva', 'fl511_panhandl', '511Georgia',
#        'fl511_state', 'fl511_northeast', 'fl511_southeast',
#        'fl511_southwest', 'fl511_tampabay', 'fl511_central',
#        '511centralva', '511hamptonroads', '511northernva',
#        'NCDOT_Westmtn', 'NCDOT_Triangle', 'NCDOT_Piedmont',
#        'NCDOT_Charlotte', 'NCDOT_Asheville', 'NCDOT_Scoast',
#        'NCDOT_Ncoast'], dtype=object)

# %%
twitter_closures['date'] = pd.to_datetime(twitter_closures['date'])

# %%
test_df = twitter_closures[(twitter_closures['road_closure'] == 1) & (twitter_closures['username'] == 'fl511_northeast')].head(100)

# %%
def get_loc(df, text_column, location_column):
    
    # Use Spacy to extract location names from `text` column
    for i in range(len(df)):
        
        #instantiate spacy model
        nlp = spacy.load("en_core_web_sm")
        
        # create documewnt from modified text column
        doc = nlp(df[text_column].iloc[i])
        
        locations = set()
        
        # loop through every entity in the doc
        for ent in doc.ents:
            
            # find entities labelled as places
            if (ent.label_=='GPE') or (ent.label_=='FAC') or (ent.label_ == 'LOC'):
                
                # put locations in a set
                locations.add(ent.text)
                df[location_column].iloc[i] = locations
                
    return df[location_column]

# %%
test = get_loc(test_df, 'modified_text', 'location')
# Out:
# /Users/templemoore/anaconda3/envs/dsi/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
test_df['location'] = test
test_df.head()
# Out:
#                           date  \
# 8976 2016-10-13 23:33:35+00:00
# 8977 2016-10-13 23:08:56+00:00
# 8978 2016-10-13 23:03:56+00:00
# 8979 2016-10-13 23:03:34+00:00
# 8980 2016-10-13 22:53:49+00:00
#
#                                                    text      type  \
# 8976  CLEARED  Traffic congestion in Duval on I-295 ...  official
# 8977  CLEARED  Traffic congestion in Duval on I-295 ...  official
# 8978  UPDATE  Disabled vehicle in Duval on I-95 sout...  official
# 8979  CLEARED  Traffic congestion in Duval on I-295 ...  official
# 8980  CLEARED  Disabled vehicle in Duval on I-95 nor...  official
#
#              username                                              tweet  \
# 8976  fl511_northeast  CLEARED  Traffic congestion in Duval on I-295 ...
# 8977  fl511_northeast  CLEARED  Traffic congestion in Duval on I-295 ...
# 8978  fl511_northeast  UPDATE  Disabled vehicle in Duval on I-95 sout...
# 8979  fl511_northeast  CLEARED  Traffic congestion in Duval on I-295 ...
# 8980  fl511_northeast  CLEARED  Disabled vehicle in Duval on I-95 nor...
#
#       road_closure                                      modified_text  \
# 8976             1  At Cleared  Traffic Congestion At Duval At Int...
# 8977             1  At Cleared  Traffic Congestion At Duval At Int...
# 8978             1  At Update  Disabled Vehicle At Duval At Inters...
# 8979             1  At Cleared  Traffic Congestion At Duval At Int...
# 8980             1  At Cleared  Disabled Vehicle At Duval At Inter...
#
#                                                location
# 8976  {Exit 5 San Jose, Interstate 295 West North, E...
# 8977               {Interstate 295 East South, Exit 53}
# 8978    {Interstate 95 South Ramp From Exit 344 Butler}
# 8979               {Interstate 295 East North, Exit 56}
# 8980      {Interstate 95 North Ramp To Exit 353B Union}

# %%
test_df.to_csv("../data/Loc_Extracted/tweet_locations_sample_07302019.csv", index = False)

# %%
test_df = pd.read_csv("../data/Loc_Extracted/tweet_locations_sample_07302019.csv")

# %%
def exit_extractor (df, col, i_df):
    
    exits = []
    interstates = []
    lat = []
    long = []
    direction = []
    
    for item in df[col]:
        if 'Interstate' in item:
            
            i_string = re.search(r'Interstate (\S+)', item)
            interstates.append(i_string.group(0))
            
            if 'Exit' in item:
                e_string = re.search(r'Exit (\S+)', item)
                exits.append(e_string.group(0))
            else:
                exits.append("None")
        else:
            interstates.append("None")
            exits.append("None")
    
    new_df = pd.DataFrame(data = interstates, columns = ['interstate'])
    new_df['exits'] = exits
    
    for index, row in new_df.iterrows():
        
        if (row['interstate'] != "None") and (row['exits'] != "None"):
            
            mask = (i_df['interstate'].str.contains(row['interstate'])) & (i_df['exits'].str.contains(row['exits']))
            
            try:
                print(i_df[mask]['exits'].iloc[0] + ' ' + i_df[mask]['interstate'].iloc[0] + ' ' + i_df[mask]['dir'].iloc[0])
                
                lat.append(i_df[mask].iloc[0]['lat'])
                long.append(i_df[mask].iloc[0]['long'])
                
            except:
                print(f"No exit found at {index}")
                
                lat.append(np.nan)
                long.append(np.nan)

        else:
            print("No exit found")
            lat.append(np.nan)
            long.append(np.nan)
            
    
    new_df['lat'] = lat
    new_df['long'] = long
    
    return new_df

# %%
exits[(exits['interstate'] == 'Interstate 295') & (exits['exits'] == "Exit 12")].iloc[0]['lat']
# Out:
# '30.19137'

# %%
e_df = exit_extractor(test_df, 'modified_text', exits)
# Out:
# Exit 3 Interstate 295 S
# Exit 53 Interstate 295 S
# Exit 344 Interstate 95 N
# Exit 56 Interstate 295 S
# Exit 353B Interstate 95 N
# Exit 347 Interstate 95 N
# Exit 56 Interstate 295 S
# No exit found
# No exit found
# No exit found
# Exit 344 Interstate 95 N
# No exit found
# Exit 3 Interstate 295 S
# Exit 53 Interstate 295 S
# Exit 353B Interstate 95 N
# Exit 12 Interstate 295 N
# No exit found
# Exit 355 Interstate 95 N
# Exit 347 Interstate 95 N
# Exit 344 Interstate 95 N
# Exit 337 Interstate 95 N
# Exit 12 Interstate 295 N
# No exit found
# Exit 53 Interstate 295 S
# Exit 346A Interstate 95 S
# Exit 25 Interstate 295 N
# Exit 337 Interstate 95 N
# No exit found
# Exit 52 Interstate 295 S
# No exit found
# Exit 52 Interstate 295 S
# No exit found
# No exit found
# No exit found
# Exit 360 Interstate 10 E
# No exit found
# Exit 25 Interstate 295 N
# Exit 53 Interstate 295 S
# Exit 25 Interstate 295 N
# No exit found
# Exit 337 Interstate 95 N
# Exit 53 Interstate 295 S
# No exit found
# Exit 337 Interstate 95 N
# No exit found
# No exit found
# No exit found
# Exit 53 Interstate 295 S
# No exit found
# Exit 360 Interstate 95 N
# No exit found
# Exit 360 Interstate 10 E
# Exit 61B Interstate 295 S
# No exit found
# Exit 360 Interstate 95 N
# Exit 360 Interstate 10 E
# Exit 355 Interstate 95 N
# Exit 61B Interstate 295 S
# Exit 3 Interstate 295 S
# Exit 3 Interstate 295 S
# No exit found
# No exit found at 61
# Exit 58 Interstate 295 S
# Exit 346A Interstate 95 S
# Exit 3 Interstate 295 S
# Exit 356A Interstate 95 N
# Exit 51 Interstate 295 S
# Exit 344 Interstate 95 N
# No exit found
# Exit 354A Interstate 95 N
# No exit found at 70
# Exit 350B Interstate 95 S
# Exit 52 Interstate 295 S
# Exit 58 Interstate 295 S
# No exit found
# Exit 53 Interstate 295 S
# Exit 337 Interstate 95 N
# Exit 346A Interstate 95 S
# Exit 345 Interstate 95 N
# Exit 355 Interstate 95 N
# Exit 350B Interstate 95 S
# Exit 344 Interstate 95 N
# Exit 347 Interstate 95 N
# No exit found
# Exit 53 Interstate 295 S
# Exit 355 Interstate 95 N
# Exit 346A Interstate 95 S
# No exit found
# Exit 346A Interstate 95 S
# No exit found
# Exit 354A Interstate 95 N
# Exit 353A Interstate 95 S
# Exit 3 Interstate 295 S
# No exit found
# Exit 3 Interstate 295 S
# No exit found
# No exit found
# Exit 354A Interstate 95 N
# No exit found
# Exit 354A Interstate 95 N
# 68

# %%
e_df.shape
# Out:
# (100, 4)

# %%
exits[(exits['interstate'] == 'Interstate 95') & (exits['exits'] == 'Exit 348')]
# Out:
#      Unnamed: 0 exit              crossSt dir       lat      long  \
# 252         252  348  US-90 Atlantic Blvd   N  30.30263 -81.64124
#
#         interstate     exits
# 252  Interstate 95  Exit 348

# %%
for item in exit_df.iterrows():
    if item[1]['exits'] != "None":
        print(item[1]['exits'])
# Out:
# Exit 3
# Exit 53
# Exit 344
# Exit 56
# Exit 353B
# Exit 347
# Exit 56
# Exit 344
# Exit 3
# Exit 53
# Exit 353B
# Exit 12
# Exit 355
# Exit 347
# Exit 344
# Exit 337
# Exit 12
# Exit 53
# Exit 346
# Exit 25
# Exit 337
# Exit 52
# Exit 52
# Exit 360
# Exit 25
# Exit 53
# Exit 25
# Exit 337
# Exit 53
# Exit 337
# Exit 53
# Exit 360
# Exit 360
# Exit 61
# Exit 360
# Exit 360
# Exit 355
# Exit 61
# Exit 3
# Exit 3
# Exit 349
# Exit 58
# Exit 346
# Exit 3
# Exit 356
# Exit 51
# Exit 344
# Exit 354
# Exit 349
# Exit 350
# Exit 52
# Exit 58
# Exit 53
# Exit 337
# Exit 346
# Exit 345
# Exit 355
# Exit 350
# Exit 344
# Exit 347
# Exit 53
# Exit 355
# Exit 346
# Exit 346
# Exit 354
# Exit 353
# Exit 3
# Exit 3
# Exit 354
# Exit 354

# %%
exits
# Out:
#      Unnamed: 0 exit                                        crossSt dir  \
# 0             0   1A                                            NaN   S
# 1             1   1B                                            NaN   N
# 2             2   1B                                            NaN   S
# 3             3   2A                                            NaN   N
# 4             4   2B                                            NaN   N
# 5             5   2C                                            NaN   S
# 6             6   2D                                            NaN   N
# 7             7   3A                                            NaN   S
# 8             8   3B                                            NaN   S
# 9             9   2D                                            NaN   S
# 10           10   4A                                            NaN   N
# 11           11   4B                                            NaN   N
# 12           12    4                                            NaN   S
# 13           13   6A                                            NaN   N
# 14           14   6A                                            NaN   S
# 15           15   6B                                            NaN   S
# 16           16    7                                            NaN   N
# 17           17    7                                            NaN   S
# 18           18   8A                                            NaN   N
# 19           19   8A                                            NaN   S
# 20           20   8B                                            NaN   N
# 21           21   8B                                            NaN   S
# 22           22    9                                            NaN   N
# 23           23  10A                                            NaN   N
# 24           24  10A                                            NaN   S
# 25           25  10B                                            NaN   N
# 26           26  10B                                            NaN   S
# 27           27   11                                            NaN   N
# 28           28  12A                                            NaN   N
# 29           29  12B                                            NaN   N
# ..          ...  ...                                            ...  ..
# 456          94  324                            US 90 Tiger Lake Rd   E
# 457          95  324                                          US 90   W
# 458          96  327                           CR 229 Reid Stafford   E
# 459          97  327                           CR 229 Reid Stafford   W
# 460          98  333                            CR 125 Nursery Blvd   E
# 461          99  333                            CR 125 Nursery Blvd   W
# 462         100  335                                SR 121 S 6th St   E
# 463         101  335                                SR 121 S 6th St   W
# 464         102  336                                         SR 228   E
# 465         103  336                                         SR 228   W
# 466         104  343                                         US 301   E
# 467         105  343                                         US 301   W
# 468         106  350  SR 23 Cecil Commerce Center Parkway Beaver St   E
# 469         107  350  SR 23 Cecil Commerce Center Parkway Beaver St   W
# 470         108  351                            SR 115-C Chaffee Rd   E
# 471         109  351                            SR 115-C Chaffee Rd   W
# 472         110  355                          Marietta Hammond Blvd   E
# 473         111  355                          Marietta Hammond Blvd   W
# 474         112  356                                          I-295   E
# 475         113  356                                          I-295   W
# 476         114  357                                SR 103 Lane Ave   E
# 477         115  357                                SR 103 Lane Ave   W
# 478         116  358                 SR 111 Cassat Ave Edgewood Ave   E
# 479         117  358                 SR 111 Cassat Ave Edgewood Ave   W
# 480         118  359                                 Luna St Waller   W
# 481         119  360                      SR 129 McDuff Ave Rayford   E
# 482         120  360                       SR 129 McDuff Ave Waller   W
# 483         121  361                           US 17 Roosevelt Blvd   W
# 484         122  362                                    Stockton St   E
# 485         123  362                                    Stockton St   W
#
#                     lat      long     interstate     exits
# 0              25.75506 -80.20200  Interstate 95   Exit 1A
# 1              25.76255 -80.19960  Interstate 95   Exit 1B
# 2              25.77588 -80.19986  Interstate 95   Exit 1B
# 3              25.77139 -80.19882  Interstate 95   Exit 2A
# 4              25.77339 -80.19866  Interstate 95   Exit 2B
# 5               25.7752 -80.19976  Interstate 95   Exit 2C
# 6              25.78082 -80.19989  Interstate 95   Exit 2D
# 7              25.79316 -80.20553  Interstate 95   Exit 3A
# 8               25.7877 -80.20368  Interstate 95   Exit 3B
# 9              25.79003 -80.20486  Interstate 95   Exit 2D
# 10             25.78963 -80.20405  Interstate 95   Exit 4A
# 11             25.80777 -80.20570  Interstate 95   Exit 4B
# 12             25.81704 -80.20641  Interstate 95    Exit 4
# 13             25.82871 -80.20609  Interstate 95   Exit 6A
# 14             25.83547 -80.20619  Interstate 95   Exit 6A
# 15             25.83865 -80.20627  Interstate 95   Exit 6B
# 16             25.84436 -80.20663  Interstate 95    Exit 7
# 17   25.852240000000002 -80.20815  Interstate 95    Exit 7
# 18             25.85877 -80.20804  Interstate 95   Exit 8A
# 19             25.86545 -80.20855  Interstate 95   Exit 8A
# 20             25.86639 -80.20825  Interstate 95   Exit 8B
# 21             25.87232 -80.20889  Interstate 95   Exit 8B
# 22             25.88015 -80.20895  Interstate 95    Exit 9
# 23             25.88579 -80.20895  Interstate 95  Exit 10A
# 24             25.89282 -80.20960  Interstate 95  Exit 10A
# 25             25.89504 -80.20939  Interstate 95  Exit 10B
# 26             25.90352 -80.21026  Interstate 95  Exit 10B
# 27             25.90923 -80.20979  Interstate 95   Exit 11
# 28             25.91485 -80.20998  Interstate 95  Exit 12A
# 29             25.91485 -80.20998  Interstate 95  Exit 12B
# ..                  ...       ...            ...       ...
# 456            30.23882 -82.30376  Interstate 10  Exit 324
# 457  30.236729999999998 -82.29935  Interstate 10  Exit 324
# 458  30.240090000000002 -82.25891  Interstate 10  Exit 327
# 459            30.24005 -82.26114  Interstate 10  Exit 327
# 460            30.26192 -82.16602  Interstate 10  Exit 333
# 461             30.2617 -82.15928  Interstate 10  Exit 333
# 462            30.25892 -82.12280  Interstate 10  Exit 335
# 463  30.259079999999997 -82.12305  Interstate 10  Exit 335
# 464            30.26128 -82.10818  Interstate 10  Exit 336
# 465  30.264909999999997 -82.10084  Interstate 10  Exit 336
# 466  30.288520000000002 -81.99057  Interstate 10  Exit 343
# 467            30.28933 -81.98345  Interstate 10  Exit 343
# 468            30.30534 -81.89183  Interstate 10  Exit 350
# 469            30.30797 -81.86741  Interstate 10  Exit 350
# 470            30.30915 -81.84853  Interstate 10  Exit 351
# 471            30.30933 -81.84856  Interstate 10  Exit 351
# 472  30.314759999999996 -81.79673  Interstate 10  Exit 355
# 473             30.3152 -81.78708  Interstate 10  Exit 355
# 474  30.315179999999998 -81.77517  Interstate 10  Exit 356
# 475            30.31585 -81.76204  Interstate 10  Exit 356
# 476             30.3155 -81.75616  Interstate 10  Exit 357
# 477            30.31602 -81.74865  Interstate 10  Exit 357
# 478            30.31721 -81.73408  Interstate 10  Exit 358
# 479  30.318620000000003 -81.72756  Interstate 10  Exit 358
# 480  30.320940000000004 -81.71658  Interstate 10  Exit 359
# 481  30.320859999999996 -81.70904  Interstate 10  Exit 360
# 482            30.32136 -81.70181  Interstate 10  Exit 360
# 483             30.3219 -81.69821  Interstate 10  Exit 361
# 484  30.320729999999998 -81.69256  Interstate 10  Exit 362
# 485            30.32145 -81.68432  Interstate 10  Exit 362
#
# [486 rows x 8 columns]

# %%
exits = exit_extractor(test_df, 'modified_text', i95)
final_df = pd.concat([test_df, exits], axis = 1)
final_df.head()
# Out:
#                         date  \
# 0  2016-11-29 23:59:23+00:00
# 1  2016-11-29 23:59:15+00:00
# 2  2016-11-29 23:54:26+00:00
# 3  2016-11-29 23:49:10+00:00
# 4  2016-11-29 23:49:10+00:00
#
#                                                                                                      text  \
# 0                            NEW  Crash in Duval on I-295 E north beyond Philips Hwy, right lane blocked
# 1  CLEARED  Traffic congestion in Duval on I-95 north from before Fuller Warren to ramp to Exit 351 I-10
# 2               CLEARED  Traffic congestion in Duval on I-295 W north from Exit 5 San Jose to at Buckman
# 3   UPDATE  Traffic congestion in Duval on I-95 north from before Fuller Warren to ramp to Exit 351 I-10
# 4     CLEARED  Traffic congestion in Duval on I-295 E south from Exit 53 Butler to at Exit 56 Baymeadows
#
#        type         username  \
# 0  official  fl511_northeast
# 1  official  fl511_northeast
# 2  official  fl511_northeast
# 3  official  fl511_northeast
# 4  official  fl511_northeast
#
#                                                                                                     tweet  \
# 0                            NEW  Crash in Duval on I-295 E north beyond Philips Hwy, right lane blocked
# 1  CLEARED  Traffic congestion in Duval on I-95 north from before Fuller Warren to ramp to Exit 351 I-10
# 2               CLEARED  Traffic congestion in Duval on I-295 W north from Exit 5 San Jose to at Buckman
# 3   UPDATE  Traffic congestion in Duval on I-95 north from before Fuller Warren to ramp to Exit 351 I-10
# 4     CLEARED  Traffic congestion in Duval on I-295 E south from Exit 53 Butler to at Exit 56 Baymeadows
#
#    road_closure  \
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
#
#                                                                                                                  modified_text  \
# 0                                  At New  Crash At Duval At Interstate 295 East North Beyond Philips Hwy, Right Lane Blocked
# 1  At Cleared  Traffic Congestion At Duval At Interstate 95 North From Before Fuller Warren To Ramp To Exit 351 Interstate 10
# 2                     At Cleared  Traffic Congestion At Duval At Interstate 295 West North From Exit 5 San Jose To At Buckman
# 3   At Update  Traffic Congestion At Duval At Interstate 95 North From Before Fuller Warren To Ramp To Exit 351 Interstate 10
# 4           At Cleared  Traffic Congestion At Duval At Interstate 295 East South From Exit 53 Butler To At Exit 56 Baymeadows
#
#                                                              location  \
# 0  {'Interstate 295 East North', 'New  Crash At Duval', 'Right Lane'}
# 1                            {'Interstate 10', 'Interstate 95 North'}
# 2                 {'Interstate 295 West North', 'San Jose', 'Exit 5'}
# 3                            {'Interstate 10', 'Interstate 95 North'}
# 4                 {'Exit 56', 'Exit 53', 'Interstate 295 East South'}
#
#        interstate     exits       lat      long
# 0  Interstate 295      None       NaN       NaN
# 1   Interstate 95  Exit 351  30.31568 -81.67278
# 2  Interstate 295    Exit 5       NaN       NaN
# 3   Interstate 95  Exit 351  30.31568 -81.67278
# 4  Interstate 295   Exit 53       NaN       NaN

# %%
i95.head()
# Out:
#   exit crossSt dir       lat      long     interstate    exits
# 0   1A     NaN   S  25.75506 -80.20200  Interstate 95  Exit 1A
# 1   1B     NaN   N  25.76255 -80.19960  Interstate 95  Exit 1B
# 2   1B     NaN   S  25.77588 -80.19986  Interstate 95  Exit 1B
# 3   2A     NaN   N  25.77139 -80.19882  Interstate 95  Exit 2A
# 4   2B     NaN   N  25.77339 -80.19866  Interstate 95  Exit 2B

# %%
i95[i95['exits'].str.contains('Exit 351')].iloc[0]
# Out:
# exit                   351A
# crossSt             Park St
# dir                       N
# lat                30.31568
# long               -81.6728
# interstate    Interstate 95
# exits             Exit 351A
# Name: 253, dtype: object

# %%
mylist = []
for row in final_df.iterrows():     
    if row[1]['interstate'] != "None":
            
        if (row[1]['interstate'] in i95['interstate'].unique()) and (row[1]['exits'] != "None"): 
            print(f"{row[1]['exits']} Lat: {i95[i95['exits'].str.contains(row[1]['exits'])]['lat'].iloc[0]}")
            mylist.append(row[1]['exits'])
        else:
            print("No Exit Found")
            mylist.append("None")
# Out:
# No Exit Found
# Exit 351 Lat: 30.31568
# No Exit Found
# Exit 351 Lat: 30.31568
# No Exit Found
# Exit 344 Lat: 30.24393
# No Exit Found
# No Exit Found
# No Exit Found
# Exit 351 Lat: 30.31568
# No Exit Found
# No Exit Found
# Exit 347 Lat: 30.288710000000002
# Exit 344 Lat: 30.24393
# No Exit Found
# Exit 344 Lat: 30.24393
# Exit 344 Lat: 30.24393
# No Exit Found
# No Exit Found
# No Exit Found
# Exit 337 Lat: 30.15859
# No Exit Found
# No Exit Found
# Exit 347 Lat: 30.288710000000002
# No Exit Found
# Exit 347 Lat: 30.288710000000002
# Exit 346 Lat: 30.27203
# No Exit Found
# Exit 351 Lat: 30.31568
# Exit 337 Lat: 30.15859
# No Exit Found
# Exit 346 Lat: 30.27203
# No Exit Found
# No Exit Found
# No Exit Found
# Exit 344 Lat: 30.24393
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# Exit 337 Lat: 30.15859
# Exit 337 Lat: 30.15859
# No Exit Found
# Exit 353 Lat: 30.33461
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# Exit 347 Lat: 30.288710000000002
# No Exit Found
# Exit 351 Lat: 30.31568
# No Exit Found
# Exit 353 Lat: 30.33461
# No Exit Found
# Exit 353 Lat: 30.33461
# Exit 337 Lat: 30.15859
# Exit 347 Lat: 30.288710000000002
# No Exit Found
# Exit 347 Lat: 30.288710000000002
# No Exit Found
# Exit 344 Lat: 30.24393
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# Exit 344 Lat: 30.24393
# No Exit Found
# Exit 353 Lat: 30.33461
# No Exit Found
# Exit 353 Lat: 30.33461
# No Exit Found
# Exit 351 Lat: 30.31568
# No Exit Found
# Exit 351 Lat: 30.31568
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# Exit 335 Lat: 30.13684
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# Exit 335 Lat: 30.13684
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found

# %%
len(mylist)
# Out:
# 100

# %%
len(final_df)
# Out:
# 100
