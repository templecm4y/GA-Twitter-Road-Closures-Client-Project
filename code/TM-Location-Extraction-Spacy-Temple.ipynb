# %% [markdown]
# # Location Extraction and Spacy Word Vectorization

# %%
import pandas as pd
import numpy as np
import re
import spacy
import string
import datetime

# %%
# Read in csv with Tweets
twitter_closures = pd.read_csv("../data/Cleaned_Tweets/cleaned_historic_official_07252019.csv")

twitter_closures = twitter_closures[['date', 'text', 'type', 'username', 'tweet', 'road_closure']]

# Print DF shape
print(twitter_closures.shape)

# Show head 
twitter_closures.head()
# Out:
# (43016, 6)
#                         date  \
# 0  2016-11-29 14:33:36+00:00
# 1  2016-11-28 20:35:05+00:00
# 2  2016-11-28 19:02:02+00:00
# 3  2016-11-24 19:01:16+00:00
# 4  2016-11-24 01:00:30+00:00
#
#                                                 text      type username  \
# 0  Douglas County Crash - EB I-20 b4 Post Rd  exi...  official  GDOTATL
# 1  With rain on the way - we have an important me...  official  GDOTATL
# 2  Much needed rain is headed our way    please b...  official  GDOTATL
# 3  Happy Thanksgiving  Please drive safe and pati...  official  GDOTATL
# 4  Have a safe Thanksgiving  Put away your cell p...  official  GDOTATL
#
#                                                tweet  road_closure
# 0  Douglas County Crash - EB I-20 b4 Post Rd  exi...             0
# 1  With rain on the way - we have an important me...             0
# 2  Much needed rain is headed our way    please b...             0
# 3  Happy Thanksgiving  Please drive safe and pati...             0
# 4  Have a safe Thanksgiving  Put away your cell p...             0

# %% [markdown]
# ## SpaCy Preprocessing

# %%
# Create new columns to transfer modified tweet text. Five versions of tweets will be created.
twitter_closures['modified_text'] = ''
twitter_closures['location'] = ''

# Show modified DF
twitter_closures.head(2)
# Out:
#                         date  \
# 0  2016-11-29 14:33:36+00:00
# 1  2016-11-28 20:35:05+00:00
#
#                                                 text      type username  \
# 0  Douglas County Crash - EB I-20 b4 Post Rd  exi...  official  GDOTATL
# 1  With rain on the way - we have an important me...  official  GDOTATL
#
#                                                tweet  road_closure  \
# 0  Douglas County Crash - EB I-20 b4 Post Rd  exi...             0
# 1  With rain on the way - we have an important me...             0
#
#   modified_text location
# 0
# 1

# %%
format_dict = {"hwy": "Highway ",
            "Blvd": "Boulevard",
            " st": "street",
           "CR ": "Country Road ",
           "SR ": "State Road",
           "I-": "Interstate ",
           "EB ": "Eastbound ",
           "WB ": "Westbound ",
           "SB ": "Southbound",
           "NB ": "Northbound",
           " on ": " at ",
           " E ": " East ",
           " W ": " West ",
           " S ": " South",
           " N ": " North",
           "mi ": "mile ",
           "between ": "at ",
           "Between ": "at ",
           "In ": "in ",
           " in ": " at "}

# %%
def spacy_cleaner(df, col, word_dict):
    modified_text = "At " + df[col].replace(word_dict, regex=True)
    modified_text = modified_text.str.title()
    return modified_text

# %%
# run the text cleaning function and test results
twitter_closures['modified_text'] = spacy_cleaner(twitter_closures, 'text', format_dict)

# %%
twitter_closures['username'].unique()
# Out:
# array(['GDOTATL', 'SCDOTMidlands', 'SCDOTPeeDee', 'SCDOTLowCountry',
#        'SCDOTPiedmont', '511statewideva', 'fl511_panhandl', '511Georgia',
#        'fl511_state', 'fl511_northeast', 'fl511_southeast',
#        'fl511_southwest', 'fl511_tampabay', 'fl511_central',
#        '511centralva', '511hamptonroads', '511northernva',
#        'NCDOT_Westmtn', 'NCDOT_Triangle', 'NCDOT_Piedmont',
#        'NCDOT_Charlotte', 'NCDOT_Asheville', 'NCDOT_Scoast',
#        'NCDOT_Ncoast'], dtype=object)

# %%
twitter_closures['date'] = pd.to_datetime(twitter_closures['date'])

# %%
test_df = twitter_closures[(twitter_closures['road_closure'] == 1) & (twitter_closures['username'] == 'fl511_northeast')].head(100)

# %%
def get_loc(df, text_column, location_column):
    
    # Use Spacy to extract location names from `text` column
    for i in range(len(df)):
        
        #instantiate spacy model
        nlp = spacy.load("en_core_web_sm")
        
        # create documewnt from modified text column
        doc = nlp(df[text_column].iloc[i])
        
        locations = set()
        
        # loop through every entity in the doc
        for ent in doc.ents:
            
            # find entities labelled as places
            if (ent.label_=='GPE') or (ent.label_=='FAC') or (ent.label_ == 'LOC'):
                
                # put locations in a set
                locations.add(ent.text)
                df[location_column].iloc[i] = locations
                
    return df[location_column]

# %%
test = get_loc(test_df, 'modified_text', 'location')
# Out:
# /Users/templemoore/anaconda3/envs/dsi/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
test_df['location'] = test
test_df.head()
# Out:
#                            date  \
# 19213 2016-11-29 23:59:23+00:00
# 19214 2016-11-29 23:59:15+00:00
# 19215 2016-11-29 23:54:26+00:00
# 19216 2016-11-29 23:49:10+00:00
# 19217 2016-11-29 23:49:10+00:00
#
#                                                                                                          text  \
# 19213                            NEW  Crash in Duval on I-295 E north beyond Philips Hwy, right lane blocked
# 19214  CLEARED  Traffic congestion in Duval on I-95 north from before Fuller Warren to ramp to Exit 351 I-10
# 19215               CLEARED  Traffic congestion in Duval on I-295 W north from Exit 5 San Jose to at Buckman
# 19216   UPDATE  Traffic congestion in Duval on I-95 north from before Fuller Warren to ramp to Exit 351 I-10
# 19217     CLEARED  Traffic congestion in Duval on I-295 E south from Exit 53 Butler to at Exit 56 Baymeadows
#
#            type         username  \
# 19213  official  fl511_northeast
# 19214  official  fl511_northeast
# 19215  official  fl511_northeast
# 19216  official  fl511_northeast
# 19217  official  fl511_northeast
#
#                                                                                                         tweet  \
# 19213                            NEW  Crash in Duval on I-295 E north beyond Philips Hwy, right lane blocked
# 19214  CLEARED  Traffic congestion in Duval on I-95 north from before Fuller Warren to ramp to Exit 351 I-10
# 19215               CLEARED  Traffic congestion in Duval on I-295 W north from Exit 5 San Jose to at Buckman
# 19216   UPDATE  Traffic congestion in Duval on I-95 north from before Fuller Warren to ramp to Exit 351 I-10
# 19217     CLEARED  Traffic congestion in Duval on I-295 E south from Exit 53 Butler to at Exit 56 Baymeadows
#
#        road_closure  \
# 19213             1
# 19214             1
# 19215             1
# 19216             1
# 19217             1
#
#                                                                                                                      modified_text  \
# 19213                                  At New  Crash At Duval At Interstate 295 East North Beyond Philips Hwy, Right Lane Blocked
# 19214  At Cleared  Traffic Congestion At Duval At Interstate 95 North From Before Fuller Warren To Ramp To Exit 351 Interstate 10
# 19215                     At Cleared  Traffic Congestion At Duval At Interstate 295 West North From Exit 5 San Jose To At Buckman
# 19216   At Update  Traffic Congestion At Duval At Interstate 95 North From Before Fuller Warren To Ramp To Exit 351 Interstate 10
# 19217           At Cleared  Traffic Congestion At Duval At Interstate 295 East South From Exit 53 Butler To At Exit 56 Baymeadows
#
#                                                            location
# 19213  {Interstate 295 East North, New  Crash At Duval, Right Lane}
# 19214                          {Interstate 10, Interstate 95 North}
# 19215                 {Interstate 295 West North, San Jose, Exit 5}
# 19216                          {Interstate 10, Interstate 95 North}
# 19217                 {Exit 56, Exit 53, Interstate 295 East South}

# %%
test_df.to_csv("../data/Loc_Extracted/tweet_locations_sample_07292019.csv", index = False)

# %%
test_df = pd.read_csv("../data/Loc_Extracted/tweet_locations_sample_07292019.csv")

# %%
pd.options.display.max_colwidth = 200
test_df[test_df['tweet'].str.contains('I-95') == True]['text']
# Out:
# 1        CLEARED  Traffic congestion in Duval on I-95 north from before Fuller Warren to ramp to Exit 351 I-10
# 3         UPDATE  Traffic congestion in Duval on I-95 north from before Fuller Warren to ramp to Exit 351 I-10
# 5            CLEARED  Traffic congestion in Duval on I-95 south from Exit 344 Butler to at Exit 341 Baymeadows
# 9                                     CLEARED  Traffic congestion in Duval on I-95 south ramp to Exit 351 I-10
# 10                 CLEARED  Traffic congestion in Duval on SR-202   Butler Blvd west from Southside to at I-95
# 11              CLEARED  Traffic congestion in Duval on I-295 W north from Exit 61 I-95 to at Exit 3 St Aug Rd
# 12         CLEARED  Traffic congestion in Duval on I-95 south from Exit 347 Emerson to ramp to Exit 344 Butler
# 13                                 CLEARED  Crash in Duval on I-95 south at Exit 344 Butler, left lane blocked
# 15                                  UPDATE  Crash in Duval on I-95 south at Exit 344 Butler, left lane blocked
# 16            UPDATE  Traffic congestion in Duval on I-95 south from Exit 344 Butler to at Exit 341 Baymeadows
# 20           CLEARED  Traffic congestion in Duval on I-95 south from Exit 337 I-295 W to at Exit 335 St Aug Rd
# 23                CLEARED  Traffic congestion in Duval on I-95 south from Fuller Warren to at Exit 347 Emerson
# 25          UPDATE  Traffic congestion in Duval on I-95 south from Exit 347 Emerson to ramp to Exit 344 Butler
# 26         UPDATE  Traffic congestion in Duval on I-95 north from Exit 346 University to ramp to Exit 351 I-10
# 28                                     UPDATE  Traffic congestion in Duval on I-95 south ramp to Exit 351 I-10
# 29                                      CLEARED  Traffic congestion in Duval on I-95 south at Exit 337 I-295 W
# 30               UPDATE  Traffic congestion in Duval on I-295 W north from Exit 61 I-95 to at Exit 3 St Aug Rd
# 31       UPDATE  Traffic congestion in Duval on I-95 south from Exit 346 University to ramp to Exit 344 Butler
# 35               NEW  Traffic congestion in Duval on I-95 south from Exit 344 Butler to at Exit 341 Baymeadows
# 41               NEW  Traffic congestion in Duval on I-95 south from Exit 337 I-295 W to at Exit 335 St Aug Rd
# 42                                       UPDATE  Traffic congestion in Duval on I-95 south at Exit 337 I-295 W
# 44    UPDATE  Traffic congestion in Duval on I-95 south from before Exit 353 Union St to ramp to Exit 351 I-10
# 49            UPDATE  Traffic congestion in Duval on I-95 north from Exit 347 Emerson to ramp to Exit 351 I-10
# 51              UPDATE  Traffic congestion in Duval on I-95 north from beyond Emerson to ramp to Exit 351 I-10
# 52                                NEW  Crash in Duval on I-95 north before Fuller Warren, 2 left lanes blocked
# 53    UPDATE  Traffic congestion in Duval on I-95 south from before Exit 353 Union St to ramp to Exit 351 I-10
# 54                  UPDATE  Traffic congestion in Duval on SR-202   Butler Blvd west from Southside to at I-95
# 55       NEW  Traffic congestion in Duval on I-95 south from before Exit 353 Union St to ramp to Exit 351 I-10
# 56                                          NEW  Traffic congestion in Duval on I-95 south at Exit 337 I-295 W
# 57                 UPDATE  Traffic congestion in Duval on I-95 south from Fuller Warren to at Exit 347 Emerson
# 58              NEW  Traffic congestion in Duval on SR-202   Butler Blvd west from beyond Southside to at I-95
# 59                      NEW  Traffic congestion in Duval on I-95 south from beyond US-1 to at Exit 347 Emerson
# 60               UPDATE  Traffic congestion in Duval on I-295 W north from Exit 61 I-95 to at Exit 3 St Aug Rd
# 61         UPDATE  Traffic congestion in Duval on I-95 south from beyond University to ramp to Exit 344 Butler
# 62                       CLEARED  Traffic congestion in Duval on I-95 south from beyond 8th St to ramp to I-10
# 66                        UPDATE  Traffic congestion in Duval on I-95 south from beyond 8th St to ramp to I-10
# 69                        UPDATE  Traffic congestion in Duval on I-95 south from before 8th St to ramp to I-10
# 71                  NEW  Traffic congestion in Duval on I-295 W north from Exit 61 I-95 to at Exit 3 St Aug Rd
# 72                                      NEW  Traffic congestion in Duval on I-95 south ramp to Exit 344 Butler
# 74             UPDATE  Traffic congestion in Duval on I-95 south from before Exit 353 Union St to ramp to I-10
# 76                NEW  Traffic congestion in Duval on I-95 south from before Exit 353 Union St to ramp to I-10
# 78              UPDATE  Traffic congestion in Duval on I-95 north from beyond Emerson to ramp to Exit 351 I-10
# 80                  NEW  Traffic congestion in Duval on I-95 north from Fuller Warren to ramp to Exit 351 I-10
# 88                                   CLEARED  Disabled truck in Duval on I-95 north ramp to Exit 335 St Aug Rd
# 90       CLEARED  Unconfirmed disabled vehicle in Duval on I-95 south at Fuller Warren, right shoulder blocked
# 92                  CLEARED  Disabled vehicle in Duval on SR-202   Butler Blvd east at I-95, left lane blocked
# 93                                    UPDATE  Disabled truck in Duval on I-95 north ramp to Exit 335 St Aug Rd
# 97           NEW  Unconfirmed disabled vehicle in Duval on I-95 south at Fuller Warren, right shoulder blocked
# 99                      NEW  Disabled vehicle in Duval on SR-202   Butler Blvd east at I-95, left lane blocked
# Name: text, dtype: object

# %%
i95 = pd.read_csv('../df_csv')
i95['interstate'] = 'Interstate 95'
i95['exits'] = 'Exit ' + i95['exit']
i95.head()
# Out:
#   exit crossSt dir       lat      long     interstate    exits
# 0   1A     NaN   S  25.75506 -80.20200  Interstate 95  Exit 1A
# 1   1B     NaN   N  25.76255 -80.19960  Interstate 95  Exit 1B
# 2   1B     NaN   S  25.77588 -80.19986  Interstate 95  Exit 1B
# 3   2A     NaN   N  25.77139 -80.19882  Interstate 95  Exit 2A
# 4   2B     NaN   N  25.77339 -80.19866  Interstate 95  Exit 2B

# %%
for item in i95.iterrows():
    if item[1]['exits'] != "None":
        print(item[1]['exit'])
        if "Exit 337" in item[1]['exits']:
            print(str(item[1]['lat']) + " " + str(item[1]['long']))
# Out:
# 1A
# 1B
# 1B
# 2A
# 2B
# 2C
# 2D
# 3A
# 3B
# 2D
# 4A
# 4B
# 4
# 6A
# 6A
# 6B
# 7
# 7
# 8A
# 8A
# 8B
# 8B
# 9
# 10A
# 10A
# 10B
# 10B
# 11
# 12A
# 12B
# 12C
# 12
# 14
# 14
# 16
# 16
# 18
# 18
# 19
# 19
# 20
# 20
# 21
# 21
# 22
# 22
# 23
# 23
# 24
# 25
# 25
# 26
# 26
# 27
# 27
# 29A
# 29B
# 29
# 31A
# 31B
# 31
# 32
# 32
# 33A
# 33B
# 33
# 36
# 36
# 38
# 38A
# 38B
# 39
# 39
# 41
# 41
# 42A
# 42B
# 42
# 44
# 44
# 45
# 45
# 48A
# 48B
# 48
# 50
# 50
# 51
# 51
# 52
# 52
# 56
# 56
# 57
# 57
# 59
# 59
# 60
# 60
# 61
# 61
# 63
# 63
# 64
# 64
# 66
# 66
# 68
# 68
# 69
# 69A
# 69B
# 70
# 70
# 71
# 71
# 74
# 74
# 76
# 76
# 77
# 77
# 79A
# 79B
# 79
# 79C
# 83
# 83
# 87A
# 87A
# 87B
# 87B
# 96
# 96
# 101
# 101
# 102
# 102
# 110
# 110
# 114
# 114
# 118
# 118
# 120
# 120
# 121
# 121
# 126
# 126
# 129
# 129
# 131
# 131
# 138
# 138
# 147
# 147
# 156
# 156
# 173
# 173
# 176
# 176
# 180
# 180
# 183
# 183
# 188
# 188
# 191
# 191
# 193
# 193
# 195
# 195
# 201
# 201
# 202
# 202
# 205A
# 205A
# 205B
# 205B
# 208
# 208
# 212
# 212
# 215
# 215
# 220
# 220
# 223
# 223
# 231
# 231
# 244
# 244
# 249
# 249A
# 249B
# 256
# 256
# 260A
# 260A
# 260B
# 260B
# 261
# 265
# 265
# 268
# 268
# 273
# 273
# 278
# 278
# 284
# 284
# 289
# 289
# 293
# 293
# 298
# 298
# 305
# 305
# 311
# 311
# 318
# 318
# 323
# 323
# 329
# 329
# 333
# 333
# 335
# 335
# 337
# 30.15859 -81.55057
# 337
# 30.17594 -81.55901999999999
# 339
# 339
# 340
# 341
# 341
# 344
# 344
# 345
# 346A
# 346B
# 347
# 347
# 348
# 351A
# 351B
# 350B
# 350A
# 352A
# 352B
# 352C
# 351C
# 352D
# 353A
# 353B
# 353B
# 353C
# 353C
# 353D
# 353D
# 354A
# 354A
# 354B
# 354B
# 355
# 355
# 356A
# 356B
# 356
# 357
# 357
# 358A
# 358A
# 358B
# 358B
# 360
# 360
# 362A
# 362A
# 362B
# 362B
# 363A
# 363B
# 363
# 366
# 366
# 373
# 373
# 380
# 380

# %%
def exit_extractor (df, col, i_df):
    
    exits = []
    interstates = []
    lat = []
    long = []
    direction = []
    
    for item in df[col]:
        if 'Interstate' in item:
            
            i_string = re.search(r'Interstate (\S+)', item)
            interstates.append(i_string.group(0))
            
            if 'Exit' in item:
                e_string = re.search(r'Exit (\S+)', item)
                exits.append(e_string.group(0))
            else:
                exits.append("None")
        else:
            interstates.append("None")
            exits.append("None")
    
    new_df = pd.DataFrame(data = interstates, columns = ['interstate'])
    new_df['exits'] = exits
    
    for row in new_df.iterrows():
        
        if row[1]['interstate'] != "None":

            if (row[1]['interstate'] in i95['interstate'].unique()) and (row[1]['exits'] != "None"):
                
                lat.append(i_df[i_df['exits'].str.contains(row[1]['exits'])]['lat'].iloc[0])
                long.append(i_df[i_df['exits'].str.contains(row[1]['exits'])]['long'].iloc[0])
                      
            else:
                lat.append(np.nan)
                long.append(np.nan)
    
    new_df['lat'] = lat
    new_df['long'] = long
    
    return new_df

# %%
exit_extractor(test_df, 'modified_text', i95)
# Out:
#         interstate     exits                 lat      long
# 0   Interstate 295      None                 NaN       NaN
# 1    Interstate 95  Exit 351            30.31568 -81.67278
# 2   Interstate 295    Exit 5                 NaN       NaN
# 3    Interstate 95  Exit 351            30.31568 -81.67278
# 4   Interstate 295   Exit 53                 NaN       NaN
# 5    Interstate 95  Exit 344            30.24393 -81.58858
# 6   Interstate 295   Exit 53                 NaN       NaN
# 7   Interstate 295      None                 NaN       NaN
# 8   Interstate 295    Exit 5                 NaN       NaN
# 9    Interstate 95  Exit 351            30.31568 -81.67278
# 10   Interstate 95      None                 NaN       NaN
# 11  Interstate 295   Exit 61                 NaN       NaN
# 12   Interstate 95  Exit 347  30.288710000000002 -81.62745
# 13   Interstate 95  Exit 344            30.24393 -81.58858
# 14  Interstate 295   Exit 55                 NaN       NaN
# 15   Interstate 95  Exit 344            30.24393 -81.58858
# 16   Interstate 95  Exit 344            30.24393 -81.58858
# 17  Interstate 295      None                 NaN       NaN
# 18  Interstate 295   Exit 53                 NaN       NaN
# 19  Interstate 295   Exit 58                 NaN       NaN
# 20   Interstate 95  Exit 337            30.15859 -81.55057
# 21  Interstate 295   Exit 10                 NaN       NaN
# 22  Interstate 295      None                 NaN       NaN
# 23   Interstate 95  Exit 347  30.288710000000002 -81.62745
# 24  Interstate 295      None                 NaN       NaN
# 25   Interstate 95  Exit 347  30.288710000000002 -81.62745
# 26   Interstate 95  Exit 346            30.27203 -81.61395
# 27  Interstate 295      None                 NaN       NaN
# 28   Interstate 95  Exit 351            30.31568 -81.67278
# 29   Interstate 95  Exit 337            30.15859 -81.55057
# ..             ...       ...                 ...       ...
# 70  Interstate 295      None                 NaN       NaN
# 71  Interstate 295   Exit 61                 NaN       NaN
# 72   Interstate 95  Exit 344            30.24393 -81.58858
# 73  Interstate 295   Exit 53                 NaN       NaN
# 74   Interstate 95  Exit 353            30.33461 -81.67100
# 75  Interstate 295   Exit 56                 NaN       NaN
# 76   Interstate 95  Exit 353            30.33461 -81.67100
# 77  Interstate 295      None                 NaN       NaN
# 78   Interstate 95  Exit 351            30.31568 -81.67278
# 79  Interstate 295      None                 NaN       NaN
# 80   Interstate 95  Exit 351            30.31568 -81.67278
# 81  Interstate 295      None                 NaN       NaN
# 82  Interstate 295      None                 NaN       NaN
# 83   Interstate 10      None                 NaN       NaN
# 84  Interstate 295      None                 NaN       NaN
# 85  Interstate 295   Exit 56                 NaN       NaN
# 86  Interstate 295      None                 NaN       NaN
# 87   Interstate 10      None                 NaN       NaN
# 88   Interstate 95  Exit 335            30.13684 -81.53598
# 89  Interstate 295   Exit 19                 NaN       NaN
# 90   Interstate 95      None                 NaN       NaN
# 91   Interstate 10      None                 NaN       NaN
# 92  Interstate 95,      None                 NaN       NaN
# 93   Interstate 95  Exit 335            30.13684 -81.53598
# 94  Interstate 295      None                 NaN       NaN
# 95  Interstate 295      None                 NaN       NaN
# 96  Interstate 295   Exit 19                 NaN       NaN
# 97   Interstate 95      None                 NaN       NaN
# 98   Interstate 10      None                 NaN       NaN
# 99  Interstate 95,      None                 NaN       NaN
#
# [100 rows x 4 columns]

# %%
exits = exit_extractor(test_df, 'modified_text', i95)
final_df = pd.concat([test_df, exits], axis = 1)
final_df.head()
# Out:
#                         date  \
# 0  2016-11-29 23:59:23+00:00
# 1  2016-11-29 23:59:15+00:00
# 2  2016-11-29 23:54:26+00:00
# 3  2016-11-29 23:49:10+00:00
# 4  2016-11-29 23:49:10+00:00
#
#                                                                                                      text  \
# 0                            NEW  Crash in Duval on I-295 E north beyond Philips Hwy, right lane blocked
# 1  CLEARED  Traffic congestion in Duval on I-95 north from before Fuller Warren to ramp to Exit 351 I-10
# 2               CLEARED  Traffic congestion in Duval on I-295 W north from Exit 5 San Jose to at Buckman
# 3   UPDATE  Traffic congestion in Duval on I-95 north from before Fuller Warren to ramp to Exit 351 I-10
# 4     CLEARED  Traffic congestion in Duval on I-295 E south from Exit 53 Butler to at Exit 56 Baymeadows
#
#        type         username  \
# 0  official  fl511_northeast
# 1  official  fl511_northeast
# 2  official  fl511_northeast
# 3  official  fl511_northeast
# 4  official  fl511_northeast
#
#                                                                                                     tweet  \
# 0                            NEW  Crash in Duval on I-295 E north beyond Philips Hwy, right lane blocked
# 1  CLEARED  Traffic congestion in Duval on I-95 north from before Fuller Warren to ramp to Exit 351 I-10
# 2               CLEARED  Traffic congestion in Duval on I-295 W north from Exit 5 San Jose to at Buckman
# 3   UPDATE  Traffic congestion in Duval on I-95 north from before Fuller Warren to ramp to Exit 351 I-10
# 4     CLEARED  Traffic congestion in Duval on I-295 E south from Exit 53 Butler to at Exit 56 Baymeadows
#
#    road_closure  \
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
#
#                                                                                                                  modified_text  \
# 0                                  At New  Crash At Duval At Interstate 295 East North Beyond Philips Hwy, Right Lane Blocked
# 1  At Cleared  Traffic Congestion At Duval At Interstate 95 North From Before Fuller Warren To Ramp To Exit 351 Interstate 10
# 2                     At Cleared  Traffic Congestion At Duval At Interstate 295 West North From Exit 5 San Jose To At Buckman
# 3   At Update  Traffic Congestion At Duval At Interstate 95 North From Before Fuller Warren To Ramp To Exit 351 Interstate 10
# 4           At Cleared  Traffic Congestion At Duval At Interstate 295 East South From Exit 53 Butler To At Exit 56 Baymeadows
#
#                                                              location  \
# 0  {'Interstate 295 East North', 'New  Crash At Duval', 'Right Lane'}
# 1                            {'Interstate 10', 'Interstate 95 North'}
# 2                 {'Interstate 295 West North', 'San Jose', 'Exit 5'}
# 3                            {'Interstate 10', 'Interstate 95 North'}
# 4                 {'Exit 56', 'Exit 53', 'Interstate 295 East South'}
#
#        interstate     exits       lat      long
# 0  Interstate 295      None       NaN       NaN
# 1   Interstate 95  Exit 351  30.31568 -81.67278
# 2  Interstate 295    Exit 5       NaN       NaN
# 3   Interstate 95  Exit 351  30.31568 -81.67278
# 4  Interstate 295   Exit 53       NaN       NaN

# %%
i95.head()
# Out:
#   exit crossSt dir       lat      long     interstate    exits
# 0   1A     NaN   S  25.75506 -80.20200  Interstate 95  Exit 1A
# 1   1B     NaN   N  25.76255 -80.19960  Interstate 95  Exit 1B
# 2   1B     NaN   S  25.77588 -80.19986  Interstate 95  Exit 1B
# 3   2A     NaN   N  25.77139 -80.19882  Interstate 95  Exit 2A
# 4   2B     NaN   N  25.77339 -80.19866  Interstate 95  Exit 2B

# %%
i95[i95['exits'].str.contains('Exit 351')].iloc[0]
# Out:
# exit                   351A
# crossSt             Park St
# dir                       N
# lat                30.31568
# long               -81.6728
# interstate    Interstate 95
# exits             Exit 351A
# Name: 253, dtype: object

# %%
mylist = []
for row in final_df.iterrows():     
    if row[1]['interstate'] != "None":
            
        if (row[1]['interstate'] in i95['interstate'].unique()) and (row[1]['exits'] != "None"): 
            print(f"{row[1]['exits']} Lat: {i95[i95['exits'].str.contains(row[1]['exits'])]['lat'].iloc[0]}")
            mylist.append(row[1]['exits'])
        else:
            print("No Exit Found")
            mylist.append("None")
# Out:
# No Exit Found
# Exit 351 Lat: 30.31568
# No Exit Found
# Exit 351 Lat: 30.31568
# No Exit Found
# Exit 344 Lat: 30.24393
# No Exit Found
# No Exit Found
# No Exit Found
# Exit 351 Lat: 30.31568
# No Exit Found
# No Exit Found
# Exit 347 Lat: 30.288710000000002
# Exit 344 Lat: 30.24393
# No Exit Found
# Exit 344 Lat: 30.24393
# Exit 344 Lat: 30.24393
# No Exit Found
# No Exit Found
# No Exit Found
# Exit 337 Lat: 30.15859
# No Exit Found
# No Exit Found
# Exit 347 Lat: 30.288710000000002
# No Exit Found
# Exit 347 Lat: 30.288710000000002
# Exit 346 Lat: 30.27203
# No Exit Found
# Exit 351 Lat: 30.31568
# Exit 337 Lat: 30.15859
# No Exit Found
# Exit 346 Lat: 30.27203
# No Exit Found
# No Exit Found
# No Exit Found
# Exit 344 Lat: 30.24393
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# Exit 337 Lat: 30.15859
# Exit 337 Lat: 30.15859
# No Exit Found
# Exit 353 Lat: 30.33461
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# Exit 347 Lat: 30.288710000000002
# No Exit Found
# Exit 351 Lat: 30.31568
# No Exit Found
# Exit 353 Lat: 30.33461
# No Exit Found
# Exit 353 Lat: 30.33461
# Exit 337 Lat: 30.15859
# Exit 347 Lat: 30.288710000000002
# No Exit Found
# Exit 347 Lat: 30.288710000000002
# No Exit Found
# Exit 344 Lat: 30.24393
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# Exit 344 Lat: 30.24393
# No Exit Found
# Exit 353 Lat: 30.33461
# No Exit Found
# Exit 353 Lat: 30.33461
# No Exit Found
# Exit 351 Lat: 30.31568
# No Exit Found
# Exit 351 Lat: 30.31568
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# Exit 335 Lat: 30.13684
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# Exit 335 Lat: 30.13684
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found
# No Exit Found

# %%
len(mylist)
# Out:
# 100

# %%
len(final_df)
# Out:
# 100
