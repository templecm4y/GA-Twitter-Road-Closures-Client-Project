# %% [markdown]
# # Location Extraction and Spacy Word Vectorization

# %%
import pandas as pd
import numpy as np
import re
import spacy
import string
import datetime

from spacy import displacy

# %%
# Read in csv with Tweets
twitter_closures = pd.read_csv("../data/Cleaned_Tweets/cleaned_historic_official_07312019.csv")
rt_closures = pd.read_csv("../data/Cleaned_Tweets/cleaned_RT_official_07312019.csv")

exits = pd.read_csv("../data/interstate_exits.csv")

twitter_closures = twitter_closures[['date', 'text', 'type', 'username', 'tweet', 'state', 'road_closure']]
rt_closures = rt_closures[['date', 'text', 'type', 'username', 'tweet', 'state', 'road_closure']]

# Print DF shape
print(twitter_closures.shape)
print(rt_closures.shape)

# Show head of real time tweets
rt_closures.head()
# Out:
# (24054, 7)
# (200, 7)
#                   date                                               text  \
# 0  2019-07-31 19:34:13  cleared  planned construction in duval on sr-1...
# 1  2019-07-31 19:34:12  cleared  planned construction in duval on sr-1...
# 2  2019-07-31 19:00:11  cleared  object on roadway in st johns on i-95...
# 3  2019-07-31 18:12:24  cleared  planned construction in clay on sr-21...
# 4  2019-07-31 16:26:10  cleared  vehicle on fire in st johns on i-95 s...
#
#        type         username  \
# 0  official  fl511_northeast
# 1  official  fl511_northeast
# 2  official  fl511_northeast
# 3  official  fl511_northeast
# 4  official  fl511_northeast
#
#                                                tweet    state  road_closure
# 0  Cleared  Planned construction in Duval on SR-1...  Florida             0
# 1  Cleared  Planned construction in Duval on SR-1...  Florida             0
# 2  Cleared  Object on roadway in St Johns on I-95...  Florida             0
# 3  Cleared  Planned construction in Clay on SR-21...  Florida             0
# 4  Cleared  Vehicle on fire in St Johns on I-95 s...  Florida             0

# %% [markdown]
# ## SpaCy Preprocessing

# %%
# Create new columns to transfer modified tweet text. Five versions of tweets will be created.
twitter_closures['modified_text'] = ''
twitter_closures['location'] = ''
rt_closures['modified_text'] = ''
rt_closures['location'] = ''

# Show modified DF
twitter_closures.head(2)
# Out:
#                         date  \
# 0  2016-10-11 16:39:51+00:00
# 1  2016-10-10 19:10:23+00:00
#
#                                                 text      type username  \
# 0  the pioh for the sr 138 i-20 is going on now u...  official  GDOTATL
# 1  we appreciate all the hard work our crews have...  official  GDOTATL
#
#                                                tweet    state  road_closure  \
# 0  The PIOH for the SR 138 I-20 is going on now u...  Georgia             0
# 1  We appreciate all the hard work our crews have...  Georgia             0
#
#   modified_text location
# 0
# 1

# %%
format_dict = {"hwy": "highway ",
            "blvd": "boulevard",
            " st": "street",
           "CR ": "County Road ",
           "SR ": "State Road",
           "I-": "Interstate ",
           "EB ": "Eastbound ",
           "WB ": "Westbound ",
           "SB ": "Southbound",
           "NB ": "Northbound",
           " on ": " at ",
           " E ": " East ",
           " W ": " West ",
           " S ": " South",
           " N ": " North",
           "mi ": "mile ",
           "between ": "at ",
           "Between ": "at ",
           " In ": " in",
           " in ": " at "}

# %%
def spacy_cleaner(df, col, word_dict):
    modified_text = "At " + df[col].replace(word_dict, regex=True)
    modified_text = modified_text.str.title()
    return modified_text

# %%
# run the text cleaning function and test results
twitter_closures['modified_text'] = spacy_cleaner(twitter_closures, 'tweet', format_dict)
rt_closures['modified_text'] = spacy_cleaner(rt_closures, 'tweet', format_dict)

# %%
twitter_closures['username'].unique()
# Out:
# array(['GDOTATL', 'SCDOTMidlands', 'SCDOTPeeDee', 'SCDOTLowCountry',
#        'SCDOTPiedmont', '511statewideva', 'fl511_panhandl', '511Georgia',
#        'fl511_state', 'fl511_northeast', 'fl511_southeast',
#        'fl511_southwest', 'fl511_tampabay', 'fl511_central',
#        '511centralva', '511hamptonroads', '511northernva',
#        'NCDOT_Westmtn', 'NCDOT_Triangle', 'NCDOT_Piedmont',
#        'NCDOT_Charlotte', 'NCDOT_Asheville', 'NCDOT_Scoast',
#        'NCDOT_Ncoast'], dtype=object)

# %%
# convert date column to datetime
twitter_closures['date'] = pd.to_datetime(twitter_closures['date'])
rt_closures['date'] = pd.to_datetime(rt_closures['date'])

# %%
# for ease of use of the historic tweets, only take tweets that happened from
# October 6, 2016 to October 9, 2016
# the day Hurricane Matthew hit Jacksonville
twitter_closures = twitter_closures[(twitter_closures['date'] > '2016-10-6') & (twitter_closures['date'] < '2016-10-9')]

# %%
# only use tweets that contain road closures are from 'fl511 northeast'
loc_df = twitter_closures[(twitter_closures['road_closure'] == 1) & (twitter_closures['username'] == 'fl511_northeast')]
loc_df.shape
# Out:
# (267, 9)

# %%
# only take tweets that contain road closures from the real time set
rt_loc_df = rt_closures[(rt_closures['road_closure'] == 1)]
rt_loc_df.shape
# Out:
# (127, 9)

# %%
def get_loc(df, text_column, location_column):
    
    # Use Spacy to extract location names from `text` column
    for i in range(len(df)):
        
        #instantiate spacy model
        nlp = spacy.load("en_core_web_sm")
        
        # create documewnt from modified text column
        doc = nlp(df[text_column].iloc[i])
        
        locations = set()
        
        # loop through every entity in the doc
        for ent in doc.ents:
            
            # find entities labelled as places
            if (ent.label_=='GPE') or (ent.label_=='FAC') or (ent.label_ == 'LOC'):
                
                # put locations in a set
                locations.add(ent.text)
                df[location_column].iloc[i] = locations
                
    return df[location_column]

# %%
loc = get_loc(loc_df, 'modified_text', 'location')
# Out:
# /Users/templemoore/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
rt_loc = get_loc(rt_loc_df, 'modified_text', 'location')
# Out:
# /Users/templemoore/anaconda3/envs/dsi/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/templemoore/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
loc_df['location'] = loc
print(loc_df.shape)
loc_df.head()
# Out:
# (267, 9)
# /Users/templemoore/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                            date  \
# 13806 2016-10-08 23:33:38+00:00
# 13807 2016-10-08 23:18:05+00:00
# 13808 2016-10-08 21:58:06+00:00
# 13809 2016-10-08 21:33:05+00:00
# 13810 2016-10-08 21:28:40+00:00
#
#                                                     text      type  \
# 13806  new  disabled vehicle in duval on sr-202   but...  official
# 13807  new  disabled vehicle in duval on i-295 w nort...  official
# 13808  new  unconfirmed disabled vehicle in duval on ...  official
# 13809  update  disabled vehicle in duval on i-295 w n...  official
# 13810  new  disabled vehicle in duval on i-295 w nort...  official
#
#               username                                              tweet  \
# 13806  fl511_northeast  NEW  Disabled vehicle in Duval on SR-202   But...
# 13807  fl511_northeast  NEW  Disabled vehicle in Duval on I-295 W nort...
# 13808  fl511_northeast  NEW  Unconfirmed disabled vehicle in Duval on ...
# 13809  fl511_northeast  UPDATE  Disabled vehicle in Duval on I-295 W n...
# 13810  fl511_northeast  NEW  Disabled vehicle in Duval on I-295 W nort...
#
#          state  road_closure  \
# 13806  Florida             1
# 13807  Florida             1
# 13808  Florida             1
# 13809  Florida             1
# 13810  Florida             1
#
#                                            modified_text  \
# 13806  At New  Disabled Vehicle At Duval At Sr-202   ...
# 13807  At New  Disabled Vehicle At Duval At Interstat...
# 13808  At New  Unconfirmed Disabled Vehicle At Duval ...
# 13809  At Update  Disabled Vehicle At Duval At Inters...
# 13810  At New  Disabled Vehicle At Duval At Interstat...
#
#                                               location
# 13806  {Kernan Blvd Right Shoulder Blocked, Blvd East}
# 13807            {Interstate 295 West North, San Jose}
# 13808       {Interstate 10 East Ramp To Interstate 95}
# 13809                      {Interstate 295 West North}
# 13810                      {Interstate 295 West North}

# %%
rt_loc_df['location'] = rt_loc
print(rt_loc_df.shape)
rt_loc_df.head()
# Out:
# (127, 9)
# /Users/templemoore/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                   date                                               text  \
# 73 2019-07-31 19:57:12  updated  disabled vehicle in duval on i-295 e ...
# 74 2019-07-31 19:53:12  updated  disabled vehicle in duval on i-295 e ...
# 75 2019-07-31 19:49:14  updated  disabled vehicle in duval on i-295 e ...
# 76 2019-07-31 19:33:16  new  disabled vehicle in duval on i-295 e sout...
# 77 2019-07-31 18:58:11  updated  object on roadway in st johns on i-95...
#
#         type         username  \
# 73  official  fl511_northeast
# 74  official  fl511_northeast
# 75  official  fl511_northeast
# 76  official  fl511_northeast
# 77  official  fl511_northeast
#
#                                                 tweet    state  road_closure  \
# 73  Updated  Disabled vehicle in Duval on I-295 E ...  Florida             1
# 74  Updated  Disabled vehicle in Duval on I-295 E ...  Florida             1
# 75  Updated  Disabled vehicle in Duval on I-295 E ...  Florida             1
# 76  New  Disabled vehicle in Duval on I-295 E sout...  Florida             1
# 77  Updated  Object on roadway in St Johns on I-95...  Florida             1
#
#                                         modified_text  \
# 73  At Updated  Disabled Vehicle At Duval At Inter...
# 74  At Updated  Disabled Vehicle At Duval At Inter...
# 75  At Updated  Disabled Vehicle At Duval At Inter...
# 76  At New  Disabled Vehicle At Duval At Interstat...
# 77  At Updated  Object At Roadway At St Johns At I...
#
#                                              location
# 73           {Interstate 295 East South, Dames Point}
# 74         {Dames Point 2, Interstate 295 East South}
# 75           {Interstate 295 East South, Dames Point}
# 76           {Interstate 295 East South, Dames Point}
# 77  {Johns, Sr-16 Right Lane Blocked, Interstate 9...

# %%
loc_df.to_csv("../data/Loc_Extracted/tweet_locations_sample_07312019.csv", index = False)
rt_loc_df.to_csv("../data/Loc_Extracted/rt_locations_sample_07312019.csv", index = False)

# %%
loc_df = pd.read_csv("../data/Loc_Extracted/tweet_locations_sample_07312019.csv")
rt_loc_df = pd.read_csv("../data/Loc_Extracted/rt_locations_sample_07312019.csv")

# %% [markdown]
# ## GPS Coordinate Extraction using Interstate Exits

# %%
# function to extract interstate, exit number, and direction
def exit_extractor (df, col, i_df):
    
    # instantiate lists for exit data
    exits = []
    interstates = []
    lat = []
    long = []
    direction = []
    
    # loop through text column
    for item in df[col]:
        
        # look for "interstate" in text
        if 'Interstate' in item:
            
            # use regex to extract interstate and number from text
            i_string = re.search(r'Interstate (\S+)', item)
            interstates.append(i_string.group(0))
            
            # use regex to extract direction following "interstate"
            d_string = re.search("(i-\d*|Interstate \d*) (South|North|East|West)*", item)
            d_string = d_string.group(0)
            d_string =  re.search("South|North|East|West", d_string)
            
            # try to extract the direction from the regex object
            # append null if an error is thrown
            try:
                d_string = d_string.group(0)
                
            except AttributeError: 
                d_string = np.nan
                
            # append direction to list    
            direction.append(d_string)
                             
            # find "exit" in text
            if 'Exit' in item:
                
                # use regex to extract interstate and number from text
                e_string = re.search(r'Exit (\S+)', item)
                exits.append(e_string.group(0))
            
            # add "none" when no exit is found   
            else:
                exits.append("None")
                
        # add "none" to exits and interstates if no interstate is found
        else:
            interstates.append("None")
            exits.append("None")
            direction.append("None")
            
    # create a new dataframe from the interstate and exit lists
    new_df = pd.DataFrame(data = interstates, columns = ['interstate'])
    new_df['exits'] = exits
    new_df['direction'] = direction
    
    # return new dataframe
    return new_df

# %%
# function to extract longitude and latitude, if available
def loc_extractor(new_df, i_df):
    
    lat = []
    long = []
    
    # loop through the new dataframe
    for index, row in new_df.iterrows():
        
        # find rows that have both an interstate and exit extracted
        if (row['interstate'] != "None") and (row['exits'] != "None") and row['direction'] != "None":
            
            # attempt to add lat and long based on exit and interstate strings
            try:    
                mask = (i_df['interstate'].str.contains(row['interstate'])) & (i_df['exits'].str.contains(row['exits']))
                
                # add lat and long to list
                lat.append(i_df[mask].iloc[0]['lat'])
                long.append(i_df[mask].iloc[0]['long'])
            
            # if an error occurs, append null to lat and long
            # print index where error occured
            except:
                print(f"No exit found at {index}")

                lat.append(np.nan)
                long.append(np.nan)
        # if no exit is found, add null values to lat and long
        else:
            lat.append(np.nan)
            long.append(np.nan)
            
    # add lat and long to new dataframe
    new_df['lat'] = lat
    new_df['long'] = long
    
    return new_df

# %%
e_df = loc_extractor(exit_extractor(loc_df, 'modified_text', exits), exits)
final_df = pd.concat([loc_df, e_df], axis = 1)
# Out:
# No exit found at 148
# No exit found at 154
# No exit found at 206
# No exit found at 216
# No exit found at 237
# No exit found at 248
# No exit found at 250

# %%
rt_e_df = loc_extractor(exit_extractor(rt_loc_df, 'modified_text', exits), exits)
final_rt_df = pd.concat([rt_loc_df, rt_e_df], axis = 1)
# Out:
# No exit found at 34
# No exit found at 76
# No exit found at 80
# No exit found at 81

# %%
final_rt_df.dropna()
# Out:
#                     date                                               text  \
# 4    2019-07-31 18:58:11  updated  object on roadway in st johns on i-95...
# 5    2019-07-31 18:17:07  updated  emergency road construction in st joh...
# 6    2019-07-31 18:03:22  updated  emergency road construction in st joh...
# 7    2019-07-31 17:36:22  updated  planned construction in columbia on i...
# 10   2019-07-31 16:19:08  updated  vehicle on fire in st johns on i-95 s...
# 11   2019-07-31 16:18:07  updated  emergency vehicles in st johns on i-9...
# 25   2019-07-31 11:38:18  updated  vehicle on fire in st johns on i-95 s...
# 26   2019-07-31 11:27:06  new  vehicle on fire in st johns on i-95 south...
# 28   2019-07-31 11:03:08  updated  emergency vehicles in st johns on i-9...
# 29   2019-07-31 10:46:05  updated  emergency vehicles in st johns on i-9...
# 30   2019-07-31 10:44:08  updated  emergency vehicles in st johns on i-9...
# 39   2019-07-31 09:07:07  updated  emergency vehicles in st johns on i-9...
# 40   2019-07-31 08:46:41  new  emergency vehicles in st johns on i-95 so...
# 44   2019-07-31 06:45:10  updated  planned construction in duval on i-29...
# 46   2019-07-31 05:28:09  updated  planned construction in duval on i-29...
# 47   2019-07-31 04:14:28  updated  planned construction in duval on i-10...
# 49   2019-07-31 04:12:29  updated  planned construction in duval on i-29...
# 53   2019-07-31 04:11:23  updated  planned construction in duval on i-29...
# 58   2019-07-31 04:10:33  updated  planned construction in duval on i-29...
# 60   2019-07-31 04:10:32  new  planned construction in duval on i-10 wes...
# 71   2019-07-31 03:04:29  new  planned construction in duval on i-295 e ...
# 78   2019-07-31 02:16:27  updated  planned construction in columbia on i...
# 82   2019-07-31 02:14:10  new  planned construction in duval on i-295 e ...
# 86   2019-07-31 01:35:37  updated  crash in duval on i-295 e north at ex...
# 87   2019-07-31 01:23:13  new  planned construction in duval on i-10 eas...
# 88   2019-07-31 01:17:59  new  planned construction in duval on i-295 w ...
# 89   2019-07-31 01:09:09  new  planned construction in duval on i-295 e ...
# 90   2019-07-31 01:07:10  new  planned construction in duval on i-295 w ...
# 93   2019-07-30 23:18:14  updated  multi-vehicle crash in duval on i-295...
# 94   2019-07-30 22:41:24  updated  traffic congestion in duval on i-295 ...
# 95   2019-07-30 22:17:10  new  traffic congestion in duval on i-295 w no...
# 96   2019-07-30 22:16:12  new  crash in duval on i-295 w north at exit 5...
# 98   2019-07-30 21:51:16  updated  crash in duval on i-95 south at exit ...
# 106  2019-07-30 17:16:12  updated  crash in duval on i-95 north ramp to ...
# 109  2019-07-30 16:08:22  updated  crash in duval on i-95 north ramp to ...
# 110  2019-07-30 15:57:06  new  crash in duval on i-95 north ramp to exit...
# 113  2019-07-30 12:43:13  updated  multi-vehicle crash in duval on i-295...
# 118  2019-07-30 12:23:37  updated  crash in duval on i-295 w south ramp ...
# 124  2019-07-30 11:53:06  updated  multi-vehicle crash in duval on i-95 ...
# 125  2019-07-30 11:39:10  updated  crash in duval on i-95 south at exit ...
#
#          type         username  \
# 4    official  fl511_northeast
# 5    official  fl511_northeast
# 6    official  fl511_northeast
# 7    official  fl511_northeast
# 10   official  fl511_northeast
# 11   official  fl511_northeast
# 25   official  fl511_northeast
# 26   official  fl511_northeast
# 28   official  fl511_northeast
# 29   official  fl511_northeast
# 30   official  fl511_northeast
# 39   official  fl511_northeast
# 40   official  fl511_northeast
# 44   official  fl511_northeast
# 46   official  fl511_northeast
# 47   official  fl511_northeast
# 49   official  fl511_northeast
# 53   official  fl511_northeast
# 58   official  fl511_northeast
# 60   official  fl511_northeast
# 71   official  fl511_northeast
# 78   official  fl511_northeast
# 82   official  fl511_northeast
# 86   official  fl511_northeast
# 87   official  fl511_northeast
# 88   official  fl511_northeast
# 82                  {'Interstate 295 East South Ramp'}  Interstate 295
# 86                        {'East North', 'Interstate'}  Interstate 295
# 87                          {'Exit 357', 'Interstate'}   Interstate 10
# 88            {'Exit 33', 'Interstate 295 West North'}  Interstate 295
# 89                        {'East North', 'Interstate'}  Interstate 295
# 90            {'Exit 10', 'Interstate 295 West South'}  Interstate 295
# 93             {'Exit 5', 'Interstate 295 West North'}  Interstate 295
# 94   {'Interstate 95', 'Exit 5 San Jose', 'Intersta...  Interstate 295
# 95    {'Exit 5 San Jose', 'Interstate 295 West North'}  Interstate 295
# 96   {'Exit 5', '56Pm', 'West North', 'Interstate',...  Interstate 295
# 98   {'Exit 347 Emerson Right Lane', 'Interstate 95...   Interstate 95
# 106           {'Interstate 95 North Ramp To Exit 333'}   Interstate 95
# 109           {'Interstate 95 North Ramp To Exit 333'}   Interstate 95
# 110  {'Interstate 95 North Ramp To Exit 333', 'New ...   Interstate 95
# 113  {'Interstate 95', 'Interstate 295 West South R...  Interstate 295
# 118  {'Interstate 95', 'Interstate 295 West South R...  Interstate 295
# 124                {'Exit 356', 'Interstate 95 South'}   Interstate 95
# 125                {'Exit 356', 'Interstate 95 South'}   Interstate 95
#
#         exits direction                 lat      long
# 4    Exit 318     North            29.91303 -81.41050
# 5    Exit 298     South            29.66032 -81.28373
# 6    Exit 298     South            29.66032 -81.28373
# 7    Exit 296      West  30.267359999999996 -82.75739
# 10   Exit 298     South            29.66032 -81.28373
# 11   Exit 298     South            29.66032 -81.28373
# 25   Exit 298     South            29.66032 -81.28373
# 26   Exit 298     South            29.66032 -81.28373
# 28   Exit 298     South            29.66032 -81.28373
# 29   Exit 298     South            29.66032 -81.28373
# 30   Exit 298     South            29.66032 -81.28373
# 39   Exit 298     South            29.66032 -81.28373
# 40   Exit 298     South            29.66032 -81.28373
# 44    Exit 10      West            30.19177 -81.69811
# 46    Exit 10      West            30.19177 -81.69811
# 47   Exit 359      West  30.320940000000004 -81.71658
# 49    Exit 53      East              30.257 -81.51787
# 53    Exit 53      East              30.257 -81.51787
# 58    Exit 10      West            30.19177 -81.69811
# 60   Exit 359      West  30.320940000000004 -81.71658
# 71    Exit 53      East              30.257 -81.51787
# 78   Exit 296      West  30.267359999999996 -82.75739
# 82    Exit 53      East              30.257 -81.51787
# 86    Exit 40      East              30.434 -81.58155
# 87   Exit 357      East             30.3155 -81.75616
# 88    Exit 33      West            30.45977 -81.67688
# 89    Exit 40      East              30.434 -81.58155
# 90    Exit 10      West            30.19177 -81.69811
# 93     Exit 5      West            30.17924 -81.62420
# 94     Exit 5      West            30.17924 -81.62420
# 95     Exit 5      West            30.17924 -81.62420
# 96     Exit 5      West            30.17924 -81.62420
# 98   Exit 347     South  30.288710000000002 -81.62745
# 106  Exit 333     North            30.10968 -81.50905
# 109  Exit 333     North            30.10968 -81.50905
# 110  Exit 333     North            30.10968 -81.50905
# 113   Exit 61      West            30.16726 -81.55374
# 118   Exit 61      West            30.16726 -81.55374
# 124  Exit 356     South            30.38052 -81.67336
# 125  Exit 356     South            30.38052 -81.67336

# 54   new  object on roadway in duval on i-95 north ...  official
# 69   update  object on roadway in duval on i-295 w ...  official
# 73   update  object on roadway in duval on i-295 w ...  official
# 74   new  unconfirmed object on roadway in duval on...  official
# 75   new  object on roadway in duval on i-295 w nor...  official
# 76   new  unconfirmed traffic congestion in duval o...  official
# 80   new  object on roadway in duval on i-295 w sou...  official
# 81   update  object on roadway in duval on i-295 w ...  official
# 82   update  object on roadway in duval on i-295 w ...  official
# 83   new  unconfirmed object on roadway in duval on...  official
# 87   update  object on roadway in duval on i-295 w ...  official
# 90   new  object on roadway in duval on i-295 w sou...  official
# 111  new  disabled truck in duval on i-95 north ram...  official
# 116  update  crash in duval on i-10 west ramp to ex...  official
# 117  update  crash in duval on i-95 south ramp to e...  official
# 121  update  disabled vehicle in duval on i-295 w n...  official
# 130  update  crash in duval on i-95 north ramp to e...  official
# 131  update  disabled vehicle in suwannee on i-10 w...  official
# 132  update  crash in duval on i-95 north ramp to e...  official
# 134  update  traffic congestion in suwannee on i-10...  official
# 135  new  traffic congestion in columbia on i-10 we...  official
# ..                                                 ...       ...
# 212  new  traffic congestion in duval on i-295 w no...  official
# 213  new  traffic congestion in duval on i-295 w no...  official
# 215  update  traffic congestion in duval on i-10 we...  official
# 220  update  traffic congestion in duval on i-10 we...  official
# 221  update  traffic congestion in duval on i-10 we...  official
# 224  new  disabled truck in duval on i-295 w south ...  official
# 225  update  traffic congestion in duval on i-10 we...  official
# 226  update  traffic congestion in duval on i-10 we...  official
# 228  update  crash in duval on i-10 west ramp to ex...  official
# 229  update  traffic congestion in duval on i-10 we...  official
# 230  update  unconfirmed disabled vehicle in duval ...  official
# 231  new  unconfirmed disabled vehicle in duval on ...  official
# 232  new  traffic congestion in duval on i-10 west ...  official
# 234  new  disabled vehicle in nassau on i-95 north ...  official
# 239  update  traffic congestion in duval on i-95 so...  official
# 240  update  disabled vehicle in duval on i-95 sout...  official
# 241  new  disabled vehicle in duval on i-95 south r...  official
# 242  new  traffic congestion in duval on i-95 south...  official
# 244  new  disabled vehicle in duval on i-95 north r...  official
# 246  update  traffic congestion in duval on i-95 so...  official
# 249  new  disabled vehicle in duval on i-10 west ra...  official
# 251  update  disabled vehicle in duval on i-295 w s...  official
# 253  new  disabled vehicle in duval on i-95 north r...  official
# 254  new  traffic congestion in duval on i-10 east ...  official
# 255  update  crash in duval on i-10 east at exit 35...  official
# 257  new  bridge maintenance operations in duval on...  official
# 260  new  unconfirmed crash in duval on i-95 north ...  official
# 262  new  disabled vehicle in nassau on i-95 north ...  official
# 263  new  disabled vehicle in duval on i-95 north a...  official
# 264  new  disabled vehicle in duval on i-295 w sout...  official
#
#             username                                              tweet  \
# 6    fl511_northeast  NEW  Disabled vehicle in Duval on I-295 E nort...
# 13   fl511_northeast  NEW  Disabled vehicle in Duval on I-295 W sout...
# 25   fl511_northeast  NEW  Disabled vehicle in Duval on I-295 E nort...
# 27   fl511_northeast  NEW  Disabled vehicle in Duval on I-10 east ra...
# 38   fl511_northeast  NEW  Disabled vehicle in Duval on I-95 north r...
# 45   fl511_northeast  UPDATE  Disabled truck in Duval on I-10 east r...
# 46   fl511_northeast  NEW  Unconfirmed disabled vehicle in Duval on ...
# 49   fl511_northeast  UPDATE  Object on roadway in Duval on I-95 sou...
# 52   fl511_northeast  UPDATE  Object on roadway in Duval on I-95 nor...
# 54   fl511_northeast  NEW  Object on roadway in Duval on I-95 north ...
# 69   fl511_northeast  UPDATE  Object on roadway in Duval on I-295 W ...
# 73   fl511_northeast  UPDATE  Object on roadway in Duval on I-295 W ...
# 74   fl511_northeast  NEW  Unconfirmed object on roadway in Duval on...
# 75   fl511_northeast  NEW  Object on roadway in Duval on I-295 W nor...
# 76   fl511_northeast  NEW  Unconfirmed traffic congestion in Duval o...
# 80   fl511_northeast  NEW  Object on roadway in Duval on I-295 W sou...
# 81   fl511_northeast  UPDATE  Object on roadway in Duval on I-295 W ...
# 82   fl511_northeast  UPDATE  Object on roadway in Duval on I-295 W ...
# 83   fl511_northeast  NEW  Unconfirmed object on roadway in Duval on...
# 87   fl511_northeast  UPDATE  Object on roadway in Duval on I-295 W ...
# 90   fl511_northeast  NEW  Object on roadway in Duval on I-295 W sou...
# 111  fl511_northeast  NEW  Disabled truck in Duval on I-95 north ram...
# 116  fl511_northeast  UPDATE  Crash in Duval on I-10 west ramp to Ex...
# 117  fl511_northeast  UPDATE  Crash in Duval on I-95 south ramp to E...
# 121  fl511_northeast  UPDATE  Disabled vehicle in Duval on I-295 W n...
# 130  fl511_northeast  UPDATE  Crash in Duval on I-95 north ramp to E...
# 131  fl511_northeast  UPDATE  Disabled vehicle in Suwannee on I-10 w...
# 132  fl511_northeast  UPDATE  Crash in Duval on I-95 north ramp to E...
# 134  fl511_northeast  UPDATE  Traffic congestion in Suwannee on I-10...
# 135  fl511_northeast  NEW  Traffic congestion in Columbia on I-10 we...
# ..               ...                                                ...
# 212  fl511_northeast  NEW  Traffic congestion in Duval on I-295 W no...
# 213  fl511_northeast  NEW  Traffic congestion in Duval on I-295 W no...
# 215  fl511_northeast  UPDATE  Traffic congestion in Duval on I-10 we...
# 220  fl511_northeast  UPDATE  Traffic congestion in Duval on I-10 we...
# 221  fl511_northeast  UPDATE  Traffic congestion in Duval on I-10 we...
# 224  fl511_northeast  NEW  Disabled truck in Duval on I-295 W south ...
# 225  fl511_northeast  UPDATE  Traffic congestion in Duval on I-10 we...
# 226  fl511_northeast  UPDATE  Traffic congestion in Duval on I-10 we...
# 228  fl511_northeast  UPDATE  Crash in Duval on I-10 west ramp to Ex...
# 229  fl511_northeast  UPDATE  Traffic congestion in Duval on I-10 we...
# 230  fl511_northeast  UPDATE  Unconfirmed disabled vehicle in Duval ...
# 231  fl511_northeast  NEW  Unconfirmed disabled vehicle in Duval on ...
# 232  fl511_northeast  NEW  Traffic congestion in Duval on I-10 west ...
# 234  fl511_northeast  NEW  Disabled vehicle in Nassau on I-95 north ...
# 239  fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 so...
# 240  fl511_northeast  UPDATE  Disabled vehicle in Duval on I-95 sout...
# 241  fl511_northeast  NEW  Disabled vehicle in Duval on I-95 south r...
# 242  fl511_northeast  NEW  Traffic congestion in Duval on I-95 south...
# 244  fl511_northeast  NEW  Disabled vehicle in Duval on I-95 north r...
# 246  fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 so...
# 249  fl511_northeast  NEW  Disabled vehicle in Duval on I-10 west ra...
# 251  fl511_northeast  UPDATE  Disabled vehicle in Duval on I-295 W s...
# 253  fl511_northeast  NEW  Disabled vehicle in Duval on I-95
Florida             1  At New  Disabled Vehicle At Duval At Interstat...
# 264  Florida             1  At New  Disabled Vehicle At Duval At Interstat...
#
#                                               location      interstate  \
# 6                   {'Interstate 295 East North Ramp'}  Interstate 295
# 13   {'Interstate 295 West South Ramp To Exit 22 Co...  Interstate 295
# 25   {'Interstate 295 East North Ramp To Exit 51 Be...  Interstate 295
# 27   {'Interstate 10 East Ramp', 'Interstate 295 We...   Interstate 10
# 38            {'Interstate 95 North Ramp To Exit 366'}   Interstate 95
# 45                         {'Interstate 10 East Ramp'}   Interstate 10
# 46                         {'Interstate 10 East Ramp'}   Interstate 10
# 49            {'Exit 341', 'Interstate 95 South Ramp'}   Interstate 95
# 52                          {'Exit 341', 'Interstate'}   Interstate 95
# 54                          {'Exit 341', 'Interstate'}   Interstate 95
# 69   {'West North', 'Exit 12 Blanding Blvd Right La...  Interstate 295
# 73   {'West North', 'Exit 12 Blanding Blvd Right La...  Interstate 295
# 74          {'Interstate 95 North Ramp', 'Right Lane'}   Interstate 95
# 75   {'West North', 'Exit 12 Blanding Blvd Right La...  Interstate 295
# 76   {'New Kings Rd', 'Exit 30', 'Exit 28', 'Inters...  Interstate 295
# 80                {'Exit 5', 'San Jose', 'Interstate'}  Interstate 295
# 81                  {'Interstate 295 West North Ramp'}  Interstate 295
# 82   {'Interstate 295 West North Ramp', 'Normandy B...  Interstate 295
# 83                  {'Interstate 295 East South Ramp'}  Interstate 295
# 87            {'Exit 32', 'Interstate 295 West South'}  Interstate 295
# 90            {'Exit 32', 'Interstate 295 West South'}  Interstate 295
# 111  {'Interstate 95 North Ramp From Exit 357 Edgew...   Interstate 95
# 116  {'Interstate 10 West Ramp To Exit 356 Intersta...   Interstate 10
# 117           {'Interstate 95 South Ramp To Exit 348'}   Interstate 95
# 121  {'Exit 17', 'Wilson Blvd', 'Interstate 295 Wes...  Interstate 295
# 130  {'Interstate 95 North Ramp To Exit 350 Downtow...   Interstate 95
# 131          {'Exit 283 Us-129', 'Interstate 10 West'}   Interstate 10
# 132  {'Interstate 95 North Ramp To Exit 350', 'Down...   Interstate 95
# 134          {'Exit 283 Us-129', 'Interstate 10 West'}   Interstate 10
# 135  {'Before Mm 314', 'Exit 303', 'Interstate 10 W...   Interstate 10
# ..                                                 ...             ...
# 212  {'Exit 19', 'Normandy Blvd', 'Interstate 295 W...  Interstate 295
# 213  {'Exit 21 Interstate 10', 'Exit 19', 'Normandy...  Interstate 295
# 215  {'Exit 343 Us-301', 'Interstate 10 West From E...   Interstate 10
# 220  {'Exit 343 Us-301', 'Hammond Blvd', 'Interstat...   Interstate 10
# 221  {'Exit 343 Us-301', 'Interstate 10 West From E...   Interstate 10
# 224           {'Exit 10', 'Interstate 295 West South'}  Interstate 295
# 225  {'Interstate 10 West From Exit 356 Interstate ...   Interstate 10
# 226  {'Hammond Blvd', 'Interstate 10 West From Exit...   Interstate 10
# 228  {'Interstate 10 West Ramp To Exit 356 Intersta...   Interstate 10
# 229               {'Interstate 10 West From Exit 351'}   Interstate 10
# 230                {'Interstate 95 South', 'Exit 355'}   Interstate 95
# 231                {'Interstate 95 South', 'Exit 355'}   Interstate 95
# 232               {'Interstate 10 West From Exit 351'}   Interstate 10
# 234  {'Interstate 95 North', 'Exit 380 Us-17 Right ...   Interstate 95
# 239            {'Interstate 95 South Beyond Exit 350'}   Interstate 95
# 240           {'Interstate 95 South Ramp To Exit 344'}   Interstate 95
# 241    {'Interstate 95 South Ramp To Exit 344 Butler'}   Interstate 95
# 242            {'Interstate 95 South Beyond Exit 350'}   Interstate 95
# 244  {'Interstate 95 North Ramp To Exit 337 Interst...   Interstate 95
# 246           {'Interstate 95 South Ramp To Exit 350'}   Interstate 95
# 249            {'Interstate 10 West Ramp To Exit 351'}   Interstate 10
# 251  {'Normandy Blvd', 'Exit 19', 'Interstate 295 W...  Interstate 295
# 253    {'Interstate 95 North Ramp To Exit 344 Butler'}   Interstate 95
# 254                 {'Exit 358', 'Interstate 10 East'}   Interstate 10
# 255                 {'Exit 358', 'Interstate 10 East'}   Interstate 10
# 257           {'Interstate 95 South Ramp To Exit 350'}   Interstate 95
# 260                    {'Interstate 95 North At Exit'}   Interstate 95
# 262  {'Exit 380 Us-17 Left Shoulder', 'Interstate 9...   Interstate 95
# 263                {'Interstate 95 North At Exit 341'}   Interstate 95
# 264    {'Interstate 295 West South Ramp From Exit 30'}  Interstate 295
#
#         exits direction                 lat      long
# 6     Exit 60      East            30.16893 -81.53623
# 13    Exit 22      West            30.33213 -81.76245
# 25    Exit 51      East            30.29054 -81.52207
# 27   Exit 356      East  30.315179999999998 -81.77517
# 38   Exit 366     North            30.51338 -81.63441
# 45   Exit 360      East  30.320859999999996 -81.70904
# 46   Exit 360      East  30.320859999999996 -81.70904
# 49   Exit 341     South            30.21727 -81.56876
# 52   Exit 341     North            30.21727 -81.56876
# 54   Exit 341     North            30.21727 -81.56876
# 69    Exit 12      West            30.19137 -81.71509
# 73    Exit 12      West            30.19137 -81.71509
# 74   Exit 341     North            30.21727 -81.56876
# 75    Exit 12      West            30.19137 -81.71509
# 76    Exit 30      West            30.43487 -81.72636
# 80     Exit 5      West            30.17924 -81.62420
# 81    Exit 10      West            30.19177 -81.69811
# 82    Exit 19      West            30.29471 -81.77069
# 83    Exit 58      East            30.18663 -81.51383
# 87    Exit 32      West            30.45315 -81.70980
# 90    Exit 32      West            30.45315 -81.70980
# 111  Exit 357     North            30.39003 -81.66778
# 116  Exit 356      West  30.315179999999998 -81.77517
# 117  Exit 348     South            30.30263 -81.64124
# 121   Exit 17      West             30.2669 -81.76590
# 130  Exit 350     North            30.31451 -81.66867
# 131  Exit 283      West  30.333740000000002 -82.96652
# 132  Exit 350     North            30.31451 -81.66867
# 134  Exit 283      West  30.333740000000002 -82.96652
# 135  Exit 303      West            30.24193 -82.64245
# ..        ...       ...                 ...       ...
# 212   Exit 19      West            30.29471 -81.77069
# 213   Exit 19      West            30.29471 -81.77069
# 215  Exit 357      West             30.3155 -81.75616
# 220  Exit 355      West  30.314759999999996 -81.79673
# 221  Exit 356      West  30.315179999999998 -81.77517
# 224   Exit 10      West            30.19177 -81.69811
# 225  Exit 356      West  30.315179999999998 -81.77517
# 226  Exit 355      West  30.314759999999996 -81.79673
# 228  Exit 356      West  30.315179999999998 -81.77517
# 229  Exit 351      West            30.30915 -81.84853
# 230  Exit 355     South            30.36142 -81.66860
# 231  Exit 355     South            30.36142 -81.66860
# 232  Exit 351      West            30.30915 -81.84853
# 234  Exit 380     North            30.71175 -81.67104
# 239  Exit 350     South            30.31451 -81.66867
# 240  Exit 344     South            30.24393 -81.58858
# 241  Exit 344     South            30.24393 -81.58858
# 242  Exit 350     South            30.31451 -81.66867
# 244  Exit 337     North            30.15859 -81.55057
# 246  Exit 350     South            30.31451 -81.66867
# 249  Exit 351      West            30.30915 -81.84853
# 251   Exit 19      West            30.29471 -81.77069
# 253  Exit 344     North            30.24393 -81.58858
# 254  Exit 358      East            30.31721 -81.73408
# 255  Exit 358      East            30.31721 -81.73408
# 257  Exit 350     South            30.31451 -81.66867
# 260  Exit 357     North            30.39003 -81.66778
# 262  Exit 380     North            30.71175 -81.67104
# 263  Exit 341     North            30.21727 -81.56876
# 264   Exit 30      West            30.43487 -81.72636
#
# [94 rows x 14 columns]

# %%
final_df.to_csv("../data/Loc_Extracted/tweet_locations_sample_07312019.csv", index = False)
rt_loc_df.to_csv("../data/Loc_Extracted/rt_locations_sample_07312019.csv", index = False)

# %% [markdown]
# ## SpaCy Visualization

# %%
nlp = spacy.load("en_core_web_sm")
text = final_rt_df.iloc[110]['modified_text']
doc = nlp(text)
displacy.render(doc, style="ent", jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5">At
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     New  Crash At Duval
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  At
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Interstate 95 North Ramp To Exit 333
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  Sr-9B Off-Ramp Closed  Last Updated At
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     11 56
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  58Am  #
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Fl511
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#   </div>

# %%
text = final_rt_df.iloc[110]['modified_text']
doc = nlp(text)
displacy.render(doc, style="dep", jupyter = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-24a8497b35dc> in <module>
#       1 text = final_rt_df.iloc[110]['modified_text']
#       2 doc = nlp(text)
# ----> 3 displacy.render(doc, style="dep", jupyter = True)
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/spacy/displacy/__init__.py in render(docs, style, page, minify, jupyter, options, manual)
#      37     renderer, converter = factories[style]
#      38     renderer = renderer(options=options)
# ---> 39     parsed = [converter(doc, options) for doc in docs] if not manual else docs
#      40     _html['parsed'] = renderer.render(parsed, page=page, minify=minify).strip()
#      41     html = _html['parsed']
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/spacy/displacy/__init__.py in <listcomp>(.0)
#      37     renderer, converter = factories[style]
#      38     renderer = renderer(options=options)
# ---> 39     parsed = [converter(doc, options) for doc in docs] if not manual else docs
#      40     _html['parsed'] = renderer.render(parsed, page=page, minify=minify).strip()
#      41     html = _html['parsed']
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/spacy/displacy/__init__.py in parse_deps(orig_doc, options)
#      87     RETURNS (dict): Generated dependency parse keyed by words and arcs.
#      88     """
# ---> 89     doc = Doc(orig_doc.vocab).from_bytes(orig_doc.to_bytes())
#      90     if not doc.is_parsed:
#      91         user_warning(Warnings.W005)
#
# doc.pyx in spacy.tokens.doc.Doc.to_bytes()
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/spacy/util.py in to_bytes(getters, exclude)
#     484         if key not in exclude:
#     485             serialized[key] = getter()
# --> 486     return msgpack.dumps(serialized, use_bin_type=True, encoding='utf8')
#     487
#     488
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/msgpack_numpy.py in packb(o, **kwargs)
#     194     """
#     195
# --> 196     return Packer(**kwargs).pack(o)
#     197
#     198 def unpack(stream, **kwargs):
#
# TypeError: __init__() got an unexpected keyword argument 'encoding'
