# %% [markdown]
# # Location Extraction and Spacy Word Vectorization

# %%
import pandas as pd
import re
import spacy
import string

import geocoder

# %%
# Read in csv with Tweets
twitter_closures = pd.read_csv("../data/Cleaned_Tweets/cleaned_historic_official_07242019.csv")

twitter_closures = twitter_closures[['text', 'type', 'username', 'tweet', 'road_closure']]

# Print DF shape
print(twitter_closures.shape)

# Show head 
twitter_closures.head()
# Out:
# (43016, 5)
#                                                 text      type username  \
# 0  Douglas County Crash - EB I-20 b4 Post Rd  exi...  official  GDOTATL
# 1  With rain on the way - we have an important me...  official  GDOTATL
# 2  Much needed rain is headed our way    please b...  official  GDOTATL
# 3  Happy Thanksgiving  Please drive safe and pati...  official  GDOTATL
# 4  Have a safe Thanksgiving  Put away your cell p...  official  GDOTATL
#
#                                                tweet  road_closure
# 0  Douglas County Crash - EB I-20 b4 Post Rd  exi...             0
# 1  With rain on the way - we have an important me...             0
# 2  Much needed rain is headed our way    please b...             0
# 3  Happy Thanksgiving  Please drive safe and pati...             0
# 4  Have a safe Thanksgiving  Put away your cell p...             0

# %% [markdown]
# ## SpaCy Preprocessing

# %%
# Create new columns to transfer modified tweet text. Five versions of tweets will be created.
twitter_closures['modified_text'] = ''
twitter_closures['location'] = ''

# Show modified DF
twitter_closures.head(2)
# Out:
#                                                 text      type username  \
# 0  Douglas County Crash - EB I-20 b4 Post Rd  exi...  official  GDOTATL
# 1  With rain on the way - we have an important me...  official  GDOTATL
#
#                                                tweet  road_closure  \
# 0  Douglas County Crash - EB I-20 b4 Post Rd  exi...             0
# 1  With rain on the way - we have an important me...             0
#
#   modified_text location
# 0
# 1

# %%
format_dict = {"hwy": "Highway ",
            "Blvd": "Boulevard",
            " st": "street",
           "CR ": "Country Road ",
           "SR ": "State Road",
           "I-": "Interstate ",
           "EB ": "Eastbound ",
           "WB ": "Westbound ",
           "SB ": "Southbound",
           "NB ": "Northbound",
           " on ": " at ",
           " E ": " East ",
           " W ": " West ",
           " S ": " South",
           " N ": " North",
           "mi ": "mile ",
           "between ": "at ",
           "Between ": "at ",
           "In ": "in ",
           " in ": " at "}

# %%
def spacy_cleaner(df, col, word_dict):
    modified_text = "At " + df[col].replace(word_dict, regex=True)
    modified_text = modified_text.str.title()
    return modified_text

# %%
# run the text cleaning function and test results
twitter_closures['modified_text'] = spacy_cleaner(twitter_closures, 'text', format_dict)

# %%
twitter_closures['username'].unique()
# Out:
# array(['GDOTATL', 'SCDOTMidlands', 'SCDOTPeeDee', 'SCDOTLowCountry',
#        'SCDOTPiedmont', '511statewideva', 'fl511_panhandl', '511Georgia',
#        'fl511_state', 'fl511_northeast', 'fl511_southeast',
#        'fl511_southwest', 'fl511_tampabay', 'fl511_central',
#        '511centralva', '511hamptonroads', '511northernva',
#        'NCDOT_Westmtn', 'NCDOT_Triangle', 'NCDOT_Piedmont',
#        'NCDOT_Charlotte', 'NCDOT_Asheville', 'NCDOT_Scoast',
#        'NCDOT_Ncoast'], dtype=object)

# %%
test_df = twitter_closures[(twitter_closures['road_closure'] == 1) & (twitter_closures['username'] == 'NCDOT_Triangle')].head(100)

# %%
def get_loc(df, text_column, location_column):
    
    # Use Spacy to extract location names from `text` column
    for i in range(len(df)):
        
        #instantiate spacy model
        nlp = spacy.load("en_core_web_sm")
        
        # create documewnt from modified text column
        doc = nlp(df[text_column].iloc[i])
        
        locations = set()
        
        # loop through every entity in the doc
        for ent in doc.ents:
            
            # find entities labelled as places
            if (ent.label_=='GPE') or (ent.label_=='FAC') or (ent.label_ == 'LOC'):
                
                # put locations in a set
                locations.add(ent.text)
                df[location_column].iloc[i] = locations
                
    return df[location_column]

# %%
test = get_loc(test_df, 'modified_text', 'location')
# Out:
# C:\Users\templ\Anaconda3\envs\dsi\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
test_df['location'] = test

# %%
test_df
# Out:
#                                                     text      type  \
# 39347  I-40, Mile Marker 295, East, Raleigh, Wake, Ve...  official
# 39348  I-40, Mile Marker 295, East, Raleigh, Wake, Ve...  official
# 39349  I-40, Mile Marker 295, East, Raleigh, Wake, Ve...  official
# 39350  I-40, Mile Marker 300, East, Raleigh, Wake, Ve...  official
# 39351  I-540, Mile Marker 2, East, Raleigh, Wake, Veh...  official
# 39352  I-40, Mile Marker 297, East, Raleigh, Wake, Di...  official
# 39353  I-40, Mile Marker 279, West, Durham, Durham, V...  official
# 39354  I-540, In Raleigh Wake, Vehicle Accident, Lane...  official
# 39355  I-40, Mile Marker 297, East, Raleigh, Wake, Di...  official
# 39356  I-40, Mile Marker 270, West, Durham, Durham, V...  official
# 39357  I-40, Mile Marker 269, West, Chapel Hill, Oran...  official
# 39358  Triangle Expressway, Mile Marker 57, North, Ap...  official
# 39359  I-440, Mile Marker 1, West, Raleigh, Wake, Veh...  official
# 39360  I-40, Mile Marker 312, West, Clayton, Johnston...  official
# 39361  Capital Blvd, Near Raleigh Wake, Vehicle Accid...  official
# 39362  Capital Blvd, Near Raleigh Wake, Vehicle Accid...  official
# 39363  I-95, Mile Marker 93, North, Four Oaks, Johnst...  official
# 39364  Capital Blvd, In Raleigh Wake, Vehicle Acciden...  official
# 39365  I-40, Mile Marker 295, West, Raleigh, Wake, Ve...  official
# 39366  I-40, Mile Marker 297, West, Raleigh, Wake, Ve...  official
# 39367  I-40, Mile Marker 293, West, Raleigh, Wake, Ve...  official
# 39368  Devil Race Trck, Near Four Oaks Johnston, Main...  official
# 39369  I-95, Mile Marker 96 to 95, South, Smithfield,...  official
# 39370  Triangle Expressway, Mile Marker 54, South, Mo...  official
# 39371  I-40, Mile Marker 287, West, Cary, Wake, Vehic...  official
# 39372  I-40, Mile Marker 281, East, Durham, Durham, V...  official
# 39373  I-40, Mile Marker 281, East, Durham, Durham, V...  official
# 39374  I-95, Mile Marker 92 to 91, South, Smithfield,...  official
# 39375  I-95, Mile Marker 91 to 92, North, Smithfield,...  official
# 39376  I-85, Mile Marker 203, South, Oxford, Granvill...  official
# ...                                                  ...       ...
# 39417  I-40, Mile Marker 300, West, Raleigh, Wake, Di...  official
# 39418  I-40, Mile Marker 285, West, Raleigh, Wake, Ve...  official
# 39419  I-40, Mile Marker 285, West, Raleigh, Wake, Ve...  official
# 39420  I-40, Mile Marker 313, East, Benson, Johnston,...  official
# 39421  US-64   US-264, Mile Marker 430, West, Wendell...  official
# 39422  US-64   US-264, Mile Marker 430, West, Wendell...  official
# 39423  I-440, Mile Marker 2, West, Raleigh, Wake, Oth...  official
# 39424  I-40, Mile Marker 270, West, Chapel Hill, Oran...  official
# 39425  I-40, Mile Marker 297, West, Raleigh, Wake, Ve...  official
# 39426  I-540, Mile Marker 8, East, Raleigh, Wake, Veh...  official
# 39427  I-540, Mile Marker 8, East, Raleigh, Wake, Veh...  official
# 39428  I-85, Mile Marker 184, North, Gorman, Durham, ...  official
# 39429  I-85, Mile Marker 184, North, Gorman, Durham, ...  official
# 39430  Durham Freeway, Mile Marker 11, North, Durham,...  official
# 39431  I-40, Mile Marker 301, East, Raleigh, Wake, Ve...  official
# 39432  Glenwood Avenue, In Raleigh Wake, Vehicle Acci...  official
# 39433  I-85, Mile Marker 182, North, Durham, Durham, ...  official
# 39434  I-85, Mile Marker 182, North, Durham, Durham, ...  official
# 39435  I-40, Mile Marker 273, East, Durham, Durham, V...  official
# 39436  S Saunders, In Raleigh Wake, Vehicle Accident,...  official
# 39437  South Saunders St, In Raleigh Wake, Vehicle Ac...  official
# 39438  I-40, Mile Marker 296, West, Raleigh, Wake, Di...  official
# 39439  I-40, Mile Marker 296, West, Raleigh, Wake, Di...  official
# 39440  I-40, Mile Marker 270, West, Chapel Hill, Oran...  official
# 39441  I-85, Mile Marker 163, North, Hillsborough, Or...  official
# 39442  I-85, Mile Marker 163, North, Hillsborough, Or...  official
# 39443  I-440, Mile Marker 1, West, Raleigh, Wake, Veh...  official
# 39444  Wake Forest Road, In Raleigh Wake, Disabled Ve...  official
# 39445  I-440, Mile Marker 10, West, Raleigh, Wake, Di...  official
# 39446  I-85, Mile Marker 171, South, Hillsborough, Or...  official
#
#              username                                              tweet  \
# 39347  NCDOT_Triangle  I-40, Mile Marker 295, East, Raleigh, Wake, Ve...
# 39348  NCDOT_Triangle  I-40, Mile Marker 295, East, Raleigh, Wake, Ve...
# 39349  NCDOT_Triangle  I-40, Mile Marker 295, East, Raleigh, Wake, Ve...
# 39350  NCDOT_Triangle  I-40, Mile Marker 300, East, Raleigh, Wake, Ve...
# 39351  NCDOT_Triangle  I-540, Mile Marker 2, East, Raleigh, Wake, Veh...
# 39352  NCDOT_Triangle  I-40, Mile Marker 297, East, Raleigh, Wake, Di...
# 39353  NCDOT_Triangle  I-40, Mile Marker 279, West, Durham, Durham, V...
# 39354  NCDOT_Triangle  I-540, In Raleigh Wake, Vehicle Accident, Lane...
# 39355  NCDOT_Triangle  I-40, Mile Marker 297, East, Raleigh, Wake, Di...
# 39356  NCDOT_Triangle  I-40, Mile Marker 270, West, Durham, Durham, V...
# 39357  NCDOT_Triangle  I-40, Mile Marker 269, West, Chapel Hill, Oran...
# 39358  NCDOT_Triangle  Triangle Expressway, Mile Marker 57, North, Ap...
# 39359  NCDOT_Triangle  I-440, Mile Marker 1, West, Raleigh, Wake, Veh...
# 39360  NCDOT_Triangle  I-40, Mile Marker 312, West, Clayton, Johnston...
# 39361  NCDOT_Triangle  Capital Blvd, Near Raleigh Wake, Vehicle Accid...
# 39362  NCDOT_Triangle  Capital Blvd, Near Raleigh Wake, Vehicle Accid...
# 39363  NCDOT_Triangle  I-95, Mile Marker 93, North, Four Oaks, Johnst...
# 39364  NCDOT_Triangle  Capital Blvd, In Raleigh Wake, Vehicle Acciden...
# 39365  NCDOT_Triangle  I-40, Mile Marker 295, West, Raleigh, Wake, Ve...
# 39366  NCDOT_Triangle  I-40, Mile Marker 297, West, Raleigh, Wake, Ve...
# 39367  NCDOT_Triangle  I-40, Mile Marker 293, West, Raleigh, Wake, Ve...
# 39368  NCDOT_Triangle  Devil Race Trck, Near Four Oaks Johnston, Main...
# 39369  NCDOT_Triangle  I-95, Mile Marker 96 to 95, South, Smithfield,...
# 39370  NCDOT_Triangle  Triangle Expressway, Mile Marker 54, South, Mo...
# 39371  NCDOT_Triangle  I-40, Mile Marker 287, West, Cary, Wake, Vehic...
# 39372  NCDOT_Triangle  I-40, Mile Marker 281, East, Durham, Durham, V...
# 39373  NCDOT_Triangle  I-40, Mile Marker 281, East, Durham, Durham, V...
# 39374  NCDOT_Triangle  I-95, Mile Marker 92 to 91, South, Smithfield,...
# 39375  NCDOT_Triangle  I-95, Mile Marker 91 to 92, North, Smithfield,...
# 39376  NCDOT_Triangle  I-85, Mile Marker 203, South, Oxford, Granvill...
# ...               ...                                                ...
# 39417  NCDOT_Triangle  I-40, Mile Marker 300, West, Raleigh, Wake, Di...
# 39418  NCDOT_Triangle  I-40, Mile Marker 285, West, Raleigh, Wake, Ve...
# 39419  NCDOT_Triangle  I-40, Mile Marker 285, West, Raleigh, Wake, Ve...
# 39420  NCDOT_Triangle  I-40, Mile Marker 313, East, Benson, Johnston,...
# 39421  NCDOT_Triangle  US-64   US-264, Mile Marker 430, West, Wendell...
# 39422  NCDOT_Triangle  US-64   US-264, Mile Marker 430, West, Wendell...
# 39423  NCDOT_Triangle  I-440, Mile Marker 2, West, Raleigh, Wake, Oth...
# 39424  NCDOT_Triangle  I-40, Mile Marker 270, West, Chapel Hill, Oran...
# 39425  NCDOT_Triangle  I-40, Mile Marker 297, West, Raleigh, Wake, Ve...
# 39426  NCDOT_Triangle  I-540, Mile Marker 8, East, Raleigh, Wake, Veh...
# 39427  NCDOT_Triangle  I-540, Mile Marker 8, East, Raleigh, Wake, Veh...
# 39428  NCDOT_Triangle  I-85, Mile Marker 184, North, Gorman, Durham, ...
# 39429  NCDOT_Triangle  I-85, Mile Marker 184, North, Gorman, Durham, ...
# 39430  NCDOT_Triangle  Durham Freeway, Mile Marker 11, North, Durham,...
# 39431  NCDOT_Triangle  I-40, Mile Marker 301, East, Raleigh, Wake, Ve...
# 39432  NCDOT_Triangle  Glenwood Avenue, In Raleigh Wake, Vehicle Acci...
# 39433  NCDOT_Triangle  I-85, Mile Marker 182, North, Durham, Durham, ...
# 39434  NCDOT_Triangle  I-85, Mile Marker 182, North, Durham, Durham, ...
# 39435  NCDOT_Triangle  I-40, Mile Marker 273, East, Durham, Durham, V...
# 39436  NCDOT_Triangle  S Saunders, In Raleigh Wake, Vehicle Accident,...
# 39437  NCDOT_Triangle  South Saunders St, In Raleigh Wake, Vehicle Ac...
# 39438  NCDOT_Triangle  I-40, Mile Marker 296, West, Raleigh, Wake, Di...
# 39439  NCDOT_Triangle  I-40, Mile Marker 296, West, Raleigh, Wake, Di...
# 39440  NCDOT_Triangle  I-40, Mile Marker 270, West, Chapel Hill, Oran...
# 39441  NCDOT_Triangle  I-85, Mile Marker 163, North, Hillsborough, Or...
# 39442  NCDOT_Triangle  I-85, Mile Marker 163, North, Hillsborough, Or...
# 39443  NCDOT_Triangle  I-440, Mile Marker 1, West, Raleigh, Wake, Veh...
# 39444  NCDOT_Triangle  Wake Forest Road, In Raleigh Wake, Disabled Ve...
# 39445  NCDOT_Triangle  I-440, Mile Marker 10, West, Raleigh, Wake, Di...
# 39446  NCDOT_Triangle  I-85, Mile Marker 171, South, Hillsborough, Or...
#
#        road_closure                                      modified_text  \
# 39347             1  At Interstate 40, Mile Marker 295, East, Ralei...
# 39348             1  At Interstate 40, Mile Marker 295, East, Ralei...
# 39349             1  At Interstate 40, Mile Marker 295, East, Ralei...
# 39350             1  At Interstate 40, Mile Marker 300, East, Ralei...
# 39351             1  At Interstate 540, Mile Marker 2, East, Raleig...
# 39352             1  At Interstate 40, Mile Marker 297, East, Ralei...
# 39353             1  At Interstate 40, Mile Marker 279, West, Durha...
# 39354             1  At Interstate 540, In Raleigh Wake, Vehicle Ac...
# 39355             1  At Interstate 40, Mile Marker 297, East, Ralei...
# 39356             1  At Interstate 40, Mile Marker 270, West, Durha...
# 39357             1  At Interstate 40, Mile Marker 269, West, Chape...
# 39358             1  At Triangle Expressway, Mile Marker 57, North,...
# 39359             1  At Interstate 440, Mile Marker 1, West, Raleig...
# 39360             1  At Interstate 40, Mile Marker 312, West, Clayt...
# 39361             1  At Capital Boulevard, Near Raleigh Wake, Vehic...
# 39362             1  At Capital Boulevard, Near Raleigh Wake, Vehic...
# 39363             1  At Interstate 95, Mile Marker 93, North, Four ...
# 39364             1  At Capital Boulevard, In Raleigh Wake, Vehicle...
# 39365             1  At Interstate 40, Mile Marker 295, West, Ralei...
# 39366             1  At Interstate 40, Mile Marker 297, West, Ralei...
# 39367             1  At Interstate 40, Mile Marker 293, West, Ralei...
# 39368             1  At Devil Race Trck, Near Four Oaks Johnston, M...
# 39369             1  At Interstate 95, Mile Marker 96 To 95, South,...
# 39370             1  At Triangle Expressway, Mile Marker 54, South,...
# 39371             1  At Interstate 40, Mile Marker 287, West, Cary,...
# 39372             1  At Interstate 40, Mile Marker 281, East, Durha...
# 39373             1  At Interstate 40, Mile Marker 281, East, Durha...
# 39374             1  At Interstate 95, Mile Marker 92 To 91, South,...
# 39375             1  At Interstate 95, Mile Marker 91 To 92, North,...
# 39376             1  At Interstate 85, Mile Marker 203, South, Oxfo...
# ...             ...                                                ...
# 39417             1  At Interstate 40, Mile Marker 300, West, Ralei...
# 39418             1  At Interstate 40, Mile Marker 285, West, Ralei...
# 39419             1  At Interstate 40, Mile Marker 285, West, Ralei...
# 39420             1  At Interstate 40, Mile Marker 313, East, Benso...
# 39421             1  At Us-64   Us-264, Mile Marker 430, West, Wend...
# 39422             1  At Us-64   Us-264, Mile Marker 430, West, Wend...
# 39423             1  At Interstate 440, Mile Marker 2, West, Raleig...
# 39424             1  At Interstate 40, Mile Marker 270, West, Chape...
# 39425             1  At Interstate 40, Mile Marker 297, West, Ralei...
# 39426             1  At Interstate 540, Mile Marker 8, East, Raleig...
# 39427             1  At Interstate 540, Mile Marker 8, East, Raleig...
# 39428             1  At Interstate 85, Mile Marker 184, North, Gorm...
# 39429             1  At Interstate 85, Mile Marker 184, North, Gorm...
# 39430             1  At Durham Freeway, Mile Marker 11, North, Durh...
# 39431             1  At Interstate 40, Mile Marker 301, East, Ralei...
# 39432             1  At Glenwood Avenue, In Raleigh Wake, Vehicle A...
# 39433             1  At Interstate 85, Mile Marker 182, North, Durh...
# 39434             1  At Interstate 85, Mile Marker 182, North, Durh...
# 39435             1  At Interstate 40, Mile Marker 273, East, Durha...
# 39436             1  At S Saunders, In Raleigh Wake, Vehicle Accide...
# 39437             1  At South Saunders St, In Raleigh Wake, Vehicle...
# 39438             1  At Interstate 40, Mile Marker 296, West, Ralei...
# 39439             1  At Interstate 40, Mile Marker 296, West, Ralei...
# 39440             1  At Interstate 40, Mile Marker 270, West, Chape...
# 39441             1  At Interstate 85, Mile Marker 163, North, Hill...
# 39442             1  At Interstate 85, Mile Marker 163, North, Hill...
# 39443             1  At Interstate 440, Mile Marker 1, West, Raleig...
# 39444             1  At Wake Forest Road, In Raleigh Wake, Disabled...
# 39445             1  At Interstate 440, Mile Marker 10, West, Ralei...
# 39446             1  At Interstate 85, Mile Marker 171, South, Hill...
#
#                                            location
# 39347                         {East, Interstate 40}
# 39348                         {East, Interstate 40}
# 39349                         {East, Interstate 40}
# 39350                         {East, Interstate 40}
# 39351                        {East, Interstate 540}
# 39352                         {East, Interstate 40}
# 39353                 {Durham, Interstate 40, West}
# 39354                {Raleigh Wake, Interstate 540}
# 39355                         {East, Interstate 40}
# 39356                 {Durham, Interstate 40, West}
# 39357                         {Interstate 40, West}
# 39358           {Triangle Expressway, North, Apex,}
# 39359                        {Interstate 440, West}
# 39360                         {Interstate 40, West}
# 39361                           {Capital Boulevard}
# 39362                           {Capital Boulevard}
# 39363              {Johnston, Interstate 95, North}
# 39364
# 39365                         {Interstate 40, West}
# 39366                               {Interstate 40}
# 39367                         {Interstate 40, West}
# 39368
# 39369            {Smithfield, Interstate 95, South}
# 39370                  {Triangle Expressway, South}
# 39371                         {Interstate 40, West}
# 39372                 {East, Interstate 40, Durham}
# 39373                 {East, Interstate 40, Durham}
# 39374  {Johnston, Smithfield, Interstate 95, South}
# 39375  {Johnston, Interstate 95, North, Smithfield}
# 39376     {Oxford, Interstate 85, Granville, South}
# ...                                             ...
# 39417                               {Interstate 40}
# 39418                         {Interstate 40, West}
# 39419                         {Interstate 40, West}
# 39420                         {East, Interstate 40}
# 39421                                        {West}
# 39422                                        {West}
# 39423                        {Interstate 440, West}
# 39424                  {11 26, Interstate 40, West}
# 39425                               {Interstate 40}
# 39426                        {East, Interstate 540}
# 39427                        {East, Interstate 540}
# 39428                               {Interstate 85}
# 39429                               {Interstate 85}
# 39430       {Durham, Durham Freeway, North, Durham}
# 39431                         {East, Interstate 40}
# 39432                             {Glenwood Avenue}
# 39433                {Durham, Interstate 85, North}
# 39434                {Durham, Interstate 85, North}
# 39435                 {East, Interstate 40, Durham}
# 39436
# 39437                           {South Saunders St}
# 39438                         {Interstate 40, West}
# 39439                         {Interstate 40, West}
# 39440                         {Interstate 40, West}
# 39441          {North, Hillsborough, Interstate 85}
# 39442          {North, Hillsborough, Interstate 85}
# 39443                        {Interstate 440, West}
# 39444                            {Wake Forest Road}
# 39445                        {Interstate 440, West}
# 39446                        {Interstate 85, South}
#
# [100 rows x 7 columns]
