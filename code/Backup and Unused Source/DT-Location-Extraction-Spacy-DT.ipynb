# %% [markdown]
# # Location Extraction and Spacy Word Vectorization

# %%
import pandas as pd
import re
import spacy
import string

# %%
# Read in csv with Tweets
twitter_closures = pd.read_csv("../data/Cleaned_Tweets/cleaned_historic_official_07252019.csv")

twitter_closures = twitter_closures[['text', 'type', 'username', 'tweet', 'road_closure']]

# Print DF shape
print(twitter_closures.shape)

# Show head 
twitter_closures.head()
# Out:
# (43016, 5)
#                                                 text      type username  \
# 0  Douglas County Crash - EB I-20 b4 Post Rd  exi...  official  GDOTATL
# 1  With rain on the way - we have an important me...  official  GDOTATL
# 2  Much needed rain is headed our way    please b...  official  GDOTATL
# 3  Happy Thanksgiving  Please drive safe and pati...  official  GDOTATL
# 4  Have a safe Thanksgiving  Put away your cell p...  official  GDOTATL
#
#                                                tweet  road_closure
# 0  Douglas County Crash - EB I-20 b4 Post Rd  exi...             0
# 1  With rain on the way - we have an important me...             0
# 2  Much needed rain is headed our way    please b...             0
# 3  Happy Thanksgiving  Please drive safe and pati...             0
# 4  Have a safe Thanksgiving  Put away your cell p...             0

# %% [markdown]
# ## SpaCy Preprocessing

# %%
# Create new columns to transfer modified tweet text. Five versions of tweets will be created.
twitter_closures['modified_text'] = ''
twitter_closures['location'] = ''

# Show modified DF
twitter_closures.head(2)
# Out:
#                                                 text      type username  \
# 0  Douglas County Crash - EB I-20 b4 Post Rd  exi...  official  GDOTATL
# 1  With rain on the way - we have an important me...  official  GDOTATL
#
#                                                tweet  road_closure  \
# 0  Douglas County Crash - EB I-20 b4 Post Rd  exi...             0
# 1  With rain on the way - we have an important me...             0
#
#   modified_text location
# 0
# 1

# %%
format_dict = {"hwy": "Highway ",
            "Blvd": "Boulevard",
            " st": "street",
           "CR ": "Country Road ",
           "SR ": "State Road",
           "I-": "Interstate ",
           "EB ": "Eastbound ",
           "WB ": "Westbound ",
           "SB ": "Southbound",
           "NB ": "Northbound",
           " on ": " at ",
           " E ": " East ",
           " W ": " West ",
           " S ": " South",
           " N ": " North",
           "mi ": "mile ",
           "between ": "at ",
           "Between ": "at ",
           "In ": "in ",
           " in ": " at "}

# %%
def spacy_cleaner(df, col, word_dict):
    modified_text = "At " + df[col].replace(word_dict, regex=True)
    modified_text = modified_text.str.title()
    return modified_text

# %%
# run the text cleaning function and test results
twitter_closures['modified_text'] = spacy_cleaner(twitter_closures, 'text', format_dict)

# %%
twitter_closures['username'].unique()
# Out:
# array(['GDOTATL', 'SCDOTMidlands', 'SCDOTPeeDee', 'SCDOTLowCountry',
#        'SCDOTPiedmont', '511statewideva', 'fl511_panhandl', '511Georgia',
#        'fl511_state', 'fl511_northeast', 'fl511_southeast',
#        'fl511_southwest', 'fl511_tampabay', 'fl511_central',
#        '511centralva', '511hamptonroads', '511northernva',
#        'NCDOT_Westmtn', 'NCDOT_Triangle', 'NCDOT_Piedmont',
#        'NCDOT_Charlotte', 'NCDOT_Asheville', 'NCDOT_Scoast',
#        'NCDOT_Ncoast'], dtype=object)

# %%
test_df = twitter_closures[(twitter_closures['road_closure'] == 1) & (twitter_closures['username'] == 'fl511_northeast')].head(100)

# %%
def get_loc(df, text_column, location_column):
    
    # Use Spacy to extract location names from `text` column
    for i in range(len(df)):
        
        #instantiate spacy model
        nlp = spacy.load("en_core_web_sm")
        
        # create documewnt from modified text column
        doc = nlp(df[text_column].iloc[i])
        
        locations = set()
        
        # loop through every entity in the doc
        for ent in doc.ents:
            
            # find entities labelled as places
            if (ent.label_=='GPE') or (ent.label_=='FAC') or (ent.label_ == 'LOC'):
                
                # put locations in a set
                locations.add(ent.text)
                df[location_column].iloc[i] = locations
                
    return df[location_column]

# %%
test = get_loc(test_df, 'modified_text', 'location')
# Out:
# /Users/davidtrichter/anaconda3/envs/dsi/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
test_df['location'] = test
test_df.head(20)
# Out:
#                                                     text      type  \
# 19213  NEW  Crash in Duval on I-295 E north beyond Ph...  official
# 19214  CLEARED  Traffic congestion in Duval on I-95 n...  official
# 19215  CLEARED  Traffic congestion in Duval on I-295 ...  official
# 19216  UPDATE  Traffic congestion in Duval on I-95 no...  official
# 19217  CLEARED  Traffic congestion in Duval on I-295 ...  official
# 19218  CLEARED  Traffic congestion in Duval on I-95 s...  official
# 19219  CLEARED  Traffic congestion in Duval on I-295 ...  official
# 19220  CLEARED  Traffic congestion in Duval on SR-202...  official
# 19221  UPDATE  Traffic congestion in Duval on I-295 W...  official
# 19222  CLEARED  Traffic congestion in Duval on I-95 s...  official
# 19223  CLEARED  Traffic congestion in Duval on SR-202...  official
# 19224  CLEARED  Traffic congestion in Duval on I-295 ...  official
# 19225  CLEARED  Traffic congestion in Duval on I-95 s...  official
# 19226  CLEARED  Crash in Duval on I-95 south at Exit ...  official
# 19227  CLEARED  Unconfirmed disabled vehicle in Duval...  official
# 19228  UPDATE  Crash in Duval on I-95 south at Exit 3...  official
# 19229  UPDATE  Traffic congestion in Duval on I-95 so...  official
# 19230  CLEARED  Disabled vehicle in Duval on SR-202  ...  official
# 19231  UPDATE  Traffic congestion in Duval on I-295 E...  official
# 19232  CLEARED  Traffic congestion in Duval on I-295 ...  official
#
#               username                                              tweet  \
# 19213  fl511_northeast  NEW  Crash in Duval on I-295 E north beyond Ph...
# 19214  fl511_northeast  CLEARED  Traffic congestion in Duval on I-95 n...
# 19215  fl511_northeast  CLEARED  Traffic congestion in Duval on I-295 ...
# 19216  fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 no...
# 19217  fl511_northeast  CLEARED  Traffic congestion in Duval on I-295 ...
# 19218  fl511_northeast  CLEARED  Traffic congestion in Duval on I-95 s...
# 19219  fl511_northeast  CLEARED  Traffic congestion in Duval on I-295 ...
# 19220  fl511_northeast  CLEARED  Traffic congestion in Duval on SR-202...
# 19221  fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 W...
# 19222  fl511_northeast  CLEARED  Traffic congestion in Duval on I-95 s...
# 19223  fl511_northeast  CLEARED  Traffic congestion in Duval on SR-202...
# 19224  fl511_northeast  CLEARED  Traffic congestion in Duval on I-295 ...
# 19225  fl511_northeast  CLEARED  Traffic congestion in Duval on I-95 s...
# 19226  fl511_northeast  CLEARED  Crash in Duval on I-95 south at Exit ...
# 19227  fl511_northeast  CLEARED  Unconfirmed disabled vehicle in Duval...
# 19228  fl511_northeast  UPDATE  Crash in Duval on I-95 south at Exit 3...
# 19229  fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 so...
# 19230  fl511_northeast  CLEARED  Disabled vehicle in Duval on SR-202  ...
# 19231  fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 E...
# 19232  fl511_northeast  CLEARED  Traffic congestion in Duval on I-295 ...
#
#        road_closure                                      modified_text  \
# 19213             1  At New  Crash At Duval At Interstate 295 East ...
# 19214             1  At Cleared  Traffic Congestion At Duval At Int...
# 19215             1  At Cleared  Traffic Congestion At Duval At Int...
# 19216             1  At Update  Traffic Congestion At Duval At Inte...
# 19217             1  At Cleared  Traffic Congestion At Duval At Int...
# 19218             1  At Cleared  Traffic Congestion At Duval At Int...
# 19219             1  At Cleared  Traffic Congestion At Duval At Int...
# 19220             1  At Cleared  Traffic Congestion At Duval At Sr-...
# 19221             1  At Update  Traffic Congestion At Duval At Inte...
# 19222             1  At Cleared  Traffic Congestion At Duval At Int...
# 19223             1  At Cleared  Traffic Congestion At Duval At Sr-...
# 19224             1  At Cleared  Traffic Congestion At Duval At Int...
# 19225             1  At Cleared  Traffic Congestion At Duval At Int...
# 19226             1  At Cleared  Crash At Duval At Interstate 95 So...
# 19227             1  At Cleared  Unconfirmed Disabled Vehicle At Du...
# 19228             1  At Update  Crash At Duval At Interstate 95 Sou...
# 19229             1  At Update  Traffic Congestion At Duval At Inte...
# 19230             1  At Cleared  Disabled Vehicle At Duval At Sr-20...
# 19231             1  At Update  Traffic Congestion At Duval At Inte...
# 19232             1  At Cleared  Traffic Congestion At Duval At Int...
#
#                                    location
# 19213
# 19214              {Exit 351 Interstate 10}
# 19215                   {Buckman, San Jose}
# 19216              {Exit 351 Interstate 10}
# 19217                 {Exit 56, East South}
# 19218                 {Exit 341 Baymeadows}
# 19219                          {East North}
# 19220                    {Kernan Boulevard}
# 19221                   {Buckman, San Jose}
# 19222              {Exit 351 Interstate 10}
# 19223                       {Interstate 95}
# 19224                    {Exit 3 St Aug Rd}
# 19225   {Exit 347 Emerson, Exit 344 Butler}
# 19226                     {Exit 344 Butler}
# 19227       {Exit 55 Gate Pkwy, East North}
# 19228
# 19229                 {Exit 341 Baymeadows}
# 19230
# 19231                          {East North}
# 19232  {Exit 58 Sr-9B, Exit 56, East North}

# %%
i95 = pd.read_csv('../df_csv')
i95.head()
# Out:
#   exit crossSt dir       lat      long
# 0   1A     NaN   S  25.75506 -80.20200
# 1   1B     NaN   N  25.76255 -80.19960
# 2   1B     NaN   S  25.77588 -80.19986
# 3   2A     NaN   N  25.77139 -80.19882
# 4   2B     NaN   N  25.77339 -80.19866

# %%
test_df.loc[19218]['tweet'].lower()
# Out:
# 'cleared  traffic congestion in duval on i-95 south from exit 344 butler to at exit 341 baymeadows '

# %%
exit_loc = test_df.loc[19218]['tweet'].lower().find('exit')
exit_loc = exit_loc + 5

# %%
import numpy as np

# %%
import re

#Use tweet text, convert to lower case
txt = "Cleared traffic congestion in Duval on I-295 from exit 344a W butler to at exit 341 W baymeadows "
txt=txt.lower()

#Find the Road
road = re.search("(i-\d*|interstate \d*)", txt)
road = road.group(0)
road = road.strip(' ')
print(f'Road: {road}')

#Find the Direction, specifically that are related to the interstate
direction =  re.search("(i-\d*|interstate \d*) (south|north|s|n)*", txt)
direction = direction.group(0)
direction =  re.search("south|north|s|n", direction)

#If direction is found, log direction, otherwise direction is null
try:
    direction = direction.group(0)
except AttributeError: 
    direction = np.nan
print(f'Direction: {direction}')
# Out:
# Road: i-295
# Direction: nan

# %%
test_df['tweet'].head()
# Out:
# 19213    NEW  Crash in Duval on I-295 E north beyond Ph...
# 19214    CLEARED  Traffic congestion in Duval on I-95 n...
# 19215    CLEARED  Traffic congestion in Duval on I-295 ...
# 19216    UPDATE  Traffic congestion in Duval on I-95 no...
# 19217    CLEARED  Traffic congestion in Duval on I-295 ...
# Name: tweet, dtype: object

# %%
test_df['text'].iloc[5]
# Out:
# 'CLEARED  Traffic congestion in Duval on I-95 south from Exit 344 Butler to at Exit 341 Baymeadows '

# %%
def traffic_search(test_df='test_df', column='text', i_df='i95'):
    
    #Instantiate DataFrame 
    new_df = pd.DataFrame()
    
    #Column data to collect
    exits = []
    roads = []
    lats = []
    longs = []
    directions = []
    match_list = []
    
    for row in range(len(test_df)):
        #Mask of the cell to be iterated
        search_string = df[column].iloc[row]
    
        #Check if it's cleared
        if 'cleared' in search_string:
            pass

        #Else collect data 
        else:        
            #Find the road
            road = re.search("(i-\d*|interstate \d*)", search_string)
            road = road.group(0)
            road = road.strip(' ')
            roads.append(road)

            #Find the exit
            exit = re.search("exit \d*[ab-e]*", search_string)
            exit = exit.group(0)
            exit.strip(' ')
            exits.append(exit)

            #Find the Direction -- specifically that is connected to the road
            direction =  re.search("(i-\d*|interstate \d*) (south|north|west|east|s|n|e|w)*", search_string)
            direction = direction.group(0)
            direction =  re.search("south|north|west|east|s|n|e|w", direction

                                   #If direction is found, log direction, otherwise direction is null
            try:
                direction = direction.group(0)
                directions.append(direction)
            
            except AttributeError: 
                direction = np.nan
                directions.append(direction)

            #Find title case words for cross streets
            title_text = text.split(" ")
            title_text = {word for word in title_text if word == word.title()}

            #Remove county name as a search term.  Interferes with road matching
            title_text.remove('')
            title_text.remove('Duval')
            
            #Find Matches
            matches = []
            for word in title_text:
                for row in range(len(i95)):
                    try:
                        if word in i95['crossSt'].iloc[row]:  
                            matches.append(row)
                    except TypeError:
                        pass
            match_list.append(matches)
    
    new_df['road'] = roads
    new_df['exit'] = exits
    new_df['direction'] = directions
    new_df['match'] = match_list
#    new_df['lat'] = lats
#    new_df['long'] = longs
    return new_df
# Out:
#   File "<ipython-input-109-ea7aae7c86ae>", line 42
#     try:
#       ^
# SyntaxError: invalid syntax

# %%
text = "At New  Disabled Vehicle At Duval At Interstate 10 East Before Cassat, Right Shoulder Blocked"

#Pull out 'title case' words
title_text = text.split(" ")
title_text = {word for word in title_text if word == word.title()}

title_text.remove('')
title_text.remove('Duval')
title_text
# Out:
# {'10',
#  'At',
#  'Before',
#  'Blocked',
#  'Cassat,',
#  'Disabled',
#  'East',
#  'Interstate',
#  'New',
#  'Right',
#  'Shoulder',
#  'Vehicle'}

# %%
#Make a list of matching rows for the title text search
matches = []
for word in title_text:
    for row in range(len(i10)):
        try:
            if word in i10['crossSt'].iloc[row]:  
                matches.append(row)
        except TypeError:
            pass

i10.iloc[matches]
# Out:
#      exit              crossSt dir       lat      long
# 8      12                I-110   E  30.50348 -87.23715
# 9      12                I-110   W  30.50379 -87.22393
# 114   357      SR 103 Lane Ave   E  30.31550 -81.75616
# 115   357      SR 103 Lane Ave   W  30.31602 -81.74865
# 64   209B  US 90 East Mahan Dr   E  30.48486 -84.15795
# 65   209B  US 90 East Mahan Dr   W  30.48210 -84.15316

# %%
road = re.search("(i-\d*|interstate \d*) (south|north|s|n)", txt)
direction = direction.group(0)
direction

# %%
exit = re.search("exit \d*[ab-e]*", txt)
exit = exit.group(0)
exit.strip(' ')

# %%
temp_df

# %%
result = i95[i95['crossSt'].str.contains('SR 202') == True]
result

# %%
pd.options.display.max_colwidth = 200
test_df[test_df['text'].str.contains('I-95') == True]['text']

# %%
i95['road'] = 'I-95'

# %%
i95.head()

# %%
i10 = pd.read_csv('../i10_csv')

# %%
i10
# Out:
#     exit                                        crossSt dir       lat  \
# 0      5                                      US 90 Alt   E  30.53662
# 1      5                                      US 90 Alt   W  30.53215
# 2      7                                         SR 297   W  30.51983
# 3     7A                                   SR 297 South   E  30.52261
# 4     7B                                   SR 297 North   E  30.52072
# 5    10A                                    US 29 South   E  30.50267
# 6    10B                                    US 29 North   E  30.50226
# 7     10                                    US 29 North   W  30.50409
# 8     12                                          I-110   E  30.50348
# 9     12                                          I-110   W  30.50379
# 10    13                                         SR 291   E  30.50338
# 11    13                                         SR 291   W  30.50348
# 12    17                                          US 90   E  30.50322
# 13    17                                          US 90   W  30.50640
# 14    22                             SR 281 Avalon Blvd   E  30.53379
# 15    22                             SR 281 Avalon Blvd   W  30.53409
# 16    26                                         CR 191   E  30.56676
# 17    26                                         CR 191   W  30.57350
# 18    28                               CR 89 Ward Basin   E  30.58891
# 19    28                               CR 89 Ward Basin   W  30.59371
# 20    31                                          SR 87   E  30.61681
# 21    31                                          SR 87   W  30.62082
# 22    45                                    SR 189 Holt   E  30.69674
# 23    45                                    SR 189 Holt   W  30.70061
# 24    56                                          SR 85   E  30.72546
# 25    56                                          SR 85   W  30.72601
# 26    70                                         SR 285   E  30.73250
# 27    70                                         SR 285   W  30.73276
# 28    85                                         US 331   E  30.69252
# 29    85                                         US 331   W  30.69178
# ..   ...                                            ...  ..       ...
# 94   324                            US 90 Tiger Lake Rd   E  30.23882
# 95   324                                          US 90   W  30.23673
# 96   327                           CR 229 Reid Stafford   E  30.24009
# 97   327                           CR 229 Reid Stafford   W  30.24005
# 98   333                            CR 125 Nursery Blvd   E  30.26192
# 99   333                            CR 125 Nursery Blvd   W  30.26170
# 100  335                                SR 121 S 6th St   E  30.25892
# 101  335                                SR 121 S 6th St   W  30.25908
# 102  336                                         SR 228   E  30.26128
# 103  336                                         SR 228   W  30.26491
# 104  343                                         US 301   E  30.28852
# 105  343                                         US 301   W  30.28933
# 106  350  SR 23 Cecil Commerce Center Parkway Beaver St   E  30.30534
# 107  350  SR 23 Cecil Commerce Center Parkway Beaver St   W  30.30797
# 108  351                            SR 115-C Chaffee Rd   E  30.30915
# 109  351                            SR 115-C Chaffee Rd   W  30.30933
# 110  355                          Marietta Hammond Blvd   E  30.31476
# 111  355                          Marietta Hammond Blvd   W  30.31520
# 112  356                                          I-285   E  30.31518
# 113  356                                          I-295   W  30.31585
# 114  357                                SR 103 Lane Ave   E  30.31550
# 115  357                                SR 103 Lane Ave   W  30.31602
# 116  358                 SR 111 Cassat Ave Edgewood Ave   E  30.31721
# 117  358                 SR 111 Cassat Ave Edgewood Ave   W  30.31862
# 118  359                                 Luna St Waller   W  30.32094
# 119  360                      SR 129 McDuff Ave Rayford   E  30.32086
# 120  360                       SR 129 McDuff Ave Waller   W  30.32136
# 121  361                           US 17 Roosevelt Blvd   W  30.32190
# 122  362                                    Stockton St   E  30.32073
# 123  362                                    Stockton St   W  30.32145
#
#          long
# 0   -87.33782
# 1   -87.33082
# 2   -87.31054
# 3   -87.31612
# 4   -87.31273
# 5   -87.26841
# 6   -87.26566
# 7   -87.26204
# 8   -87.23715
# 9   -87.22393
# 10  -87.23389
# 11  -87.21669
# 12  -87.16742
# 13  -87.16330
# 14  -87.09236
# 15  -87.08180
# 16  -87.03530
# 17  -87.02695
# 18  -87.00642
# 19  -87.00080
# 20  -86.96887
# 21  -86.95728
# 22  -86.75588
# 23  -86.74657
# 24  -86.57356
# 25  -86.56330
# 26  -86.35653
# 27  -86.34614
# 28  -86.12886
# 29  -86.11697
# ..        ...
# 94  -82.30376
# 95  -82.29935
# 96  -82.25891
# 97  -82.26114
# 98  -82.16602
# 99  -82.15928
# 100 -82.12280
# 101 -82.12305
# 102 -82.10818
# 103 -82.10084
# 104 -81.99057
# 105 -81.98345
# 106 -81.89183
# 107 -81.86741
# 108 -81.84853
# 109 -81.84856
# 110 -81.79673
# 111 -81.78708
# 112 -81.77517
# 113 -81.76204
# 114 -81.75616
# 115 -81.74865
# 116 -81.73408
# 117 -81.72756
# 118 -81.71658
# 119 -81.70904
# 120 -81.70181
# 121 -81.69821
# 122 -81.69256
# 123 -81.68432
#
# [124 rows x 5 columns]
