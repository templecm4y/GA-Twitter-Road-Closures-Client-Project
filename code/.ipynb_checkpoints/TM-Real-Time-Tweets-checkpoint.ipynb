# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import tweepy
import json
import datetime
import re

# %%
# Enter Access Identification numbers 
with open('../twitter_credentials.json') as cred_data:
    info = json.load(cred_data)
    consumer_key = info['CONSUMER_KEY']
    consumer_secret = info['CONSUMER_SECRET']
    access_token = info['ACCESS_TOKEN']
    access_secret = info['ACCESS_SECRET']
 # Authenticate Twitter API using  account Keys 
auth_details = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth_details.set_access_token(access_token, access_secret)
my_accounts = []

# 
api = tweepy.API(auth_details, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
user = api.me()
print(user.name)
# Out:
# Tee Moore

# %%
# define fucntion to get tweets and add class functionality
def get_tweets(username, list_name = None, num = 20):
       
    # check for list
    if not list_name:
        # get timeline of user if no list
        tweet = tweepy.Cursor(api.user_timeline, screen_name = username).items(num)
    else:
        # get list timeline if list
        tweet = tweepy.Cursor(api.list_timeline, owner_screen_name = username, slug = list_name).items(num)
            
    # Empty Arrays
    tmp=[]
    closure_list = []
  
    # create array of tweet information: username,  
    # tweet id, date/time, text 
    # create dictionary for each tweet
    for status in tweet:
        tweet_dict = {}
        tweet_dict['id'] = status.id
        tweet_dict['username'] = status.user.name
        tweet_dict['date'] = status.created_at
        tweet_dict['text'] = status.text
        tweet_dict['hashtags'] = status.entities['hashtags']
        tweet_dict['geo'] = status.coordinates
        tweet_dict['type'] = 'official'
        tmp.append(status.text)
        closure_list.append(tweet_dict)
  
    # writing the tweets
    print(tmp)
  
    # return tweet_dict
    return closure_list
    
# Driver code 
if __name__ == '__main__': 
  
    # Here goes the twitter handle for the user and optional list
    # whose tweets are to be extracted. 
    twts = get_tweets('fl511_northeast')
# Out:
# ['Updated: Planned construction in Duval on US-90 / Beach Blvd west at Kernan Blvd, left lane blocked. Last updated...https://t.co/B9cFaA60pw', 'Updated: Planned construction in Duval on US-90 / Beach Blvd east at Kernan Blvd, left lane blocked. Last updated...https://t.co/605cfbq9aT', 'New: Planned construction in Duval on I-10 west ramp to Exit 343 US-301, off-ramp closed. Last updated at...https://t.co/9bKgHM11PW', 'New: Planned construction in Duval on US-90 / Beach Blvd west at Kernan Blvd, left lane blocked. Last updated at...https://t.co/B9cFaA60pw', 'New: Planned construction in Duval on US-90 / Beach Blvd east at Kernan Blvd, left lane blocked. Last updated at...https://t.co/605cfbq9aT', 'Cleared: Traffic congestion in St Johns on I-95 south from before SR-16 to at MM 316. Last updated at 06:42:23PM.', 'Updated: Traffic congestion in St Johns on I-95 south from before SR-16 to at MM 316. Last updated at 06:42:23PM. https://t.co/sYrIjrUtsj', 'Updated: Crash in St Johns on I-95 south before SR-16, left lane blocked. Last updated at 06:08:17PM. https://t.co/XzJ2Tbh6bt', 'Updated: Traffic congestion in St Johns on I-95 south from beyond Intl Golf Pkwy to before SR-16. Last updated at...https://t.co/sYrIjrUtsj', 'New: Traffic congestion in St Johns on I-95 south before SR-16 and traffic backed up until beyond Intl Golf Pkwy....https://t.co/sYrIjrUtsj', 'Updated: Crash in St Johns on I-95 south before SR-16, left lane blocked. Last updated at 05:57:37PM. https://t.co/XzJ2Tbh6bt', 'Updated: Crash in St Johns on I-95 south before SR-16, left lane blocked. Last updated at 05:56:48PM. https://t.co/XzJ2Tbh6bt', 'Cleared: Crash in St Johns on I-95 south at MM 309, left lane blocked. Content provided by Waze. Last updated at 05:23:20PM.', 'Cleared: Traffic congestion in St Johns on I-95 north at MM 308. Content provided by Waze. Last updated at 05:00:58PM.', 'Cleared: Crash in Baker on I-10 west at Exit 336 SR-228, right lane blocked. Content provided by Waze. Last updated at 04:59:16PM.', 'Updated: Crash in St Johns on I-95 south before SR-16, left lane blocked. Last updated at 05:20:29PM. https://t.co/XzJ2Tbh6bt', 'Updated: Disabled vehicle in St Johns on I-95 south at MM 316, right lane blocked. Last updated at 05:01:49PM. https://t.co/79oxpYHgy3', 'Updated: Crash in St Johns on I-95 south before SR-16, 2 left lanes blocked. Last updated at 05:01:44PM. https://t.co/XzJ2Tbh6bt', 'New: Crash in Baker on I-10 west at Exit 336 SR-228, right lane blocked. Content provided by Waze. Last updated...https://t.co/sfa99gMoz5', 'Updated: Disabled vehicle in St Johns on I-95 south at MM 316, right lane blocked. Last updated at 04:55:11PM. https://t.co/79oxpYHgy3']

# %%
pd.DataFrame(twts)
# Out:
#                   date   geo hashtags                   id  \
# 0  2019-07-29 01:02:29  None       []  1155644731055116288
# 1  2019-07-29 01:02:29  None       []  1155644730472062976
# 2  2019-07-29 00:02:25  None       []  1155629614045286405
# 3  2019-07-28 23:32:24  None       []  1155622059462004736
# 4  2019-07-28 23:30:36  None       []  1155621607328681984
# 5  2019-07-28 23:00:34  None       []  1155614052112113665
# 6  2019-07-28 22:43:25  None       []  1155609734260625415
# 7  2019-07-28 22:08:28  None       []  1155600939694379010
# 8  2019-07-28 22:07:31  None       []  1155600698853208065
# 9  2019-07-28 22:01:29  None       []  1155599181911863298
# 10 2019-07-28 21:58:31  None       []  1155598433014681600
# 11 2019-07-28 21:57:25  None       []  1155598156014530560
# 12 2019-07-28 21:55:31  None       []  1155597680934084608
# 13 2019-07-28 21:33:27  None       []  1155592124630482944
# 14 2019-07-28 21:27:26  None       []  1155590612764282881
# 15 2019-07-28 21:21:28  None       []  1155589109513109505
# 16 2019-07-28 21:02:36  None       []  1155584364031467520
# 17 2019-07-28 21:02:36  None       []  1155584362299219975
# 18 2019-07-28 20:59:26  None       []  1155583566333534210
# 19 2019-07-28 20:55:24  None       []  1155582550598983681
#
#                                                  text      type  \
# 0   Updated: Planned construction in Duval on US-9...  official
# 1   Updated: Planned construction in Duval on US-9...  official
# 2   New: Planned construction in Duval on I-10 wes...  official
# 3   New: Planned construction in Duval on US-90 / ...  official
# 4   New: Planned construction in Duval on US-90 / ...  official
# 5   Cleared: Traffic congestion in St Johns on I-9...  official
# 6   Updated: Traffic congestion in St Johns on I-9...  official
# 7   Updated: Crash in St Johns on I-95 south befor...  official
# 8   Updated: Traffic congestion in St Johns on I-9...  official
# 9   New: Traffic congestion in St Johns on I-95 so...  official
# 10  Updated: Crash in St Johns on I-95 south befor...  official
# 11  Updated: Crash in St Johns on I-95 south befor...  official
# 12  Cleared: Crash in St Johns on I-95 south at MM...  official
# 13  Cleared: Traffic congestion in St Johns on I-9...  official
# 14  Cleared: Crash in Baker on I-10 west at Exit 3...  official
# 15  Updated: Crash in St Johns on I-95 south befor...  official
# 16  Updated: Disabled vehicle in St Johns on I-95 ...  official
# 17  Updated: Crash in St Johns on I-95 south befor...  official
# 18  New: Crash in Baker on I-10 west at Exit 336 S...  official
# 19  Updated: Disabled vehicle in St Johns on I-95 ...  official
#
#            username
# 0   FL511 Northeast
# 1   FL511 Northeast
# 2   FL511 Northeast
# 3   FL511 Northeast
# 4   FL511 Northeast
# 5   FL511 Northeast
# 6   FL511 Northeast
# 7   FL511 Northeast
# 8   FL511 Northeast
# 9   FL511 Northeast
# 10  FL511 Northeast
# 11  FL511 Northeast
# 12  FL511 Northeast
# 13  FL511 Northeast
# 14  FL511 Northeast
# 15  FL511 Northeast
# 16  FL511 Northeast
# 17  FL511 Northeast
# 18  FL511 Northeast
# 19  FL511 Northeast
