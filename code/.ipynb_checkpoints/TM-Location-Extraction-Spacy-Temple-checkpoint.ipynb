# %% [markdown]
# # Location Extraction and Spacy Word Vectorization

# %%
import pandas as pd
import numpy as np
import re
import spacy
import string
import datetime

# %%
# Read in csv with Tweets
twitter_closures = pd.read_csv("../data/Cleaned_Tweets/cleaned_historic_official_07302019.csv")
exits = pd.read_csv("../data/interstate_exits.csv")

twitter_closures = twitter_closures[['date', 'text', 'type', 'username', 'tweet', 'state', 'road_closure']]

# Print DF shape
print(twitter_closures.shape)

# Show head 
twitter_closures.head()
# Out:
# (24054, 7)
#                         date  \
# 0  2016-10-11 16:39:51+00:00
# 1  2016-10-10 19:10:23+00:00
# 2  2016-10-09 17:30:22+00:00
# 3  2016-10-09 15:45:11+00:00
# 4  2016-10-09 14:00:20+00:00
#
#                                                 text      type username  \
# 0  the pioh for the sr 138 i-20 is going on now u...  official  GDOTATL
# 1  we appreciate all the hard work our crews have...  official  GDOTATL
# 2  need info on re-entry  check here  also follow...  official  GDOTATL
# 3  do you need some updates  you can find all of ...  official  GDOTATL
# 4  did you know that the  511georgia website and ...  official  GDOTATL
#
#                                                tweet    state  road_closure
# 0  The PIOH for the SR 138 I-20 is going on now u...  Georgia             0
# 1  We appreciate all the hard work our crews have...  Georgia             0
# 2  Need info on re-entry  Check here  Also follow...  Georgia             0
# 3  Do you need some updates  You can find ALL of ...  Georgia             0
# 4  Did you know that the  511Georgia website and ...  Georgia             0

# %% [markdown]
# ## SpaCy Preprocessing

# %%
# Create new columns to transfer modified tweet text. Five versions of tweets will be created.
twitter_closures['modified_text'] = ''
twitter_closures['location'] = ''

# Show modified DF
twitter_closures.head(2)
# Out:
#                         date  \
# 0  2016-10-11 16:39:51+00:00
# 1  2016-10-10 19:10:23+00:00
#
#                                                 text      type username  \
# 0  the pioh for the sr 138 i-20 is going on now u...  official  GDOTATL
# 1  we appreciate all the hard work our crews have...  official  GDOTATL
#
#                                                tweet    state  road_closure  \
# 0  The PIOH for the SR 138 I-20 is going on now u...  Georgia             0
# 1  We appreciate all the hard work our crews have...  Georgia             0
#
#   modified_text location
# 0
# 1

# %%
format_dict = {"hwy": "highway ",
            "blvd": "boulevard",
            " st": "street",
           "CR ": "County Road ",
           "SR ": "State Road",
           "I-": "Interstate ",
           "EB ": "Eastbound ",
           "WB ": "Westbound ",
           "SB ": "Southbound",
           "NB ": "Northbound",
           " on ": " at ",
           " E ": " East ",
           " W ": " West ",
           " S ": " South",
           " N ": " North",
           "mi ": "mile ",
           "between ": "at ",
           "Between ": "at ",
           " In ": " in",
           " in ": " at "}

# %%
def spacy_cleaner(df, col, word_dict):
    modified_text = "At " + df[col].replace(word_dict, regex=True)
    modified_text = modified_text.str.title()
    return modified_text

# %%
# run the text cleaning function and test results
twitter_closures['modified_text'] = spacy_cleaner(twitter_closures, 'tweet', format_dict)

# %%
twitter_closures['username'].unique()
# Out:
# array(['GDOTATL', 'SCDOTMidlands', 'SCDOTPeeDee', 'SCDOTLowCountry',
#        'SCDOTPiedmont', '511statewideva', 'fl511_panhandl', '511Georgia',
#        'fl511_state', 'fl511_northeast', 'fl511_southeast',
#        'fl511_southwest', 'fl511_tampabay', 'fl511_central',
#        '511centralva', '511hamptonroads', '511northernva',
#        'NCDOT_Westmtn', 'NCDOT_Triangle', 'NCDOT_Piedmont',
#        'NCDOT_Charlotte', 'NCDOT_Asheville', 'NCDOT_Scoast',
#        'NCDOT_Ncoast'], dtype=object)

# %%
twitter_closures['date'] = pd.to_datetime(twitter_closures['date'])

# %%
twitter_closures[(twitter_closures['date'] > '2016-10-4') & (twitter_closures['date'] < '2016-10-5')]
# Out:
#                            date  \
# 433   2016-10-04 23:59:18+00:00
# 434   2016-10-04 23:54:17+00:00
# 435   2016-10-04 23:49:17+00:00
# 436   2016-10-04 23:46:46+00:00
# 437   2016-10-04 23:41:45+00:00
# 438   2016-10-04 23:31:43+00:00
# 439   2016-10-04 23:16:42+00:00
# 440   2016-10-04 22:44:19+00:00
# 441   2016-10-04 22:24:18+00:00
# 442   2016-10-04 22:16:47+00:00
# 443   2016-10-04 22:01:46+00:00
# 444   2016-10-04 22:01:45+00:00
# 445   2016-10-04 21:54:15+00:00
# 446   2016-10-04 21:54:14+00:00
# 447   2016-10-04 21:49:14+00:00
# 448   2016-10-04 21:34:13+00:00
# 449   2016-10-04 21:29:12+00:00
# 450   2016-10-04 21:01:50+00:00
# 451   2016-10-04 20:01:44+00:00
# 452   2016-10-04 19:49:12+00:00
# 453   2016-10-04 17:14:16+00:00
# 454   2016-10-04 17:06:46+00:00
# 455   2016-10-04 16:39:14+00:00
# 456   2016-10-04 16:31:43+00:00
# 457   2016-10-04 16:26:42+00:00
# 458   2016-10-04 16:11:41+00:00
# 459   2016-10-04 15:46:49+00:00
# 460   2016-10-04 15:39:19+00:00
# 461   2016-10-04 15:26:48+00:00
# 462   2016-10-04 15:19:17+00:00
# ...                         ...
# 23217 2016-10-04 11:52:22+00:00
# 23330 2016-10-04 22:46:08+00:00
# 23331 2016-10-04 20:04:29+00:00
# 23332 2016-10-04 17:49:20+00:00
# 23333 2016-10-04 17:47:54+00:00
# 23334 2016-10-04 17:42:17+00:00
# 23335 2016-10-04 17:16:16+00:00
# 23336 2016-10-04 17:14:22+00:00
# 23337 2016-10-04 15:55:24+00:00
# 23338 2016-10-04 15:41:21+00:00
# 23339 2016-10-04 15:07:56+00:00
# 23340 2016-10-04 14:50:23+00:00
# 23341 2016-10-04 13:14:50+00:00
# 23342 2016-10-04 12:48:17+00:00
# 23343 2016-10-04 10:59:14+00:00
# 23344 2016-10-04 10:44:30+00:00
# 23389 2016-10-04 23:13:47+00:00
# 23390 2016-10-04 22:35:48+00:00
# 23391 2016-10-04 22:13:33+00:00
# 23392 2016-10-04 21:50:36+00:00
# 23393 2016-10-04 21:05:26+00:00
# 23394 2016-10-04 15:12:09+00:00
# 23395 2016-10-04 15:09:17+00:00
# 23396 2016-10-04 12:44:17+00:00
# 23781 2016-10-04 13:01:56+00:00
# 23782 2016-10-04 12:54:04+00:00
# 23783 2016-10-04 12:32:34+00:00
# 24051 2016-10-04 23:49:41+00:00
# 24052 2016-10-04 23:48:38+00:00
# 24053 2016-10-04 11:24:04+00:00
#
#                                                     text      type  \
# 433    cleared  construction  i-77 nb, btwn 1 mi s of...  official
# 434    construction  i-26 wb  btwn exit119 & exit116,...  official
# 435    construction  i-26 eb  btwn exit119 & 3 mi w o...  official
# 436    construction  i-20 wb  btwn exit61 & exit58, r...  official
# 437    construction  i-20 eb  btwn exit58 & 1 mi w of...  official
# 438    traf congestion  i-26 wb  btwn exit72 & exit66...  official
# 439    rd maint ops  i-26 eb  2 mi w of exit91, rht l...  official
# 440    construction  i-77 nb  btwn 1 mi s of exit2 & ...  official
# 441        cleared  accident  i-20 eb, at exit65 | 6 24p  official
# 442    update  accident  i-20 eb  at exit65, no lns c...  official
# 443    update  accident  i-20 eb  at exit65, no lns c...  official
# 444    construction  i-77 sb  btwn 1 mi n of exit24 &...  official
# 445    accident  i-20 eb  at exit65, lft ln clsd, ocr...  official
# 446    cleared  accident  i-20 eb, 1 mi w of exit68 |...  official
# 447    update  accident  i-20 eb  1 mi w of exit68, n...  official
# 448    update  accident  i-20 eb  1 mi w of exit68, n...  official
# 449    accident  i-20 eb  1 mi w of exit68, lft ln cl...  official
# 450    cleared  rd maint ops  i-77 sb, btwn exit22 & ...  official
# 451    cleared  rd maint ops  i-77 nb, btwn 1 mi s of...  official
# 452    cleared  disabled veh  i-20 eb, at exit64a | 3...  official
# 453    cleared  accident  sc 277 nb, at i20e to flore...  official
# 454    update  accident  sc 277 nb  at i20e to floren...  official
# 455       cleared  accident  i-20 eb, at exit76 | 12 39p  official
# 456    update  accident  i-20 eb  at exit76, no lns c...  official
# 457    update  accident  i-20 eb  at exit76, no lns c...  official
# 458    accident  i-20 eb  at exit76, rt exit rmp clsd...  official
# 459    cleared  accident  i-26 eb, 1 mi w of exit119 ...  official
# 460    update  accident  i-26 eb  1 mi w of exit119, ...  official
# 461    accident  i-26 eb  1 mi w of exit119, lft ln c...  official
# 462    update  accident  sc 277 nb  at i20e to floren...  official
# ...                                                  ...       ...
# 23217  nc-62, south of yanceyville caswell, vehicle a...  official
# 23330  i-85, mile marker 25, south, gastonia, gaston,...  official
# 23331  park st, in belmont gaston, vehicle accident, ...  official
# 23332  i-85, mile marker 25, south, gastonia, gaston,...  official
# 23333  i-485, mile marker 48, both, charlotte, meckle...  official
# 23334  i-485, mile marker 37 to 39, inner, charlotte,...  official
# 23335  harrisburg rd, in charlotte mecklenburg, maint...  official
# 23336  morehead rd, in charlotte mecklenburg, mainten...  official
# 23337  i-85, mile marker 40, north, charlotte, meckle...  official
# 23338  i-85, mile marker 40, north, charlotte, meckle...  official
# 23339  i-85, mile marker 40, north, charlotte, meckle...  official
# 23340  i-85, mile marker 40, north, charlotte, meckle...  official
# 23341  mangum dairy rd, south of monroe union, mainte...  official
# 23342  odell school rd, west of kannapolis cabarrus, ...  official
# 23343  i-85, mile marker 36, south, charlotte, meckle...  official
# 23344  i-85, mile marker 36, south, charlotte, meckle...  official
# 23389  i-40, mile marker 45, west, asheville, buncomb...  official
# 23390  i-40, mile marker 44, west, asheville, buncomb...  official
# 23391  us-19 23 74 alt, near asheville buncombe, vehi...  official
# 23392  i-26, mile marker 25, west, asheville, buncomb...  official
# 23393  i-40, mile marker 44, west, asheville, buncomb...  official
# 23394  i-40, mile marker 34, west, clyde, haywood, ma...  official
# 23395  i-40, mile marker 28, east, clyde, haywood, ma...  official
# 23396  i-40, mile marker 73, east, old fort, mcdowell...  official
# 23781  ocean view ave se, in holden beach brunswick, ...  official
# 23782  us-17, north of wilmington new hanover, vehicl...  official
# 23783  us-17, north of wilmington new hanover, vehicl...  official
# 24051  nc 42, west of wilson wilson, maintenance, roa...  official
# 24052  nc 42, east of wilson wilson, maintenance, roa...  official
# 24053  nc-481, north east of enfield halifax, mainten...  official
#
#               username                                              tweet  \
# 433      SCDOTMidlands  CLEARED  Construction  I-77 NB, btwn 1 mi S of...
# 434      SCDOTMidlands  Construction  I-26 WB  btwn Exit119 & Exit116,...
# 435      SCDOTMidlands  Construction  I-26 EB  btwn Exit119 & 3 mi W o...
# 436      SCDOTMidlands  Construction  I-20 WB  btwn Exit61 & Exit58, r...
# 437      SCDOTMidlands  Construction  I-20 EB  btwn Exit58 & 1 mi W of...
# 438      SCDOTMidlands  Traf congestion  I-26 WB  btwn Exit72 & Exit66...
# 439      SCDOTMidlands  Rd maint ops  I-26 EB  2 mi W of Exit91, rht l...
# 440      SCDOTMidlands  Construction  I-77 NB  btwn 1 mi S of Exit2 & ...
# 441      SCDOTMidlands      CLEARED  Accident  I-20 EB, at Exit65 | 6 24P
# 442      SCDOTMidlands  Update  Accident  I-20 EB  at Exit65, no lns c...
# 443      SCDOTMidlands  Update  Accident  I-20 EB  at Exit65, no lns c...
# 444      SCDOTMidlands  Construction  I-77 SB  btwn 1 mi N of Exit24 &...
# 445      SCDOTMidlands  Accident  I-20 EB  at Exit65, lft ln clsd, Ocr...
# 446      SCDOTMidlands  CLEARED  Accident  I-20 EB, 1 mi W of Exit68 |...
# 447      SCDOTMidlands  Update  Accident  I-20 EB  1 mi W of Exit68, n...
# 448      SCDOTMidlands  Update  Accident  I-20 EB  1 mi W of Exit68, n...
# 449      SCDOTMidlands  Accident  I-20 EB  1 mi W of Exit68, lft ln cl...
# 450      SCDOTMidlands  CLEARED  Rd maint ops  I-77 SB, btwn Exit22 & ...
# 451      SCDOTMidlands  CLEARED  Rd maint ops  I-77 NB, btwn 1 mi S of...
# 452      SCDOTMidlands  CLEARED  Disabled veh  I-20 EB, at Exit64A | 3...
# 453      SCDOTMidlands  CLEARED  Accident  SC 277 NB, at I20E to Flore...
# 454      SCDOTMidlands  Update  Accident  SC 277 NB  at I20E to Floren...
# 455      SCDOTMidlands     CLEARED  Accident  I-20 EB, at Exit76 | 12 39P
# 456      SCDOTMidlands  Update  Accident  I-20 EB  at Exit76, no lns c...
# 457      SCDOTMidlands  Update  Accident  I-20 EB  at Exit76, no lns c...
# 458      SCDOTMidlands  Accident  I-20 EB  at Exit76, rt exit rmp clsd...
# 459      SCDOTMidlands  CLEARED  Accident  I-26 EB, 1 mi W of Exit119 ...
# 460      SCDOTMidlands  Update  Accident  I-26 EB  1 mi W of Exit119, ...
# 461      SCDOTMidlands  Accident  I-26 EB  1 mi W of Exit119, lft ln c...
# 462      SCDOTMidlands  Update  Accident  SC 277 NB  at I20E to Floren...
# ...                ...                                                ...
# 23217   NCDOT_Piedmont  NC-62, South of Yanceyville Caswell, Vehicle A...
# 23330  NCDOT_Charlotte  I-85, Mile Marker 25, South, Gastonia, Gaston,...
# 23331  NCDOT_Charlotte  Park St, In Belmont Gaston, Vehicle Accident, ...
# 23332  NCDOT_Charlotte  I-85, Mile Marker 25, South, Gastonia, Gaston,...
# 23333  NCDOT_Charlotte  I-485, Mile Marker 48, Both, Charlotte, Meckle...
# 23334  NCDOT_Charlotte  I-485, Mile Marker 37 to 39, Inner, Charlotte,...
# 23335  NCDOT_Charlotte  Harrisburg Rd, In Charlotte Mecklenburg, Maint...
# 23336  NCDOT_Charlotte  Morehead Rd, In Charlotte Mecklenburg, Mainten...
# 23337  NCDOT_Charlotte  I-85, Mile Marker 40, North, Charlotte, Meckle...
# 23338  NCDOT_Charlotte  I-85, Mile Marker 40, North, Charlotte, Meckle...
# 23339  NCDOT_Charlotte  I-85, Mile Marker 40, North, Charlotte, Meckle...
# 23340  NCDOT_Charlotte  I-85, Mile Marker 40, North, Charlotte, Meckle...
# 23341  NCDOT_Charlotte  Mangum Dairy Rd, South of Monroe Union, Mainte...
# 23342  NCDOT_Charlotte  Odell School Rd, West of Kannapolis Cabarrus, ...
# 23343  NCDOT_Charlotte  I-85, Mile Marker 36, South, Charlotte, Meckle...
# 23344  NCDOT_Charlotte  I-85, Mile Marker 36, South, Charlotte, Meckle...
# 23389  NCDOT_Asheville  I-40, Mile Marker 45, West, Asheville, Buncomb...
# 23390  NCDOT_Asheville  I-40, Mile Marker 44, West, Asheville, Buncomb...
# 23391  NCDOT_Asheville  US-19 23 74 Alt, Near Asheville Buncombe, Vehi...
# 23392  NCDOT_Asheville  I-26, Mile Marker 25, West, Asheville, Buncomb...
# 23393  NCDOT_Asheville  I-40, Mile Marker 44, West, Asheville, Buncomb...
# 23394  NCDOT_Asheville  I-40, Mile Marker 34, West, Clyde, Haywood, Ma...
# 23395  NCDOT_Asheville  I-40, Mile Marker 28, East, Clyde, Haywood, Ma...
# 23396  NCDOT_Asheville  I-40, Mile Marker 73, East, Old Fort, McDowell...
# 23781     NCDOT_Scoast  Ocean View Ave SE, In Holden Beach Brunswick, ...
# 23782     NCDOT_Scoast  US-17, North of Wilmington New Hanover, Vehicl...
# 23783     NCDOT_Scoast  US-17, North of Wilmington New Hanover, Vehicl...
# 24051     NCDOT_Ncoast  NC 42, West of Wilson Wilson, Maintenance, Roa...
# 24052     NCDOT_Ncoast  NC 42, East of Wilson Wilson, Maintenance, Roa...
# 24053     NCDOT_Ncoast  NC-481, North East of Enfield Halifax, Mainten...
#
#                 state  road_closure  \
# 433    South Carolina             0
# 434    South Carolina             0
# 435    South Carolina             0
# 436    South Carolina             0
# 437    South Carolina             0
# 438    South Carolina             0
# 439    South Carolina             0
# 440    South Carolina             0
# 441    South Carolina             0
# 442    South Carolina             0
# 443    South Carolina             0
# 444    South Carolina             0
# 445    South Carolina             0
# 446    South Carolina             0
# 447    South Carolina             0
# 448    South Carolina             0
# 449    South Carolina             0
# 450    South Carolina             0
# 451    South Carolina             0
# 452    South Carolina             0
# 453    South Carolina             0
# 454    South Carolina             0
# 455    South Carolina             0
# 456    South Carolina             0
# 457    South Carolina             0
# 458    South Carolina             0
# 459    South Carolina             0
# 460    South Carolina             0
# 461    South Carolina             0
# 462    South Carolina             0
# ...               ...           ...
# 23217  North Carolina             1
# 23330  North Carolina             1
# 23331  North Carolina             1
# 23332  North Carolina             1
# 23333  North Carolina             1
# 23334  North Carolina             1
# 23335  North Carolina             1
# 23336  North Carolina             1
# 23337  North Carolina             1
# 23338  North Carolina             1
# 23339  North Carolina             1
# 23340  North Carolina             1
# 23341  North Carolina             1
# 23342  North Carolina             1
# 23343  North Carolina             1
# 23344  North Carolina             1
# 23389  North Carolina             1
# 23390  North Carolina             1
# 23391  North Carolina             1
# 23392  North Carolina             1
# 23393  North Carolina             1
# 23394  North Carolina             1
# 23395  North Carolina             1
# 23396  North Carolina             1
# 23781  North Carolina             1
# 23782  North Carolina             1
# 23783  North Carolina             1
# 24051  North Carolina             1
# 24052  North Carolina             1
# 24053  North Carolina             1
#
#                                            modified_text location
# 433    At Cleared  Construction  Interstate 77 Nb, Bt...
# 434    At Construction  Interstate 26 Westbound  Btwn...
# 435    At Construction  Interstate 26 Eastbound  Btwn...
# 436    At Construction  Interstate 20 Westbound  Btwn...
# 437    At Construction  Interstate 20 Eastbound  Btwn...
# 438    At Traf Congestion  Interstate 26 Westbound  B...
# 439    At Rd Maint Ops  Interstate 26 Eastbound  2 Mi...
# 440    At Construction  Interstate 77 Northbound Btwn...
# 441    At Cleared  Accident  Interstate 20 Eb, At Exi...
# 442    At Update  Accident  Interstate 20 Eastbound  ...
# 443    At Update  Accident  Interstate 20 Eastbound  ...
# 444    At Construction  Interstate 77 Southbound Btwn...
# 445    At Accident  Interstate 20 Eastbound  At Exit6...
# 446    At Cleared  Accident  Interstate 20 Eb, 1 Mile...
# 447    At Update  Accident  Interstate 20 Eastbound  ...
# 448    At Update  Accident  Interstate 20 Eastbound  ...
# 449    At Accident  Interstate 20 Eastbound  1 Mile W...
# 450    At Cleared  Rd Maint Ops  Interstate 77 Sb, Bt...
# 451    At Cleared  Rd Maint Ops  Interstate 77 Nb, Bt...
# 452    At Cleared  Disabled Veh  Interstate 20 Eb, At...
# 453    At Cleared  Accident  Sc 277 Nb, At I20E To Fl...
# 454    At Update  Accident  Sc 277 Northbound At I20E...
# 455    At Cleared  Accident  Interstate 20 Eb, At Exi...
# 456    At Update  Accident  Interstate 20 Eastbound  ...
# 457    At Update  Accident  Interstate 20 Eastbound  ...
# 458    At Accident  Interstate 20 Eastbound  At Exit7...
# 459    At Cleared  Accident  Interstate 26 Eb, 1 Mile...
# 460    At Update  Accident  Interstate 26 Eastbound  ...
# 461    At Accident  Interstate 26 Eastbound  1 Mile W...
# 462    At Update  Accident  Sc 277 Northbound At I20E...
# ...                                                  ...      ...
# 23217  At Nc-62, South Of Yanceyville Caswell, Vehicl...
# 23330  At Interstate 85, Mile Marker 25, South, Gasto...
# 23331  At Park St, Inbelmont Gaston, Vehicle Accident...
# 23332  At Interstate 85, Mile Marker 25, South, Gasto...
# 23333  At Interstate 485, Mile Marker 48, Both, Charl...
# 23334  At Interstate 485, Mile Marker 37 To 39, Inner...
# 23335  At Harrisburg Rd, Incharlotte Mecklenburg, Mai...
# 23336  At Morehead Rd, Incharlotte Mecklenburg, Maint...
# 23337  At Interstate 85, Mile Marker 40, North, Charl...
# 23338  At Interstate 85, Mile Marker 40, North, Charl...
# 23339  At Interstate 85, Mile Marker 40, North, Charl...
# 23340  At Interstate 85, Mile Marker 40, North, Charl...
# 23341  At Mangum Dairy Rd, South Of Monroe Union, Mai...
# 23342  At Odell School Rd, West Of Kannapolis Cabarru...
# 23343  At Interstate 85, Mile Marker 36, South, Charl...
# 23344  At Interstate 85, Mile Marker 36, South, Charl...
# 23389  At Interstate 40, Mile Marker 45, West, Ashevi...
# 23390  At Interstate 40, Mile Marker 44, West, Ashevi...
# 23391  At Us-19 23 74 Alt, Near Asheville Buncombe, V...
# 23392  At Interstate 26, Mile Marker 25, West, Ashevi...
# 23393  At Interstate 40, Mile Marker 44, West, Ashevi...
# 23394  At Interstate 40, Mile Marker 34, West, Clyde,...
# 23395  At Interstate 40, Mile Marker 28, East, Clyde,...
# 23396  At Interstate 40, Mile Marker 73, East, Old Fo...
# 23781  At Ocean View Ave Se, Inholden Beach Brunswick...
# 23782  At Us-17, North Of Wilmington New Hanover, Veh...
# 23783  At Us-17, North Of Wilmington New Hanover, Veh...
# 24051  At Nc 42, West Of Wilson Wilson, Maintenance, ...
# 24052  At Nc 42, East Of Wilson Wilson, Maintenance, ...
# 24053  At Nc-481, North East Of Enfield Halifax, Main...
#
# [1932 rows x 9 columns]

# %%
test_df = twitter_closures[(twitter_closures['road_closure'] == 1) & (twitter_closures['username'] == 'fl511_northeast')].head(100)

# %%
test_df.head()
# Out:
#                            date  \
# 13238 2016-10-13 23:03:56+00:00
# 13239 2016-10-13 22:53:46+00:00
# 13240 2016-10-13 22:40:26+00:00
# 13241 2016-10-13 22:40:25+00:00
# 13242 2016-10-13 22:38:47+00:00
#
#                                                     text      type  \
# 13238  update  disabled vehicle in duval on i-95 sout...  official
# 13239  update  traffic congestion in duval on i-295 e...  official
# 13240  new  disabled vehicle in duval on i-95 south r...  official
# 13241  new  disabled vehicle in duval on i-295 w sout...  official
# 13242  update  traffic congestion in duval on i-295 w...  official
#
#               username                                              tweet  \
# 13238  fl511_northeast  UPDATE  Disabled vehicle in Duval on I-95 sout...
# 13239  fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 E...
# 13240  fl511_northeast  NEW  Disabled vehicle in Duval on I-95 south r...
# 13241  fl511_northeast  NEW  Disabled vehicle in Duval on I-295 W sout...
# 13242  fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 W...
#
#          state  road_closure  \
# 13238  Florida             1
# 13239  Florida             1
# 13240  Florida             1
# 13241  Florida             1
# 13242  Florida             1
#
#                                            modified_text location
# 13238  At Update  Disabled Vehicle At Duval At Inters...
# 13239  At Update  Traffic Congestion At Duval At Inte...
# 13240  At New  Disabled Vehicle At Duval At Interstat...
# 13241  At New  Disabled Vehicle At Duval At Interstat...
# 13242  At Update  Traffic Congestion At Duval At Inte...

# %%
def get_loc(df, text_column, location_column):
    
    # Use Spacy to extract location names from `text` column
    for i in range(len(df)):
        
        #instantiate spacy model
        nlp = spacy.load("en_core_web_sm")
        
        # create documewnt from modified text column
        doc = nlp(df[text_column].iloc[i])
        
        locations = set()
        
        # loop through every entity in the doc
        for ent in doc.ents:
            
            # find entities labelled as places
            if (ent.label_=='GPE') or (ent.label_=='FAC') or (ent.label_ == 'LOC'):
                
                # put locations in a set
                locations.add(ent.text)
                df[location_column].iloc[i] = locations
                
    return df[location_column]

# %%
test = get_loc(test_df, 'modified_text', 'location')
# Out:
# /Users/templemoore/anaconda3/envs/dsi/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
test_df['location'] = test
test_df.head()
# Out:
#                            date  \
# 13238 2016-10-13 23:03:56+00:00
# 13239 2016-10-13 22:53:46+00:00
# 13240 2016-10-13 22:40:26+00:00
# 13241 2016-10-13 22:40:25+00:00
# 13242 2016-10-13 22:38:47+00:00
#
#                                                     text      type  \
# 13238  update  disabled vehicle in duval on i-95 sout...  official
# 13239  update  traffic congestion in duval on i-295 e...  official
# 13240  new  disabled vehicle in duval on i-95 south r...  official
# 13241  new  disabled vehicle in duval on i-295 w sout...  official
# 13242  update  traffic congestion in duval on i-295 w...  official
#
#               username                                              tweet  \
# 13238  fl511_northeast  UPDATE  Disabled vehicle in Duval on I-95 sout...
# 13239  fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 E...
# 13240  fl511_northeast  NEW  Disabled vehicle in Duval on I-95 south r...
# 13241  fl511_northeast  NEW  Disabled vehicle in Duval on I-295 W sout...
# 13242  fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 W...
#
#          state  road_closure  \
# 13238  Florida             1
# 13239  Florida             1
# 13240  Florida             1
# 13241  Florida             1
# 13242  Florida             1
#
#                                            modified_text  \
# 13238  At Update  Disabled Vehicle At Duval At Inters...
# 13239  At Update  Traffic Congestion At Duval At Inte...
# 13240  At New  Disabled Vehicle At Duval At Interstat...
# 13241  At New  Disabled Vehicle At Duval At Interstat...
# 13242  At Update  Traffic Congestion At Duval At Inte...
#
#                                                 location
# 13238    {Interstate 95 South Ramp From Exit 344 Butler}
# 13239                  {Interstate, East North, Exit 56}
# 13240    {Interstate 95 South Ramp From Exit 344 Butler}
# 13241         {Interstate 295 West South, Blanding Blvd}
# 13242  {Exit 3, Exit 5 San Jose, Interstate 295 West ...

# %%
test_df.to_csv("../data/Loc_Extracted/tweet_locations_sample_07302019.csv", index = False)

# %%
test_df = pd.read_csv("../data/Loc_Extracted/tweet_locations_sample_07302019.csv")

# %%
def exit_extractor (df, col, i_df):
    
    exits = []
    interstates = []
    lat = []
    long = []
    direction = []
    
    for item in df[col]:
        if 'Interstate' in item:
            
            i_string = re.search(r'Interstate (\S+)', item)
            interstates.append(i_string.group(0))
            
            if 'Exit' in item:
                e_string = re.search(r'Exit (\S+)', item)
                exits.append(e_string.group(0))
            else:
                exits.append("None")
        else:
            interstates.append("None")
            exits.append("None")
    
    new_df = pd.DataFrame(data = interstates, columns = ['interstate'])
    new_df['exits'] = exits
    
    for index, row in new_df.iterrows():
        
        if (row['interstate'] != "None") and (row['exits'] != "None"):
            
            mask = (i_df['interstate'].str.contains(row['interstate'])) & (i_df['exits'].str.contains(row['exits']))
            
            try:
                print(i_df[mask]['exits'].iloc[0] + ' ' + i_df[mask]['interstate'].iloc[0] + ' ' + i_df[mask]['dir'].iloc[0])
                
                lat.append(i_df[mask].iloc[0]['lat'])
                long.append(i_df[mask].iloc[0]['long'])
                
            except:
                print(f"No exit found at {index}")
                
                lat.append(np.nan)
                long.append(np.nan)

        else:
            print("No exit found")
            lat.append(np.nan)
            long.append(np.nan)
            
    
    new_df['lat'] = lat
    new_df['long'] = long
    
    return new_df

# %%
exits[(exits['interstate'] == 'Interstate 295') & (exits['exits'] == "Exit 12")].iloc[0]['lat']
# Out:
# '30.19137'

# %%
e_df = exit_extractor(test_df, 'modified_text', exits)
# Out:
# Exit 344 Interstate 95 N
# Exit 56 Interstate 295 S
# Exit 344 Interstate 95 N
# No exit found
# Exit 3 Interstate 295 S
# Exit 53 Interstate 295 S
# Exit 353B Interstate 95 N
# Exit 347 Interstate 95 N
# Exit 12 Interstate 295 N
# No exit found
# Exit 52 Interstate 295 S
# No exit found
# No exit found
# No exit found
# Exit 25 Interstate 295 N
# Exit 53 Interstate 295 S
# Exit 25 Interstate 295 N
# Exit 337 Interstate 95 N
# Exit 53 Interstate 295 S
# No exit found
# Exit 337 Interstate 95 N
# No exit found
# No exit found
# No exit found
# Exit 53 Interstate 295 S
# No exit found
# No exit found
# Exit 360 Interstate 10 E
# Exit 61B Interstate 295 S
# Exit 360 Interstate 95 N
# Exit 360 Interstate 10 E
# Exit 355 Interstate 95 N
# Exit 61B Interstate 295 S
# Exit 3 Interstate 295 S
# No exit found
# No exit found at 35
# Exit 58 Interstate 295 S
# Exit 346A Interstate 95 S
# Exit 3 Interstate 295 S
# Exit 356A Interstate 95 N
# Exit 51 Interstate 295 S
# Exit 344 Interstate 95 N
# No exit found
# Exit 354A Interstate 95 N
# No exit found at 44
# Exit 52 Interstate 295 S
# Exit 58 Interstate 295 S
# No exit found
# Exit 337 Interstate 95 N
# Exit 346A Interstate 95 S
# Exit 345 Interstate 95 N
# Exit 350B Interstate 95 S
# Exit 344 Interstate 95 N
# Exit 347 Interstate 95 N
# No exit found
# Exit 53 Interstate 295 S
# Exit 355 Interstate 95 N
# Exit 346A Interstate 95 S
# No exit found
# Exit 346A Interstate 95 S
# No exit found
# Exit 3 Interstate 295 S
# No exit found
# No exit found
# Exit 354A Interstate 95 N
# Exit 354A Interstate 95 N
# Exit 353A Interstate 95 S
# No exit found
# No exit found
# No exit found
# Exit 357 Interstate 10 E
# No exit found
# No exit found
# Exit 357 Interstate 10 E
# Exit 360 Interstate 10 E
# Exit 357 Interstate 10 E
# Exit 5A Interstate 295 S
# No exit found
# Exit 357 Interstate 10 E
# Exit 3 Interstate 295 S
# Exit 339 Interstate 95 N
# Exit 347 Interstate 95 N
# Exit 357 Interstate 10 E
# Exit 357 Interstate 10 E
# Exit 351A Interstate 95 N
# Exit 347 Interstate 95 N
# Exit 351A Interstate 95 N
# No exit found
# Exit 356 Interstate 10 E
# No exit found
# Exit 46 Interstate 295 S
# No exit found at 91
# Exit 354A Interstate 95 N
# Exit 350B Interstate 95 S
# Exit 335 Interstate 95 N
# No exit found
# Exit 335 Interstate 95 N
# Exit 19 Interstate 295 N
# Exit 341 Interstate 95 N
# Exit 46 Interstate 295 S

# %%
final_df = pd.concat([test_df, e_df], axis = 1)

# %%
final_df.dropna()
# Out:
#                          date  \
# 0   2016-10-13 23:03:56+00:00
# 1   2016-10-13 22:53:46+00:00
# 2   2016-10-13 22:40:26+00:00
# 4   2016-10-13 22:38:47+00:00
# 5   2016-10-13 22:38:36+00:00
# 6   2016-10-13 22:34:06+00:00
# 7   2016-10-13 22:33:41+00:00
# 8   2016-10-13 22:28:49+00:00
# 10  2016-10-13 22:14:08+00:00
# 14  2016-10-13 21:29:47+00:00
# 15  2016-10-13 21:23:45+00:00
# 16  2016-10-13 21:14:04+00:00
# 17  2016-10-13 21:11:04+00:00
# 18  2016-10-13 21:11:03+00:00
# 20  2016-10-13 20:58:59+00:00
# 24  2016-10-13 20:53:40+00:00
# 27  2016-10-13 20:30:13+00:00
# 28  2016-10-13 20:30:13+00:00
# 29  2016-10-13 20:13:36+00:00
# 30  2016-10-13 20:13:35+00:00
# 31  2016-10-13 20:13:35+00:00
# 32  2016-10-13 20:09:19+00:00
# 33  2016-10-13 20:04:22+00:00
# 36  2016-10-13 20:04:03+00:00
# 37  2016-10-13 20:04:02+00:00
# 38  2016-10-13 19:58:42+00:00
# 39  2016-10-13 19:58:41+00:00
# 40  2016-10-13 19:53:46+00:00
# 41  2016-10-13 19:53:45+00:00
# 43  2016-10-13 19:48:59+00:00
# ..                        ...
# 56  2016-10-13 18:58:51+00:00
# 57  2016-10-13 18:58:39+00:00
# 59  2016-10-13 18:23:33+00:00
# 61  2016-10-13 16:58:39+00:00
# 64  2016-10-13 16:43:50+00:00
# 65  2016-10-13 16:18:33+00:00
# 66  2016-10-13 16:18:33+00:00
# 70  2016-10-13 14:44:01+00:00
# 73  2016-10-13 14:14:06+00:00
# 74  2016-10-13 14:09:13+00:00
# 75  2016-10-13 14:00:30+00:00
# 76  2016-10-13 13:58:53+00:00
# 78  2016-10-13 13:49:18+00:00
# 79  2016-10-13 13:38:47+00:00
# 80  2016-10-13 13:34:46+00:00
# 81  2016-10-13 13:34:45+00:00
# 82  2016-10-13 13:23:40+00:00
# 83  2016-10-13 13:18:52+00:00
# 84  2016-10-13 13:18:32+00:00
# 85  2016-10-13 13:13:45+00:00
# 86  2016-10-13 13:04:20+00:00
# 88  2016-10-13 12:58:32+00:00
# 90  2016-10-13 12:48:43+00:00
# 92  2016-10-13 12:43:32+00:00
# 93  2016-10-13 12:40:54+00:00
# 94  2016-10-13 12:40:29+00:00
# 96  2016-10-13 12:19:31+00:00
# 97  2016-10-13 12:15:12+00:00
# 98  2016-10-13 12:15:00+00:00
# 99  2016-10-13 12:14:22+00:00
#
#                                                  text      type  \
# 0   update  disabled vehicle in duval on i-95 sout...  official
# 1   update  traffic congestion in duval on i-295 e...  official
# 2   new  disabled vehicle in duval on i-95 south r...  official
# 4   update  traffic congestion in duval on i-295 w...  official
# 5   update  traffic congestion in duval on i-295 e...  official
# 6   new  disabled vehicle in duval on i-95 north r...  official
# 7   update  traffic congestion in duval on i-95 no...  official
# 8   new  unconfirmed disabled vehicle in duval on ...  official
# 10  new  disabled vehicle in duval on i-295 e sout...  official
# 14  update  traffic congestion in duval on i-295 w...  official
# 15  update  traffic congestion in duval on i-295 e...  official
# 16  new  traffic congestion in duval on i-295 w so...  official
# 17  update  traffic congestion in duval on i-95 so...  official
# 18  update  traffic congestion in duval on i-295 e...  official
# 20  new  traffic congestion in duval on i-95 south...  official
# 24  new  traffic congestion in duval on i-295 e no...  official
# 27  update  traffic congestion in duval on i-10 ea...  official
# 28  update  traffic congestion in duval on i-295 w...  official
# 29  new  unconfirmed disabled vehicle in duval on ...  official
# 30  new  traffic congestion in duval on i-10 east ...  official
# 31  update  traffic congestion in duval on i-95 so...  official
# 32  new  traffic congestion in duval on i-295 w no...  official
# 33  update  traffic congestion in duval on i-295 w...  official
# 36  update  traffic congestion in duval on i-295 e...  official
# 37  update  traffic congestion in duval on i-95 so...  official
# 38  new  traffic congestion in duval on i-295 w no...  official
# 39  update  traffic congestion in duval on i-95 so...  official
# 40  update  traffic congestion in duval on i-295 e...  official
# 41  update  traffic congestion in duval on i-95 no...  official
# 43  new  traffic congestion in duval on i-95 south...  official
# ..                                                ...       ...
# 56  new  disabled vehicle in duval on i-95 north r...  official
# 57  update  traffic congestion in duval on i-95 no...  official
# 59  new  traffic congestion in duval on i-95 north...  official
# 61  new  unconfirmed disabled vehicle in duval on ...  official
# 64  update  traffic congestion in duval on i-95 so...  official
# 65  new  traffic congestion in duval on i-95 south...  official
# 66  update  crash in duval on i-95 south at exit 3...  official
# 70  update  disabled vehicle in duval on i-10 west...  official
# 73  new  disabled vehicle in duval on i-10 west at...  official
# 74  update  crash in duval on i-10 east at exit 36...  official
# 75  update  multi-vehicle crash in duval on i-10 e...  official
# 76  update  traffic congestion in duval on i-295 w...  official
# 78  new  multi-vehicle crash in duval on i-10 east...  official
# 79  update  traffic congestion in duval on i-295 w...  official
# 80  new  traffic congestion in duval on i-95 north...  official
# 81  update  traffic congestion in duval on i-95 no...  official
# 82  update  crash in duval on i-10 east at exit 35...  official
# 83  new  crash in duval on i-10 east at exit 357 l...  official
# 84  update  traffic congestion in duval on i-95 so...  official
# 85  new  traffic congestion in duval on i-95 north...  official
# 86  update  traffic congestion in duval on i-95 so...  official
# 88  update  traffic congestion in duval on i-10 ea...  official
# 90  update  traffic congestion in duval on i-295 e...  official
# 92  update  traffic congestion in duval on i-95 so...  official
# 93  new  crash in duval on i-95 south beyond exit ...  official
# 94  update  traffic congestion in duval on i-95 so...  official
# 96  new  traffic congestion in duval on i-95 south...  official
# 97  update  traffic congestion in duval on i-295 w...  official
# 98  update  traffic congestion in duval on i-95 no...  official
# 99  update  traffic congestion in duval on i-295 e...  official
#
#            username                                              tweet  \
# 0   fl511_northeast  UPDATE  Disabled vehicle in Duval on I-95 sout...
# 1   fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 E...
# 2   fl511_northeast  NEW  Disabled vehicle in Duval on I-95 south r...
# 4   fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 W...
# 5   fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 E...
# 6   fl511_northeast  NEW  Disabled vehicle in Duval on I-95 north r...
# 7   fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 no...
# 8   fl511_northeast  NEW  Unconfirmed disabled vehicle in Duval on ...
# 10  fl511_northeast  NEW  Disabled vehicle in Duval on I-295 E sout...
# 14  fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 W...
# 15  fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 E...
# 16  fl511_northeast  NEW  Traffic congestion in Duval on I-295 W so...
# 17  fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 so...
# 18  fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 E...
# 20  fl511_northeast  NEW  Traffic congestion in Duval on I-95 south...
# 24  fl511_northeast  NEW  Traffic congestion in Duval on I-295 E no...
# 27  fl511_northeast  UPDATE  Traffic congestion in Duval on I-10 ea...
# 28  fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 W...
# 29  fl511_northeast  NEW  Unconfirmed disabled vehicle in Duval on ...
# 30  fl511_northeast  NEW  Traffic congestion in Duval on I-10 east ...
# 31  fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 so...
# 32  fl511_northeast  NEW  Traffic congestion in Duval on I-295 W no...
# 33  fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 W...
# 36  fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 E...
# 37  fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 so...
# 38  fl511_northeast  NEW  Traffic congestion in Duval on I-295 W no...
# 39  fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 so...
# 40  fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 E...
# 41  fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 no...
# 43  fl511_northeast  NEW  Traffic congestion in Duval on I-95 south...
# ..              ...                                                ...
# 56  fl511_northeast  NEW  Disabled vehicle in Duval on I-95 north r...
# 57  fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 no...
# 59  fl511_northeast  NEW  Traffic congestion in Duval on I-95 north...
# 61  fl511_northeast  NEW  Unconfirmed disabled vehicle in Duval on ...
# 64  fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 so...
# 65  fl511_northeast  NEW  Traffic congestion in Duval on I-95 south...
# 66  fl511_northeast  UPDATE  Crash in Duval on I-95 south at Exit 3...
# 70  fl511_northeast  UPDATE  Disabled vehicle in Duval on I-10 west...
# 73  fl511_northeast  NEW  Disabled vehicle in Duval on I-10 west at...
# 74  fl511_northeast  UPDATE  Crash in Duval on I-10 east at Exit 36...
# 75  fl511_northeast  UPDATE  Multi-vehicle crash in Duval on I-10 e...
# 76  fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 W...
# 78  fl511_northeast  NEW  Multi-vehicle crash in Duval on I-10 east...
# 79  fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 W...
# 80  fl511_northeast  NEW  Traffic congestion in Duval on I-95 north...
# 81  fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 no...
# 82  fl511_northeast  UPDATE  Crash in Duval on I-10 east at Exit 35...
# 83  fl511_northeast  NEW  Crash in Duval on I-10 east at Exit 357 L...
# 84  fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 so...
# 85  fl511_northeast  NEW  Traffic congestion in Duval on I-95 north...
# 86  fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 so...
# 88  fl511_northeast  UPDATE  Traffic congestion in Duval on I-10 ea...
# 90  fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 E...
# 92  fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 so...
# 93  fl511_northeast  NEW  Crash in Duval on I-95 south beyond Exit ...
# 94  fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 so...
# 96  fl511_northeast  NEW  Traffic congestion in Duval on I-95 south...
# 97  fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 W...
# 98  fl511_northeast  UPDATE  Traffic congestion in Duval on I-95 no...
# 99  fl511_northeast  UPDATE  Traffic congestion in Duval on I-295 E...
#
#       state  road_closure                                      modified_text  \
# 0   Florida             1  At Update  Disabled Vehicle At Duval At Inters...
# 1   Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 2   Florida             1  At New  Disabled Vehicle At Duval At Interstat...
# 4   Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 5   Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 6   Florida             1  At New  Disabled Vehicle At Duval At Interstat...
# 7   Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 8   Florida             1  At New  Unconfirmed Disabled Vehicle At Duval ...
# 10  Florida             1  At New  Disabled Vehicle At Duval At Interstat...
# 14  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 15  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 16  Florida             1  At New  Traffic Congestion At Duval At Interst...
# 17  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 18  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 20  Florida             1  At New  Traffic Congestion At Duval At Interst...
# 24  Florida             1  At New  Traffic Congestion At Duval At Interst...
# 27  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 28  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 29  Florida             1  At New  Unconfirmed Disabled Vehicle At Duval ...
# 30  Florida             1  At New  Traffic Congestion At Duval At Interst...
# 31  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 32  Florida             1  At New  Traffic Congestion At Duval At Interst...
# 33  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 36  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 37  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 38  Florida             1  At New  Traffic Congestion At Duval At Interst...
# 39  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 40  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 41  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 43  Florida             1  At New  Traffic Congestion At Duval At Interst...
# ..      ...           ...                                                ...
# 56  Florida             1  At New  Disabled Vehicle At Duval At Interstat...
# 57  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 59  Florida             1  At New  Traffic Congestion At Duval At Interst...
# 61  Florida             1  At New  Unconfirmed Disabled Vehicle At Duval ...
# 64  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 65  Florida             1  At New  Traffic Congestion At Duval At Interst...
# 66  Florida             1  At Update  Crash At Duval At Interstate 95 Sou...
# 70  Florida             1  At Update  Disabled Vehicle At Duval At Inters...
# 73  Florida             1  At New  Disabled Vehicle At Duval At Interstat...
# 74  Florida             1  At Update  Crash At Duval At Interstate 10 Eas...
# 75  Florida             1  At Update  Multi-Vehicle Crash At Duval At Int...
# 76  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 78  Florida             1  At New  Multi-Vehicle Crash At Duval At Inters...
# 79  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 80  Florida             1  At New  Traffic Congestion At Duval At Interst...
# 81  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 82  Florida             1  At Update  Crash At Duval At Interstate 10 Eas...
# 83  Florida             1  At New  Crash At Duval At Interstate 10 East A...
# 84  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 85  Florida             1  At New  Traffic Congestion At Duval At Interst...
# 86  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 88  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 90  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 92  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 93  Florida             1  At New  Crash At Duval At Interstate 95 South ...
# 94  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 96  Florida             1  At New  Traffic Congestion At Duval At Interst...
# 97  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 98  Florida             1  At Update  Traffic Congestion At Duval At Inte...
# 99  Florida             1  At Update  Traffic Congestion At Duval At Inte...
#
#                                              location      interstate  \
# 0   {'Interstate 95 South Ramp From Exit 344 Butler'}   Interstate 95
# 1             {'Interstate', 'East North', 'Exit 56'}  Interstate 295
# 2   {'Interstate 95 South Ramp From Exit 344 Butler'}   Interstate 95
# 4   {'Exit 3', 'Exit 5 San Jose', 'Interstate 295 ...  Interstate 295
# 5            {'Interstate 295 East South', 'Exit 53'}  Interstate 295
# 6     {'Interstate 95 North Ramp To Exit 353B Union'}   Interstate 95
# 7   {'Fuller', 'Interstate 95 North From Exit 347 ...   Interstate 95
# 8   {'Exit 12 Blanding Blvd', 'Interstate 295 West...  Interstate 295
# 10  {'Exit 52 University Of North Florida', 'Inter...  Interstate 295
# 14  {'Exit 25', 'Pritchard Rd', 'Interstate 295 We...  Interstate 295
# 15        {'Interstate', 'East North', 'Johns Bluff'}  Interstate 295
# 16  {'Exit 25', 'Pritchard Rd', 'Interstate 295 We...  Interstate 295
# 17  {'Interstate 95 South From Exit 337 Interstate...   Interstate 95
# 18                       {'Interstate', 'East North'}  Interstate 295
# 20  {'Interstate 95 South From Exit 337 Interstate...   Interstate 95
# 24                       {'Interstate', 'East North'}  Interstate 295
# 27                   {'Interstate 10 East From Exit'}   Interstate 10
# 28  {'Exit 3', 'Interstate 95', 'Exit 61', 'Inters...  Interstate 295
# 29       {'Interstate 95 South', 'Exit 360 Dunn Ave'}   Interstate 95
# 30                   {'Interstate 10 East From Exit'}   Interstate 10
# 31              {'Interstate 95 South From Exit 355'}   Interstate 95
# 32  {'Exit 3', 'Interstate 95', 'Exit 61', 'Inters...  Interstate 295
# 33  {'Exit 3', 'Exit 35 Interstate 95', 'Interstat...  Interstate 295
# 36            {'Interstate', 'East North', 'Exit 56'}  Interstate 295
# 37  {'Exit 344 Butler', 'Interstate 95 South From ...   Interstate 95
# 38  {'Exit 3', 'Exit 35 Interstate 95', 'Interstat...  Interstate 295
# 39              {'Interstate 95 South From Exit 356'}   Interstate 95
# 40  {'Interstate 295 East South', 'Exit 51 Beach B...  Interstate 295
# 41  {'Interstate 95 North From Exit 344', 'Exit 34...   Interstate 95
# 43              {'Interstate 95 South From Exit 354'}   Interstate 95
# ..                                                ...             ...
# 56  {'Interstate 95 North Ramp To Exit 355', 'Golf...   Interstate 95
# 57  {'Interstate 95 North From Exit 346 University...   Interstate 95
# 59  {'Interstate 95 North From Exit 346 University...   Interstate 95
# 61            {'Exit 3', 'Interstate 295 West South'}  Interstate 295
# 64  {'Exit 353', 'Interstate 95 South From Exit 354'}   Interstate 95
# 65  {'Exit 353', 'Interstate 95 South From Exit 354'}   Interstate 95
# 66       {'Left Lane Blocked', 'Interstate 95 South'}   Interstate 95
# 70                 {'Exit 357', 'Interstate 10 West'}   Interstate 10
# 73                 {'Exit 357', 'Interstate 10 West'}   Interstate 10
# 74  {'Right Lane', 'Interstate 10 East', 'Exit 360...   Interstate 10
# 75                 {'Interstate 10 East', 'Exit 357'}   Interstate 10
# 76  {'San Jose', 'Interstate 95', 'Exit 5', 'Inter...  Interstate 295
# 78                 {'Interstate 10 East', 'Exit 357'}   Interstate 10
# 79  {'Exit 3', 'Interstate 295 West South', 'Inter...  Interstate 295
# 80  {'Interstate 95 North From Exit 339 Philips', ...   Interstate 95
# 81        {'Interstate 95 North At Exit 347 Emerson'}   Interstate 95
# 82                 {'Interstate 10 East', 'Exit 357'}   Interstate 10
# 83  {'Exit 357 Lane Ave', 'Interstate 10 East', 'N...   Interstate 10
# 84  {'Interstate 10', 'Interstate 95 South', 'Exit...   Interstate 95
# 85        {'Interstate 95 North At Exit 347 Emerson'}   Interstate 95
# 86  {'Interstate 95 South From Exit 351 Interstate...   Interstate 95
# 88  {'Exit 363', 'Interstate 95', 'Interstate 10 E...   Interstate 10
# 90  {'Merrill Rd', 'Interstate 295 East South', 'E...  Interstate 295
# 92  {'Interstate 10', 'Interstate 95 South From Ex...   Interstate 95
# 93  {'Interstate 95 South Beyond Exit 350', 'Right...   Interstate 95
# 94  {'Exit 335', 'Interstate 95 South', 'Interstat...   Interstate 95
# 96  {'Exit 335', 'Interstate 95 South', 'Interstat...   Interstate 95
# 97  {'Normandy Blvd', 'Exit 21 Interstate 10', 'Ex...  Interstate 295
# 98                  {'Interstate 95 North From Exit'}   Interstate 95
# 99  {'Exit 46', 'Johns Bluff', 'Merrill Rd', 'Exit...  Interstate 295
#
#         exits                 lat      long
# 0    Exit 344            30.24393 -81.58858
# 1     Exit 56            30.21982 -81.51444
# 2    Exit 344            30.24393 -81.58858
# 4      Exit 3            30.16897 -81.59703
# 5     Exit 53              30.257 -81.51787
# 6   Exit 353B            30.33387 -81.67056
# 7    Exit 347  30.288710000000002 -81.62745
# 8     Exit 12            30.19137 -81.71509
# 10    Exit 52            30.27157 -81.52147
# 14    Exit 25            30.36906 -81.76069
# 15    Exit 53              30.257 -81.51787
# 16    Exit 25            30.36906 -81.76069
# 17   Exit 337            30.15859 -81.55057
# 18    Exit 53              30.257 -81.51787
# 20   Exit 337            30.15859 -81.55057
# 24    Exit 53              30.257 -81.51787
# 27   Exit 360  30.320859999999996 -81.70904
# 28    Exit 61            30.16726 -81.55374
# 29   Exit 360            30.42657 -81.65617
# 30   Exit 360  30.320859999999996 -81.70904
# 31   Exit 355            30.36142 -81.66860
# 32    Exit 61            30.16726 -81.55374
# 33     Exit 3            30.16897 -81.59703
# 36    Exit 58            30.18663 -81.51383
# 37   Exit 346            30.27203 -81.61395
# 38     Exit 3            30.16897 -81.59703
# 39   Exit 356            30.38052 -81.67336
# 40    Exit 51            30.29054 -81.52207
# 41   Exit 344            30.24393 -81.58858
# 43   Exit 354             30.3542 -81.66838
# ..        ...                 ...       ...
# 56   Exit 355            30.36142 -81.66860
# 57   Exit 346            30.27203 -81.61395
# 59   Exit 346            30.27203 -81.61395
# 61     Exit 3            30.16897 -81.59703
# 64   Exit 354             30.3542 -81.66838
# 65   Exit 354             30.3542 -81.66838
# 66   Exit 353            30.33461 -81.67100
# 70   Exit 357             30.3155 -81.75616
# 73   Exit 357             30.3155 -81.75616
# 74   Exit 360  30.320859999999996 -81.70904
# 75   Exit 357             30.3155 -81.75616
# 76     Exit 5            30.17924 -81.62420
# 78   Exit 357             30.3155 -81.75616
# 79     Exit 3            30.16897 -81.59703
# 80   Exit 339            30.18488 -81.55790
# 81   Exit 347  30.288710000000002 -81.62745
# 82   Exit 357             30.3155 -81.75616
# 83   Exit 357             30.3155 -81.75616
# 84   Exit 351            30.31568 -81.67278
# 85   Exit 347  30.288710000000002 -81.62745
# 86   Exit 351            30.31568 -81.67278
# 88   Exit 356  30.315179999999998 -81.77517
# 90    Exit 46            30.35611 -81.55550
# 92   Exit 354             30.3542 -81.66838
# 93   Exit 350            30.31451 -81.66867
# 94   Exit 335            30.13684 -81.53598
# 96   Exit 335            30.13684 -81.53598
# 97    Exit 19            30.29471 -81.77069
# 98   Exit 341            30.21727 -81.56876
# 99    Exit 46            30.35611 -81.55550
#
# [69 rows x 13 columns]

# %%
final_df[final_df['date'] = '2016-10-10']
