# %% [markdown]
# # 1b. Real Time Twitter Scaper
#
# This notebook uses the Tweepy module to access the Twitter API. We used the Twitter API to get Tweets from blue-checkmarked 511 Twitter accounts from the Jackonville, FL metro area. This downloads the latest 200 tweets from a Twitter list.

# %%
import pandas as pd
import tweepy
import json
import datetime
import re

# %%
# Enter Access Identification numbers 
with open('../twitter_credentials.json') as cred_data:
    info = json.load(cred_data)
    consumer_key = info['CONSUMER_KEY']
    consumer_secret = info['CONSUMER_SECRET']
    access_token = info['ACCESS_TOKEN']
    access_secret = info['ACCESS_SECRET']
    
# Authenticate Twitter API using  account Keys 
auth_details = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth_details.set_access_token(access_token, access_secret)
my_accounts = []

# create api instance
api = tweepy.API(auth_details, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
# check username
user = api.me()
print(user.name)
# Out:
# Tee Moore

# %%
# define fucntion to get tweets and add class functionality
def get_tweets(username, list_name = None, num = 200):
       
    # check for list
    if not list_name:
        # get timeline of user if no list
        tweet = tweepy.Cursor(api.user_timeline, screen_name = username).items(num)
    else:
        # get list timeline if list
        tweet = tweepy.Cursor(api.list_timeline, owner_screen_name = username, slug = list_name).items(num)
            
    # Empty Arrays
    tmp=[]
    closure_list = []
  
    # create array of tweet information: username,  
    # tweet id, date/time, text 
    # create dictionary for each tweet
    for status in tweet:
        tweet_dict = {}
        tweet_dict['id'] = status.id
        tweet_dict['username'] = status.user.screen_name
        tweet_dict['date'] = status.created_at
        tweet_dict['text'] = status.text
        tweet_dict['hashtags'] = status.entities['hashtags']
        tweet_dict['geo'] = status.coordinates
        tweet_dict['type'] = 'official'
        tmp.append(status.text)
        closure_list.append(tweet_dict)
  
    # writing the tweets
    print(tmp)
  
    # return tweet_dict
    return closure_list
    
# Driver code 
if __name__ == '__main__': 
  
    # Here goes the twitter handle for the user and optional list
    # whose tweets are to be extracted. 
    twts = get_tweets('ClydeLazersex', 'Evac-Route-RT', num = 200)
# Out:
# ['Updated: Crash in Duval on SR-202 / Butler Blvd west at I-295 E, right lane blocked. Last updated at 09:12:02AM. https://t.co/D0G8dvGzZY', 'Good News!! Project wrapped early!!!! #ANJTraffic @ActionNewsJax @WOKVNews https://t.co/NpDbesQ33Z', 'Roosevelt Boulevard and San Juan Avenue railroad crossing reconstruction is complete and the intersection has reopened.', 'Year to Date in 2019:\n101 Traffic Fatalities in Duval County.\n\n🚗vs🚶🏻\u200d♂️= 27 (27%)\n🚗vs🚙= 26 (26%)\n🚙= 26 (26%)\n🚗vs🏍=… https://t.co/17i9MYQLYa', 'Jacksonville:  There will be lane closure on New Kings Rd northbound from Dunn Ave to Woodley Rd due to...https://t.co/q6rZmrGQeC', 'Gas Prices on the decline! Maybe time for that weekend trip....check it out https://t.co/Bkju9HLiZ2 #ANJTraffic… https://t.co/qw9LwwvpIq', 'RT @fl511_state: It’s almost time to head back-to-school. Use FL511 to guide you to a store during Florida’s back-to-school sales tax holid…', 'New: Disabled vehicle in Duval on I-295 E south at Dames Point, right lane blocked. Last updated at 07:10:14AM....https://t.co/0aP1cKGGuX', 'Cleared: Planned construction in Clay on SR-21 / Blanding Bl
# 172  Updated: Disabled vehicle in Duval on I-95 nor...  official
# 173  The bad guy is hoping you leave your vehicle u...  official
# 174  Updated: Planned construction in Alachua on SR...  official
# 175  Updated: Crash in Duval on I-295 E north befor...  official
# 176  Updated: Planned construction in Duval on I-29...  official
# 177  Updated: Traffic congestion in Duval on I-95 n...  official
# 178  Cleared: Crash in Duval on I-95 north at Fulle...  official
# 179  Cleared: Planned construction in Duval on I-10...  official
# 180  New: Planned construction in Duval on I-295 W ...  official
# 181  New: Planned construction in Duval on I-295 W ...  official
# 182  New: Disabled vehicle in Duval on I-95 north a...  official
# 183  Our crews are now leaving the scene... @FHPJac...  official
# 184  Updated: Traffic congestion in Duval on I-295 ...  official
# 185  Updated: Traffic congestion in Duval on I-95 n...  official
# 186  Command has now added a sixth patient to the c...  official
# 187  New: Traffic congestion in Duval on I-295 E no...  official
# 188  New: Planned construction in Duval on I-10 eas...  official
# 189  Updated: Crash in Duval on I-95 north at Fulle...  official
# 190  New: Traffic congestion in Duval on I-95 north...  official
# 191  Command has advised this is an MCI level I (5 ...  official
# 192  Crews are responding to a traffic accident nor...  official
# 193  New: Crash in Duval on I-95 north at Fuller Wa...  official
# 194  New: Planned construction in Duval on I-95 nor...  official
# 195  New: Planned construction in Duval on I-295 E ...  official
# 196  New: Planned construction in Duval on US-90 / ...  official
# 197  Jacksonville/Baldwin: There is construction on...  official
# 198  Updated: Planned construction in Duval on SR-2...  official
# 199  New: Traffic congestion in Duval on SR-21 / Bl...  official
#
#             username
# 0    fl511_northeast
# 1      ActionTraffic
# 2             JSOPIO
# 3             JSOPIO
# 4    fl511_northeast
# 5      ActionTraffic
# 6    fl511_northeast
# 7    fl511_northeast
# 8    fl511_northeast
# 9    fl511_northeast
# 10     ActionTraffic
# 11   fl511_northeast
# 12     ActionTraffic
# 13   fl511_northeast
# 14   fl511_northeast
# 15   fl511_northeast
# 16   fl511_northeast
# 17   fl511_northeast
# 18   fl511_northeast
# 19   fl511_northeast
# 20            JSOPIO
# 21   fl511_northeast
# 22   fl511_northeast
# 23   fl511_northeast
# 24   fl511_northeast
# 25   fl511_northeast
# 26   fl511_northeast
# 27   fl511_northeast
# 28   fl511_northeast
# 29   fl511_northeast
# ..               ...
# 170  fl511_northeast
# 171  fl511_northeast
# 172  fl511_northeast
# 173           JSOPIO
# 174  fl511_northeast
# 175  fl511_northeast
# 176  fl511_northeast
# 177  fl511_northeast
# 178  fl511_northeast
# 179  fl511_northeast
# 180  fl511_northeast
# 181  fl511_northeast
# 182  fl511_northeast
# 183          JFRDJAX
# 184  fl511_northeast
# 185  fl511_northeast
# 186          JFRDJAX
# 187  fl511_northeast
# 188  fl511_northeast
# 189  fl511_northeast
# 190  fl511_northeast
# 191          JFRDJAX
# 192          JFRDJAX
# 193  fl511_northeast
# 194  fl511_northeast
# 195  fl511_northeast
# 196  fl511_northeast
# 197  fl511_northeast
# 198  fl511_northeast
# 199  fl511_northeast
#
# [200 rows x 7 columns]

# %%
final_df.to_csv('../data/Current_tweets/RT_tweets_official_08022019.csv', index = False)
